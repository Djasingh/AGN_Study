# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../dataset_v5/v5_2/dataset_v5_2/final_shodhganga_dataset_v5_2.csv')

# %%
dataset1 = pd.read_csv('/home/dj/Desktop/Shodhganga_work/sodhganga_code/dataset_v5/v5_2/v5_2_2/final_shodhganga_dataset_v5_2_2.csv')

# %%
edges2 = pd.read_csv('/home/dj/Desktop/Shodhganga_work/sodhganga_code/dataset_v5/v5_2/v5_2_2/final_shodhganga_dataset_v5_2_4.csv')

# %%
nodes2 = pd.read_csv('/home/dj/Desktop/Shodhganga_work/sodhganga_code/dataset_v5/v5_2/v5_2_2/index_file2_v5_2_4.csv')

# %%
dataset1.shape
# Out:
# (201477, 24)

# %%
dataset.shape
# Out:
# (201477, 21)

# %%
dataset.columns
# Out:
# Index(['advisorId', 'researcherId', 'advId', 'resId', 'advisor_name',
#        'researcher_name', 'publisher_dept', 'DepartmentId',
#        'publisher_institution', 'instituteId', 'title', 'thesisId',
#        'N_thesisId', 'date_submitted', 'new_date_awarded', 'dc.date.awarded',
#        'dc.subject.ddc', 'uniq_ddc_across_dept', 'dc.description.abstract',
#        'dc.title.alternative', 'N_DepartmentId_1'],
#       dtype='object')

# %%
#read pickle
with open('/home/dj/Desktop/Shodhganga_work/sodhganga_code/dataset_v5/v5_2/sim_name_in_operator_1.pkl', 'rb') as f:
    in_data= pickle.load(f)

# %%
#in_data

# %%
dataset[dataset["researcher_name"].str.contains("Kumar, Rajesh")]
# Out:
#         advisorId  researcherId  advId   resId            advisor_name  \
# 2278          972         95689    972   95689            Kumar, Manoj
# 3529         1532         96757   1532   96757             Negi, Vijay
# 3907         1627         97101   1627   97101           Sharma, B. K.
# 4323         1863         97508   1863   97508            Verma, D. D.
# 6593         2841         99538   2841   99538          Srivastava, Op
# ...           ...           ...    ...     ...                     ...
# 183536      85057        264295  85057  284945  Sharma, Sukesh Chander
# 183903      85223        264692  85223  264692     Bharadwaj, Lalit M.
# 199271      92706        279598  92706  279598            Kalia, S. B.
# 199344      92713        279598  92713  285560          Blokhra, R. L.
# 200338      92956        280566  92889  280566     Kulbhushan, Chandel
#
#        researcher_name                        publisher_dept DepartmentId  \
# ...

# %%
dataset[dataset["resId"].isin([279598, 285560])].values
# Out:
# array([[92706, 279598, 92706, 279598, 'Kalia, S. B.', 'Kumar, Rajesh',
#         'department of chemistry', 'D1331',
#         'Himachal Pradesh University', 'I49',
#         'Physicochemical studies on some novel carbamate complexes of copper_ii_ and zinc_ii_ with potential insecticidal activity',
#         'T123458', 'T123458', '2015-01-01', '2015-07-01', nan,
#         '500::Natural sciences & mathematics|540::Chemistry & allied sciences',
#         "('500', '540')", nan, nan, 'D1331'],
#        [92713, 279598, 92713, 285560, 'Blokhra, R. L.', 'Kumar, Rajesh',
#         'department of chemistry', 'D1331',
#         'Himachal Pradesh University', 'I49',
#         'Ultrasonic studies of some solutions involving isopropyl alcohol',
#         'T137133', 'T137133', '1990-01-01', '1990-07-01', nan,
#         '500::Natural sciences & mathematics|540::Chemistry & allied sciences',
#         "('500', '540')", nan, nan, 'D1331']], dtype=object)

# %%
dataset[dataset["researcher_name"].str.contains("Kumar, Rajesh")][['resId','researcher_name','publisher_dept', 'publisher_institution','title']].iloc[0:20].values
# Out:
# array([[95689, 'Kumar, Rajesh', 'department of chemistry',
#         'Guru Nanak Dev University',
#         'Studies in the synthesis and recognition behaviour of Thiacalix[4] arene based receptors'],
#        [96757, 'Kumar, Rajesh', 'department of english',
#         'Maharishi Markandeshwar University',
#         'TREATMENT OF PARSI CULTURE AND TRADITION IN THE WORKS OF ROHINTON MISTRY'],
#        [97101, 'Kumar, Rajesh', 'department of physics',
#         'University of Rajasthan',
#         'Electronic structure studies of some ii vi group and intermetallic compounds in bulk nanophase'],
#        [97508, 'Kumar, Rajesh', 'department of anesthesiology',
#         'Bundelkhand University',
#         'A comparative evaluation of thiopentone sodium and propofol as induction agent for caesarean section'],
#        [99538, 'Kumar, Rajesh', 'department of ancient history',
#         'University of Allahabad', 'ANIMAL HUSBANDARY IN ANCIENT INDIA'],
# ...

# %%
#12274, 8438, 10

# %%
dataset[dataset["advisor_name"].str.contains('Adhya, T. K.')]
# Out:
#         advisorId  researcherId  advId   resId  advisor_name  \
# 2027          865         95328    865   95328  Adhya, T. K.
# 19687        8438        111100   8438  111100  Adhya, T. K.
# 19688        8438        111142   8438  111142  Adhya, T. K.
# 27981       12274        118677  12274  118677  Adhya, T. K.
# 27982       12274        118683  12274  118683  Adhya, T. K.
# 27983       12274        118824  12274  118824  Adhya, T. K.
# 185590      86019        266330  86019  266330  Adhya, T. K.
#
#             researcher_name                       publisher_dept DepartmentId  \
# 2027         Datta, Arindam  department of environmental science         D843
# 19687       Bharati, Kollah                 department of botany        D2461
# 19688   Pattnaik, Puspamala                 department of botany        D2461
# 27981         Das, Subhasis           department of microbiology         D738
# 27982   Bal, Himadri Bhusan           department of microbiology         D738
# ...

# %%
#dataset1[dataset1["advisor_name"].str.contains('Adhya, T. K.')]

# %%
#dataset2[dataset2["advisor_name"].str.contains('Adhya, T. K.')]

# %%
#edges = edges2[["advId", "resId","DepartmentId","instituteId","N_DepartmentId_1"]]

# %%
#edges.to_csv("shodhganga_edges_v5_4_4.csv",index=False)

# %%
#edges.shape
# Out:
# (201477, 5)

# %%
dataset2[dataset2["advId"]==53288]
# Out:
#         advisorId  researcherId  advId   resId  advisor_name  \
# 115028      53288         53307  53288   53307  Guruviah, S.
# 115029      53288        199024  53288  199024  Guruviah, S.
#
#           researcher_name                      publisher_dept DepartmentId  \
# 115028       Selvaraj, M.  department of industrial chemistry        D1888
# 115029  Muthukrishnan, S.  department of industrial chemistry        D1888
#
#        publisher_institution instituteId  ... new_date_awarded  \
# 115028   Alagappa University        I333  ...       1991-07-01
# 115029   Alagappa University        I333  ...       1995-07-01
#
#        dc.date.awarded                                     dc.subject.ddc  \
# 115028             NaN  500::Natural sciences & mathematics|540::Chemi...
# 115029             NaN  500::Natural sciences & mathematics|540::Chemi...
#
#        uniq_ddc_across_dept dc.description.abstract dc.title.alternative  \
# ...

# %%
nodes2[nodes2['names'].str.contains("\|")]
# Out:
#            rid                                              names
# 5            8                       Dominic, V. J.|Dominic, V J.
# 17          28     Kumar, N. Ajith|Ajith Kumar, N.|Ajithkumar, N.
# 24          35                     Vaidya, Vinay G.|Vinay, Vaidya
# 25          36  Acharya, Haridas|Acharya Haridas S.|Acharya, H...
# 27          39                    Urvashi, Rathod|Rathod, Urvashi
# ...        ...                                                ...
# 256635  285417                      Senthilkumar A|Sendhilkumar S
# 256686  285468                    Vijayakumar, P.|Vijayakumar, V.
# 256725  285507                             Kavitha, K.|K, Kavitha
# 256730  285512                    C, Senthilkumar|M, Senthilkumar
# 256794  285577                       Kumari, Anita|Kumari, Anitha
#
# [15059 rows x 2 columns]

# %%
edges2.shape
# Out:
# (201477, 24)

# %%
nodes2.shape
# Out:
# (256842, 2)

# %%
256842-201477
# Out:
# 55365
