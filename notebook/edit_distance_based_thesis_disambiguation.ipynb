# %%
import re
import textdistance
import jellyfish
import itertools
import editdistance
import pandas as pd
from collections import Counter
from cdifflib import CSequenceMatcher
from tqdm import tqdm
import pickle

# %%
chars=[',',";","\.",":","-","_"]

# %%
def rm_splChar(name):
    name = str(name)
    name1 = re.sub(" +","",name)
    regex = "|".join(chars)
    name1 = re.sub(regex,"", name1)
    name2 = re.sub(regex,"", name)
    #val = re.sub('[^A-Za-z]+', '', val)
    return name1, name2

# %%
def char_dist(name1, name2):
    name1=rm_splChar(name1)
    name2=rm_splChar(name2)
    return int(Counter(name1)==Counter(name2))

# %%
def diff_lib(name1, name2):
    name1=name1.lower()
    name2=name2.lower()
    ratio=CSequenceMatcher(lambda x: x == ' ', name1, name2).ratio()
    return ratio

# %%
def jaro_winkler_score(name1, name2):
    jw_score=textdistance.jaro_winkler.normalized_similarity(name1,name2)
    return jw_score

# %%
def levenshtein_score(name1, name2):
    leven_score = textdistance.levenshtein.normalized_similarity(name1,name2)
    return leven_score

# %%
def hamming_similarity(name1, name2):
    h_score=textdistance.hamming.normalized_similarity(name1,name2)
    return h_score

# %%
def jaccard_similarity(name1, name2):
    j_score=textdistance.jaccard.normalized_similarity(name1,name2)
    return j_score

# %%
def damerau_levenshtein_similarity(name1, name2):
    dl_score=textdistance.damerau_levenshtein.normalized_similarity(name1,name2)
    return dl_score

# %%
def sorensen_dice_similarity(name1, name2):
    sd_score=textdistance.sorensen_dice.normalized_similarity(name1,name2)
    return sd_score

# %%
def cosine_similarity(name1, name2):
    c_score=textdistance.jaccard.normalized_similarity(name1,name2)
    return c_score

# %%
def calculate_feats(name1, name2):
    sim_score=[]
    #sim_score.append(char_dist(name1, name2))
    sim_score.append(diff_lib(name1,name2))
    #sim_score.append(jaro_winkler_score(name1, name2))
    sim_score.append(levenshtein_score(name1, name2))
    #sim_score.append(hamming_similarity(name1, name2))
    sim_score.append(jaccard_similarity(name1, name2))
    sim_score.append(cosine_similarity(name1, name2))
    sim_score.append(damerau_levenshtein_similarity(name1, name2))
    sim_score.append(sorensen_dice_similarity(name1, name2))
    return sim_score

# %%
def lcs(name1, name2):
    match = CSequenceMatcher(None, name1, name2).find_longest_match(0, len(name1), 0, len(name2))
    common_subs=name1[match.a: match.a + match.size]
    name1=re.sub(re.escape(common_subs),"",name1)
    name2=re.sub(re.escape(common_subs),"",name2)
    return name1,name2

# %%
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
def load_obj(name):
    with open(name, 'rb') as f:
        return pickle.load(f)

# %%
def Merge(dict1, dict2):
    res = {**dict1, **dict2}
    return res

# %%
thesis1 = load_obj('./index_files4/similar_thesis/similar_thesis_0_100000.pkl')

# %%
thesis2 = load_obj('./index_files4/similar_thesis/similar_thesis_100000_200000.pkl')

# %%
thesis3 = load_obj('./index_files4/similar_thesis/similar_thesis_200000_281425.pkl')

# %%
tmp1 = Merge(thesis1,thesis2)

# %%
final_thesis = Merge(tmp1,thesis3)

# %%
f_final_thesis = [(t[0][0],t[1][0],t[2], final_thesis[t][0],final_thesis[t][1]) for t in final_thesis if t[0][0]!=t[1][0]]

# %%
f_final_thesis
# Out:
# [('T138459',
#   'T2109',
#   0.9527476285584368,
#   'A comparative study of public and private sector in general insurance',
#   'Dynamics of life insurance business: A study of private and public sector in India'),
#  ('T172826',
#   'T195466',
#   0.9554287577373454,
#   'Karyomorphometrical analysis and exploration of major essential oil constituents in zingiberaceae',
#   'Karyomorphometrical analysis and exploration of major chemical constituents in Dioscoreaceae'),
#  ('T155527',
#   'T132833',
#   0.9928626803485257,
#   'Fabrication electrical and structural characterization of metal schottky contacts on n type indium phosphide inp',
#   'Fabrication electrical and structural caracterization of metal schottky contacts on n type indium phosphide inp'),
#  ('T106152',
#   'T73079',
#   0.9163396150386152,
#   'Studies on structural electrical and dielectric properties of pani metal oxide conducting nanopolymer composites',
#   'Studies on structural and electrical properties of poly ethylene oxide nanocomposite electrolytes'),
#  ('T60676',
#   'T134021',
#   0.9706032624920023,
#   'Synthesis characterization and luminescence studies of rare earth and transition metal ions doped silicate nanophosphors',
#   'Luminescence spectroscopic studies of rare earth and transition metal ions doped cdsio3 nanophospher'),
#  ('T176256',
#   'T60676',
#   0.9617155787099596,
#   'Synthesis and characterization of zns nanoparticles doped with transitional metals and rare earth ions for luminescence applications',
#   'Synthesis characterization and luminescence studies of rare earth and transition metal ions doped silicate nanophosphors'),
#  ('T29165',
#   'T101165',
#   0.9808026265705551,
#   'Growth and characterization of certain ternary alkali halides and semi organic nlo materials',
#   'Growth and characterization of certain ternary alkali haldies and semi organic nlo materials'),
#  ('T177536',
#   'T119571',
#   0.9328940536115281,
#   'Rayalseema Mein Urdu Nasar Azadi Ke Baad',
#   'Urdu Afsanon Mein Tanz O Mizah Azadi Ke Baad'),
#  ('T156790',
#   'T157545',
#   0.8888663922399045,
#   'A Comparative Study Of Tamil And Telugu Folkstories Of Chittoor District',
#   'A Comparative Study Of Gandhian Thoughts In Modern Tamil And Telugu Novels'),
#  ('T98562',
#   'T157545',
#   0.8509400931486846,
#   'A Comparative Study Of Feminism In Rajam Krishnans And Volgas Novels',
#   'A Comparative Study Of Gandhian Thoughts In Modern Tamil And Telugu Novels'),
#  ('T155082',
#   'T164387',
#   0.8574728360459695,
#   'Trends In Contemporaty Tamil Social Novels',
#   'Social Justice In Tamil Dalit Novels'),
#  ('T173036',
#   'T155082',
#   0.9022006468716094,
#   'Environment Awareness In Contemporary Social Tamil Novels',
#   'Trends In Contemporaty Tamil Social Novels'),
#  ('T1119',
#   'T174570',
#   0.9737700940040971,
#   'Comparative study on the biochemistry and molecular biology of a thermophilic and alkaliphilic amylase in cereus pterogonus and opuntia vulgaris',
#   'Studies on the biochemistry and molecular biology of a thermophilic xylose isomerase in cereus pterogonus and opuntia vulgaris'),
#  ('T42475',
#   'T174570',
#   0.9715606379088038,
#   'Comparative study on the biochemistry and molecular biology of thermophilic cellulase in opuntia vulgaris and cereus pterogonus',
#   'Studies on the biochemistry and molecular biology of a thermophilic xylose isomerase in cereus pterogonus and opuntia vulgaris'),
#  ('T42475',
#   'T1119',
#   0.981207631598036,
#   'Comparative study on the biochemistry and molecular biology of thermophilic cellulase in opuntia vulgaris and cereus pterogonus',
#   'Comparative study on the biochemistry and molecular biology of a thermophilic and alkaliphilic amylase in cereus pterogonus and opuntia vulgaris'),
#  ('T195672',
#   'T195374',
#   0.9069859190977185,
#   'Studies on phytohormone induced biochemical and histological changes in male albino rat tissues',
#   'Studies on lambda cyhalothrin induced biochemical and histological alterations in Oreochromis mossambicus'),
#  ('T95218',
#   'T22908',
#   0.9704948840777119,
#   'Urdu zaban ki Tarvij aur Tarqqi main National book trust of India ka Hissa',
#   'Urdu Zuban ki Tarvij wa Taraqqi main National Book Trust of India ka Hissa'),
#  ('T26777',
#   'T130455',
#   0.956702612831643,
#   'Investigations on Performace Enhancers for Turning of Hardened Aisi 4340 Steel with Minimal Fluid Application Using Multicoated Carbide',
#   'Investigations on cutting Performance Predication During turning of Hardened AISI 4340 Steel with Mininal Fluid Application Using Multicoated Carbide Inserts'),
#  ('T80671',
#   'T83602',
#   0.9571100036385689,
#   'Investgation of Quantum Confinement Effect in pbse znse multiple Quantum Well Structures Prepared by Thermal Evaporation technique',
#   'Quantum Confinement Effect in cdse Based Multilayer Structures Prepared by Thermal Evaporation method'),
#  ('T50462',
#   'T99598',
#   0.9511774004831126,
#   'A study on fractional transportation problem using fuzzy programming approach',
#   'A Study on multi objective transportation problem by using fuzzy programming technique'),
#  ('T107364',
#   'T15749',
#   0.9648963384041868,
#   'Employee branding in higher educational institutions with special reference to management institutions in Tamilnadu',
#   'Branding in higher educational institutions: with special reference to engineering education in Tamilnadu'),
#  ('T47092',
#   'T158840',
#   0.9768579854024835,
#   'GENE ACTION FOR AGROMORPHOLOGICAL AND QUALITY TRAITS IN LINSEED Linum usitatissimum L',
#   'GENE ACTION FOR AGROMORPHOLOGICAL AND QUALITY TRAITS IN LINSEED'),
#  ('T124706',
#   'T26899',
#   0.9388996475871125,
#   'EFFECT OF INTEGRATED NUTRIENT MANAGEMENT ON PRODUCTIVITY PROFITABILITY AND SEED QUALITY IN OKRA PEA CROPPING SYSTEM',
#   'EFFECT OF LONG TERM INTEGRATED NUTRIENT MANAGEMENT SYSTEM ON SOIL AND CROP PRODUCTIVITY IN RICE WHEAT CROP SEQUENCE'),
#  ('T4865',
#   'T32989',
#   1.0000001429913685,
#   'Toxicity Evaluation and Hypoglycemic Activity Of Indigenous Medicinal Plants Of Gujarat',
#   'Toxicity Evaluation And Hypoglycemic Activity Of Indigenous Medicinal Plants Of Gujarat'),
#  ('T144830',
#   'T60881',
#   0.9733849975556932,
#   'Phytochemical Investigation And Anthelmintic Screening of Stem Bark of Bauhinia variegata Linn And Fruit of Benincasa hispida Thunb',
#   'Phytochemical Investigation Anthelmintic Screening of Stem Bark of Bauhinia variegata Linn Fruit of Benincasa hispida Thunb'),
#  ('T123802',
#   'T25710',
#   0.934361070235617,
#   'Development And Evaluation Of Mucoadhesive Delivery System For Antihypertensive Drug Candesartan By Using Chitosan',
#   'Formulation Development And Evaluation Of Modified Release Multiparticulate Drug Delivery System For Zolpidem Tartarate'),
#  ('T82551',
#   'T91408',
#   0.9999999588854146,
#   'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS Gartn ELAEOCARPACEAE',
#   'THNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE'),
#  ('T98000',
#   'T91408',
#   0.9999999588854146,
#   'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE',
#   'THNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE'),
#  ('T98000',
#   'T82551',
#   0.9999999588854146,
#   'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE',
#   'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS Gartn ELAEOCARPACEAE'),
#  ('T32427',
#   'T119595',
#   0.947860842396443,
#   'Studies in design and development of bioadhesive drug delivery systems',
#   'Formulation and development of Pulsatile drug delivery systems PDDS'),
#  ('T119000',
#   'T120444',
#   0.8846416349565482,
#   'Formulation evaluation and characterization of sustained release pellets',
#   'Studies on design and evaluation of sustained release microparticles'),
#  ('T14001',
#   'T64370',
#   0.9676211299572919,
#   'Formulation and evaluation of periodontal drug delivery system of chlorhexidine for the treatment of gum disease',
#   'Formulation and evaluation of drug delivery systems for the treatment of periodontitis'),
#  ('T142429',
#   'T78791',
#   0.9630358306861955,
#   'Modified release formulation drug delivery system for cardiovascualr drugs',
#   'Modified release drug delivery system for antiepileptic drug'),
#  ('T13039',
#   'T31980',
#   0.8690272583116544,
#   'A study on the personality traits of retail entrepreneurs of Kerala',
#   'A study on the impact of medical tourism on Kerala'),
#  ('T167997',
#   'T142179',
#   0.9478104224438921,
#   'Effect of resistance and plyometric training on selected physical physiological and skill performance variables among female hockey players',
#   'Effect of complex training with core exercise programme on selected bio motor ability physiological and skill related performance variables among football players'),
#  ('T121493',
#   'T116838',
#   0.9558187572583654,
#   'Effect of selected aerobic exercises and yogic practices on physical, physiological and biochemical variables',
#   'Effect of aerobic exercises and yogic practices on selected physiological, haematological and biochemical parameters among the middle aged men'),
#  ('T178811',
#   'T109404',
#   0.8874277637991912,
#   'Oscillatory behavior of third and fourth order difference equations',
#   'Oscillatory behavior of certain classes of difference equations'),
#  ('T188584',
#   'T38165',
#   0.9356397166213691,
#   'Existence results for impulsive differential and fractional differential systems with delay',
#   'Existence and controllability results for impulsive abstract functional differential systems with delay'),
#  ('T125714',
#   'T181043',
#   0.9534285852684705,
#   'Existence and Controllability Results for Impulsive Integrodifferential Systems with Infinite Delay',
#   'Existence and Controllability Results for Impulsive Differential Systems with state Dependent Delay'),
#  ('T85597',
#   'T43613',
#   0.9715200203079165,
#   'Study of Behavioural Shapes of Liquid Molecules and Intermolecular Interactions in Binary Mixtures of Choloroethanes with 1 Alkanols Ultrasonic Approach with the Scaled Particle Theory',
#   'Study of the Behavioral Shapes of Molecules and Intermolecular Interaction in Some Liquid Mixtures in the Light of Scaled Particle Theory and Florys Theory'),
#  ('T51332',
#   'T81337',
#   0.8830185238878707,
#   'Transport and Microwave Properties of Fast Ion Conducting Lithium Borate Glasses',
#   'The Transport and Ultrasonic Properties of Some Borate Glasses'),
#  ('T62804',
#   'T156314',
#   0.9034157887153006,
#   'Study of Electrical Properties of Silver and Oxygen Ion Conducting Silver Borate Glasses',
#   'Study of Electrical Properties and Relaxation Mechanism in Vanadium Lead Borate Glasses'),
#  ('T62804',
#   'T51332',
#   0.8880159933110017,
#   'Study of Electrical Properties of Silver and Oxygen Ion Conducting Silver Borate Glasses',
#   'Transport and Microwave Properties of Fast Ion Conducting Lithium Borate Glasses'),
#  ('T171207',
#   'T49310',
#   0.9369040395828556,
#   'Biodiversity of trees and short term population changes in a tropical evergreen forest in the Anamalais, Western Ghats, India',
#   'Fruiting patterns among canopy trees and fruit use by vertebrates in a wet evergreen forest of the Southern Western Ghats, India'),
#  ('T15970',
#   'T136742',
#   0.877767748714368,
#   'Studies on Architectural Biology of the Fish Channa Orientalis SCH',
#   'Studies on enzymes profiles and kinetics of the Fish Channa Orientalis SCH'),
#  ('T113487',
#   'T6486',
#   0.9470125541254849,
#   'Studies on Cestode Parasites of Fresh Water Fishes and Amphibians of Vidarbha Region of Maharashtra',
#   'Studies on Cestode Parasites of birds and mammals of Vidarbha Region of Maharashtra State'),
#  ('T69796',
#   'T188553',
#   0.9041952962689659,
#   'Some Neuroendocrinological Aspects of Millipede Species of Amravati',
#   'Some Eco Physiological Aspects of Millipede Species in Amravati District'),
#  ('T26152',
#   'T154429',
#   0.9032131047127848,
#   'Studies of some aspects in the slug semperdia maculata with special reference to the ecological parameters',
#   'Studies on some physiological aspects of the fish Channa Orientalis with special reference to Inorganic Pollutants'),
#  ('T46495',
#   'T157330',
#   0.9916515400222001,
#   'Ecological Studies of Chhatri Lake, Amravati with Special Reference to Planktons and Productivity',
#   'Ecological Studies of Chattri Lake Amravati With Special Reference to Planktons and Productivity'),
#  ('T23707',
#   'T191192',
#   0.9559355050653771,
#   'Studies on Some Aspects of Reproductive in Rats Rattus Rufescens',
#   'Studies on Some Aspects of Reproduction in Rat Rattus Rufescens'),
#  ('T197471',
#   'T61897',
#   0.9869690562511403,
#   'Effects of Changed Environment on Physiology and Endocrinology of the Frog Rana Cyanophlyctis',
#   'Effect of Changed Environment Physiology and Endocrinology of the frog Rana Cyanophytics'),
#  ('T197498',
#   'T157330',
#   0.9054648637122891,
#   'Limnological Studies of Amravati University Reservoirs With Reference to Trophic Status and Conservation',
#   'Ecological Studies of Chattri Lake Amravati With Special Reference to Planktons and Productivity'),
#  ('T191985',
#   'T68583',
#   0.8887094154911565,
#   'Studies on the Toxic Potentialities of Certain Heavy Metals in the Fresh Water Fish Labeo Rohita Ham',
#   'Studies on the effect of trace Metals on Osmotic and Ionic Regulation in the Fish Labeo Rohita'),
#  ('T37148',
#   'T201004',
#   0.9564185827498933,
#   'Limnological Studies of Wadali Lake Amravati Maharashtra',
#   'Limnological Studies on Lonar Lake Maharashtra'),
#  ('T50448',
#   'T91477',
#   0.9577313897982602,
#   'LEADERSHIP STYLES IN INDIAN OIL CORPORATION LIMITED WITH SPECIAL REFERENCE TO MATHURA REFINERY',
#   'PERFORMANCE APPRAISAL OF EMPLOYEES IN INDIAN OIL CORPORATION LIMITED WITH SPECIAL REFERENCE TO PANIPAT REFINERY'),
#  ('T42449',
#   'T170278',
#   0.9964306260052318,
#   'Changing scenario of leadership in insurance sector a critical appraisal of life insurance Corporation of India and Bajaj Allianz',
#   'Changing scenario of leadership in insurance sector: a critical appraisal of Life Insurance Corporation of India and Bajaj Allianz'),
#  ('T102597',
#   'T95035',
#   0.9438021879689827,
#   'A STUDY OF HUMAN RESOURCE AUDIT IN BANKS WITH REFERENCE TO STATE BANK OF INDIA AND BANK OF BARODA',
#   'HUMAN RESOURCE DEVELOPMENT PRACTICES IN INDIAN BANKING SECTOR A COMPARATIVE STUDY OF HDFC BANK AND STATE BANK OF INDIA'),
#  ('T68665',
#   'T128696',
#   1.0000000596887995,
#   'simulation of energy and water exchange processes at vegetation atmosphere interface in rice ecosystem',
#   'Simulation of energy and water exchange processes at vegetation atmosphere interface in rice ecosystem'),
#  ('T149608',
#   'T181467',
#   1.0000000119650503,
#   'studies on distribution of heavy metals in water sediment and biota in coastal areas of Sunderbans and its potential risk in the environment',
#   'Studies on distribution of heavy metals in water sediment and biota in coastal areas of Sunderbans and its potential risk in the environment'),
#  ('T15114',
#   'T54922',
#   0.9917173174552896,
#   'Modes of production, distribution and reception of writings in womenâ\x80\x99s magazines: a study in critical discourse analysis',
#   "Modes of production, distribution and reception of writings in women's Magazines: a study in critical discourse analysis"),
#  ('T188093',
#   'T184226',
#   0.9454821153558083,
#   'Demographic transition and its implications on the ageing population in Kerala',
#   'Demographic transition in Kerala and its impact on economic development'),
#  ('T9929',
#   'T37214',
#   0.8548220855240164,
#   'A study of untouchables in Kerala before independence with special reference to Gandhi',
#   'Gender dimensions of employment in Kerala: A study with reference to ICT'),
#  ('T9929',
#   'T111874',
#   0.8558064653586813,
#   'A study of untouchables in Kerala before independence with special reference to Gandhi',
#   'Foreign trade in natural rubber: A case study with reference to Kerala'),
#  ('T57271',
#   'T133105',
#   0.945737298150287,
#   'Demographic dynamics and sustainable development: a study with special reference to Kerala',
#   'Appropriate technology- dynamics and relevance: a study with special reference to water resource management systems in Kerala'),
#  ('T78957',
#   'T111322',
#   0.9783797010030137,
#   'Genetic Polymorphism of Drug Metabolizing Genes and Genetic Damage in Coronary Artery Disease Patients',
#   'Genetic Polymorphism and Genetic Damage in Coronary Artery Disease Patients'),
#  ('T116476',
#   'T78957',
#   0.9684134616803898,
#   'Genetic Polymorphism of Drug Metabolising Genes and Genetic Damage in Hypertensive Patients',
#   'Genetic Polymorphism of Drug Metabolizing Genes and Genetic Damage in Coronary Artery Disease Patients'),
#  ('T162316',
#   'T9834',
#   0.9299793407002291,
#   'Susceptible Genotypes and Genomic Instability in Patients with Renal Disease',
#   'Susceptible Genotypes and Genomic Damage in Chronic Obstructive Pulmonary Disease'),
#  ('T62639',
#   'T64082',
#   0.9330592931217697,
#   'Assessment of Chromosomal Instability and TP53 Polymorphisms in Esophageal Cancer Patients',
#   'HIF 1 TP53 Polymorphisms and Chromosomal Instability in Breast Cancer Patients'),
#  ('T99459',
#   'T55526',
#   0.8900242232727562,
#   'Design and Synthesis of Pentaquinone Derivatives',
#   'Design and Synthesis of Indole Scaffolds'),
#  ('T176366',
#   'T78957',
#   0.9419427065134633,
#   'Polymorphism of Some Metabolizing Genes and Genetic Damage in Patients on Antihypertensive Therapy',
#   'Genetic Polymorphism of Drug Metabolizing Genes and Genetic Damage in Coronary Artery Disease Patients'),
#  ('T176366',
#   'T116476',
#   0.9570883111843935,
#   'Polymorphism of Some Metabolizing Genes and Genetic Damage in Patients on Antihypertensive Therapy',
#   'Genetic Polymorphism of Drug Metabolising Genes and Genetic Damage in Hypertensive Patients'),
#  ('T141015',
#   'T111322',
#   0.9622458836413839,
#   'Genetic Polymorphism in Patients of Type 2 Diabetes and Coronary Artery Disease',
#   'Genetic Polymorphism and Genetic Damage in Coronary Artery Disease Patients'),
#  ('T141015',
#   'T78957',
#   0.944681712467827,
#   'Genetic Polymorphism in Patients of Type 2 Diabetes and Coronary Artery Disease',
#   'Genetic Polymorphism of Drug Metabolizing Genes and Genetic Damage in Coronary Artery Disease Patients'),
#  ('T124472',
#   'T102298',
#   0.9530259548854346,
#   'Production, purification and industrial applications of cellulase from aspergillus sp. AMA',
#   'Production, purification and industrial applications of Cellulase from Aspergillus S. AMA'),
#  ('T89509',
#   'T126037',
#   0.996476095119744,
#   'Production Purification and Characterization of Broad Spectrum Antimicrobial Compound from Streptomyces sp and Improvement of the Strain',
#   'Production Purification and Characterization of a Broad Spectrum Antimicrobial Compound from Streptomyces sp and Improvement of the Strain'),
#  ('T130962',
#   'T28711',
#   0.97075068610803,
#   'Isolation Synthesis of Bioactive Molecules and Development of New Synthetic Methodologies',
#   'Synthesis of Bioactive Molecules and Development of Novel Synthetic Methodologies'),
#  ('T119982',
#   'T110874',
#   0.9591220916500945,
#   'A COMPREHENSIVE STUDY OF AGGREGATE ASSEMBLIES OF VARIOUS SURFACE ACTIVE AGENTS IN PRESENCE OF ADDITIVES',
#   'PHYSICOCHEMICAL INVESTIGATIONS OF SELF ASSEMBLIES OF SURFACE ACTIVE AGENTS IN PRESENCE OF ADDITIVES'),
#  ('T125246',
#   'T196293',
#   0.902405582885171,
#   'STUDY ON INTERACTIONS OF SACCHARIDES IN AQUEOUS PHOSPHATE BASED INORGANIC SALT SOLUTIONS',
#   'A STUDY ON SOLVATION BEHAVIOUR OF SACCHARIDES IN AQUEOUS SOLUTIONS OF VARIOUS ADDITIVES'),
#  ('T73786',
#   'T181859',
#   0.9231495072027021,
#   'Studies in the Synthesis and Applications of Fluorescent Receptors as Molecular Recognition Reagents',
#   'Studies in the Synthesis and Evaluation of Fluorescent Probes as Chemosensors and Imaging Agents'),
#  ('T143126',
#   'T86187',
#   0.9582315130804936,
#   'Studies in the Synthesis and Evaluation of Photophysical Properties of Pentacenequinone Based Materials',
#   'Studies in the Synthesis and Photophysical Behaviour of Discoidal Materials'),
#  ('T169026',
#   'T28711',
#   0.9449232361363975,
#   'Synthesis of Biologically Active Compounds and Development of New Synthetic Methodologies',
#   'Synthesis of Bioactive Molecules and Development of Novel Synthetic Methodologies'),
#  ('T169026',
#   'T130962',
#   0.9601921292587101,
#   'Synthesis of Biologically Active Compounds and Development of New Synthetic Methodologies',
#   'Isolation Synthesis of Bioactive Molecules and Development of New Synthetic Methodologies'),
#  ('T19560',
#   'T180864',
#   0.9508189618384387,
#   'A Study of Functional Properties of Ion Sensors for Selective Cation Anion Recognition',
#   'A Study of Functional Properties of Electrochemical Sensors for Selective Recognition of Some Cations'),
#  ('T51128',
#   'T111798',
#   0.8679989354029193,
#   'SYNTHESIS AND EVALUATION OF C 3 FUNCTIONALIZED LACTAM AND 7 CHLOROQUINOLINE BASED MOLECULAR CONJUGATES',
#   'SYNTHESIS AND BIO EVALUATION OF FUNCTIONALLY ENRICHED ISATIN AND LACTAM BASED MOLECULAR CONJUGATES'),
#  ('T55701',
#   'T131939',
#   0.9371451101155441,
#   'TECHNICAL EFFICIENCY AND TOTAL FACTOR PRODUCTIVITY GROWTH OF REGIONAL RURAL BANKS IN INDIA',
#   'TECHNICAL EFFICIENCY CAPACITY UTILIZATION AND TOTAL FACTOR PRODUCTIVITY GROWTH IN INDIAN SUGAR INDUSTRY'),
#  ('T161846',
#   'T55701',
#   0.9243356740410263,
#   'GROWTH AND PRODUCTIVITY PERFORMANCE OF CO OPERATIVE BANKS IN INDIA',
#   'TECHNICAL EFFICIENCY AND TOTAL FACTOR PRODUCTIVITY GROWTH OF REGIONAL RURAL BANKS IN INDIA'),
#  ('T198454',
#   'T52260',
#   0.9007605338513249,
#   'Consumer protection with special reference to the role of women in Kerala',
#   'Social contributions of the Catholic Church in Kerala with special reference to Higher Education'),
#  ('T198454',
#   'T9929',
#   0.8814385005456542,
#   'Consumer protection with special reference to the role of women in Kerala',
#   'A study of untouchables in Kerala before independence with special reference to Gandhi'),
#  ('T14313',
#   'T96527',
#   0.8649114014918614,
#   'A study of the linkages of electrical machinery industry in Kerala',
#   'A study of individual investors in the capital market in Kerala'),
#  ('T13824',
#   'T111874',
#   0.8584450353005914,
#   'Rural transformation in Kerala a case study with reference to three panchayats',
#   'Foreign trade in natural rubber: A case study with reference to Kerala'),
#  ('T13824',
#   'T184198',
#   0.8982515003634735,
#   'Rural transformation in Kerala a case study with reference to three panchayats',
#   'Alternative dispute resolution in Kerala a study with particular reference to Kottayam district'),
#  ('T102164',
#   'T45748',
#   0.8943918516833771,
#   'Tile industry in Kerala: economics, problems and prospects',
#   'Professional social work education in Kerala: problems and prospects'),
#  ('T143500',
#   'T52260',
#   0.9281018466119563,
#   'Economics of Human Resource Planning with special reference to Higher Education in Kerala',
#   'Social contributions of the Catholic Church in Kerala with special reference to Higher Education'),
#  ('T143500',
#   'T9929',
#   0.8738069206621535,
#   'Economics of Human Resource Planning with special reference to Higher Education in Kerala',
#   'A study of untouchables in Kerala before independence with special reference to Gandhi'),
#  ('T143500',
#   'T198454',
#   0.908197127625559,
#   'Economics of Human Resource Planning with special reference to Higher Education in Kerala',
#   'Consumer protection with special reference to the role of women in Kerala'),
#  ('T183448',
#   'T9929',
#   0.854627840805136,
#   'A study of industrial co operatives in Kerala with special reference to modern small scale sector',
#   'A study of untouchables in Kerala before independence with special reference to Gandhi'),
#  ('T61758',
#   'T111874',
#   0.8643319009645936,
#   'Rural transformation in Kerala - a case study with reference to three panchayats',
#   'Foreign trade in natural rubber: A case study with reference to Kerala'),
#  ('T61758',
#   'T184198',
#   0.8955672006515555,
#   'Rural transformation in Kerala - a case study with reference to three panchayats',
#   'Alternative dispute resolution in Kerala a study with particular reference to Kottayam district'),
#  ('T61758',
#   'T13824',
#   0.9897082967447783,
#   'Rural transformation in Kerala - a case study with reference to three panchayats',
#   'Rural transformation in Kerala a case study with reference to three panchayats'),
#  ('T13594',
#   'T172669',
#   0.9553466723916152,
#   'Nagarjun ke katha sahitya me hasiye ka samaj',
#   'Shivprasad singh ke katha sahitya me swantabyontar bhartiya samaj ka bimb'),
#  ('T152125',
#   'T114006',
#   0.9584269580957252,
#   'Growth and morphological studies of carbon nano structures deposited by radio frequency plasma enhanced chemical vapor deposition and a study on magnetic properties',
#   'Growth and morphological studies of hydrogenated diamond like carbon films deposited by radio frequency plasma enhanced chemical vapour deposition'),
#  ('T192547',
#   'T61623',
#   0.9248509870061743,
#   'Crystal structure determination of some organic compounds of medicinal importance',
#   'Crystal structure and conformational studies of some biologically important organic compounds'),
#  ('T23741',
#   'T61623',
#   0.9551015283130918,
#   'Crystal structure conformational study and biological activities of some new compounds',
#   'Crystal structure and conformational studies of some biologically important organic compounds'),
#  ('T154039',
#   'T109246',
#   0.9888943789986304,
#   'Some Theoretical Investigations on Magneto Hydro Dynamic Mhd and Non Magneto Hydro Dynamic Problems on Squeeze Film Lubrication',
#   'Some Theoretical Investigations on Magneto Hydro Dynamic MHD and Non Magneto Hydro Dynamic Problems on Squeeze Film Lubrication'),
#  ('T28208',
#   'T141855',
#   0.9366581010385496,
#   'Growth and characterization of some nonlinear optical crystals of amino acid complexes',
#   'Growth and characterization of some organic and inorganic nonlinear optical crystals'),
#  ('T159446',
#   'T94293',
#   0.9166053259409022,
#   'Modelling and analysis of discrete lifetime data',
#   'Modeling and analysis of competing risks data'),
#  ('T120995',
#   'T159446',
#   0.8742943364957687,
#   'Modelling and analysis of some time series',
#   'Modelling and analysis of discrete lifetime data'),
#  ('T65841',
#   'T120995',
#   0.9512032929286232,
#   'Modeling and analysis of some heavy tailed time series',
#   'Modelling and analysis of some time series'),
#  ('T133212',
#   'T159446',
#   0.9223520951447334,
#   'Modelling and analysis of Bivariate lifetime data using reversed hazard rates',
#   'Modelling and analysis of discrete lifetime data'),
#  ('T180430',
#   'T16659',
#   0.9358495780428842,
#   'Management of State with Special Reference to Land Revenue Management in Maharashtra State',
#   'Enquiry into Management of Judicature with Special Reference to Lower Courts of Maharashtra State Thesis'),
#  ('T172808',
#   'T57211',
#   0.9546858452957994,
#   'Comparative Study of Personnel Relations in Nationalized Banks and Cooperative Banks with Special Reference to Amravati City',
#   'A Study of Personnel Relations in Public Sector Banks with Special Reference to Amravati District'),
#  ('T65221',
#   'T152506',
#   0.9041760277211445,
#   'On security and Opportunistic Routing in Wireless Sensor Networks',
#   'On Security and Performance Enhancement in Wireless MESH Networks'),
#  ('T45744',
#   'T94049',
#   0.8566155720255928,
#   'Total quality management in Indian healthcare industry A study with special reference to Manipur',
#   'Supply chain management in Indian textile industry with special reference to Bhiwani textile Mills Bhiwani'),
#  ('T179281',
#   'T168142',
#   0.9842624639724274,
#   'Studies in quantum field theory at finite temperature',
#   'Studies in finite temperature quantum field theory'),
#  ('T179281',
#   'T176029',
#   0.9487237415115433,
#   'Studies in quantum field theory at finite temperature',
#   'Studies in field theories at finite temperature and finite bosonic density'),
#  ('T16215',
#   'T118635',
#   0.9362896822936647,
#   'Photoacoustic investigation of the optical and thermal properties of selected amorphous Chalcogenide semiconductors',
#   'Optical and thermal properties of selected ternary amorphous semiconductors'),
#  ('T110635',
#   'T44336',
#   0.9552224190002936,
#   'Electrical properties and phase transitions in some ammonium containing ferroelectrics',
#   'Electrical and photoacoustic studies on phase transitions in certain ammonium containing crystals'),
#  ('T91461',
#   'T105505',
#   0.9490674371470594,
#   'Corrugated flange technique for beam shaping of sectoral electromagnetic horn antennas',
#   'Beam shaping of sectoral electromagnetic horn antennas using corner reflector technique'),
#  ('T71196',
#   'T57288',
#   0.9484994024206737,
#   'Photothermal investigations on certain plasma polymerized thin films and near IR overtone studies of some organic molecules',
#   'Photohermal investigations on certain organic molecules and their plasma polymerised thin films'),
#  ('T146148',
#   'T85617',
#   0.9336575064016677,
#   'Non-destructive evaluation of ion-implanted semiconductor thin films using Photothermal Deflection Spectroscopy',
#   'Photothermal beam deflection for non-destructive evaluation of semiconductor thin films'),
#  ('T102920',
#   'T5226',
#   0.8835532164706292,
#   'Defect analysis of semiconductor thin films for photovoltaic applications using photo-luminescence and photo-conductivity',
#   'Thermally stimulated current studies of compound semiconductor thin films used for photovoltaic applications'),
#  ('T14371',
#   'T167816',
#   0.9346138317972605,
#   'An investigation on the preparation and properties of reactively evaporated SnSe and Bi2Se3 thin films and Bismuth Selenide Crystals',
#   'An investigation on the preparation and properties of certain semiconducting sulphide thin films'),
#  ('T97938',
#   'T168260',
#   0.9829182561918947,
#   'Studies on laser induced optogalvanic effect in certain gas discharges (1994-01-01)',
#   'Studies on laser induced optogalvanic effect in certain gas discharges (1994-08-20)'),
#  ('T52413',
#   'T143079',
#   0.9915756919039597,
#   'Studies on electroluminescence using powder and thin film devices (1983-08-01)',
#   'Studies on electroluminescence using powder and thin film devices (1984-03-27)'),
#  ('T153513',
#   'T148739',
#   0.9195569896445313,
#   'Growth and characterisation of certain organic crystals',
#   'Growth and characterisation of tin dichalcogenide crystals'),
#  ('T37802',
#   'T65912',
#   0.9080634922971097,
#   'Studies on quasinormal modes and Late-time tails in black hole spacetimes',
#   'Studies on scattering and quasi-normal modes in black hole space-times'),
#  ('T37802',
#   'T141082',
#   0.8694283999127693,
#   'Studies on quasinormal modes and Late-time tails in black hole spacetimes',
#   'Studies on thermodynamics and quasinormal modes of higher dimensional black holes'),
#  ('T37802',
#   'T31558',
#   0.8869574312999053,
#   'Studies on quasinormal modes and Late-time tails in black hole spacetimes',
#   'Studies on quasinormal modes and latetime talis in black hole spacetimes'),
#  ('T63636',
#   'T69966',
#   0.9720066109365818,
#   'Pesticidal action of certain plant extracts against mosquito vectors culicidae diptera',
#   'Pesticidal action of certain plant extracts against mosquito vectors'),
#  ('T15908',
#   'T115831',
#   0.9432534548436866,
#   'Synthesis characterisation and biological evaluation of some novel compounds containing pyrimidine nucleus',
#   'Design synthesis and biological evaluation of some novel heterocyclic compounds'),
#  ('T38608',
#   'T115831',
#   0.941157241930318,
#   'Synthesis structural and biological evaluation of some novel imidazole derivatives',
#   'Design synthesis and biological evaluation of some novel heterocyclic compounds'),
#  ('T38608',
#   'T77619',
#   0.9156703644116301,
#   'Synthesis structural and biological evaluation of some novel imidazole derivatives',
#   'Synthesis of Fused dihydropyridine derivatives and evaluation of their biological activity'),
#  ('T38608',
#   'T15908',
#   0.9355703645820544,
#   'Synthesis structural and biological evaluation of some novel imidazole derivatives',
#   'Synthesis characterisation and biological evaluation of some novel compounds containing pyrimidine nucleus'),
#  ('T119077',
#   'T115831',
#   0.9153697071071646,
#   'Heterocyclic chemistry synthesis and biological evaluation of some azole derivatives',
#   'Design synthesis and biological evaluation of some novel heterocyclic compounds'),
#  ('T119077',
#   'T38608',
#   0.9341362442688795,
#   'Heterocyclic chemistry synthesis and biological evaluation of some azole derivatives',
#   'Synthesis structural and biological evaluation of some novel imidazole derivatives'),
#  ('T183870',
#   'T47662',
#   0.8833668619088235,
#   'A study on the organisational climate of Dr Reddys laboratories Hyderabad',
#   'A study on organisational climate in the hospital set up'),
#  ('T165861',
#   'T138459',
#   0.9098438798492596,
#   'Relative financial performance of public and private sector banks in India',
#   'A comparative study of public and private sector in general insurance'),
#  ('T3991',
#   'T165861',
#   0.9397326198847363,
#   'Operational efficiency of selected public sector banks in India',
#   'Relative financial performance of public and private sector banks in India'),
#  ('T24567',
#   'T96527',
#   0.9250200785665352,
#   'A study of determinants of investors behavior in Indian stock market',
#   'A study of individual investors in the capital market in Kerala'),
#  ('T88736',
#   'T34971',
#   0.922121470433991,
#   'A Study of Common Fixed point theorems in metric spaces',
#   'Fixed point theorems in metric spaces'),
#  ('T114782',
#   'T34971',
#   0.9615863689590792,
#   'Related Fixed point theorems in 2 metric spaces',
#   'Fixed point theorems in metric spaces'),
#  ('T114782',
#   'T88736',
#   0.926255046540295,
#   'Related Fixed point theorems in 2 metric spaces',
#   'A Study of Common Fixed point theorems in metric spaces'),
#  ('T85817',
#   'T139805',
#   0.9589145962624726,
#   'Two dimension thermal effect on vibration of visco elastics square plate with varying thickness',
#   'Free vibration of visco elastic square plate of variable thickness with thermal effect'),
#  ('T167444',
#   'T70850',
#   0.9127566270803951,
#   'A study of some sequencing models',
#   'A study on some sequencing problems'),
#  ('T82212',
#   'T32977',
#   0.910782020393174,
#   'Existence of fixed points and their applications in certain spaces',
#   'Study of fixed point theorems in Fuzzy matric spaces and their applications'),
#  ('T82212',
#   'T151430',
#   0.8908251426927755,
#   'Existence of fixed points and their applications in certain spaces',
#   'Existence of fixed points for self maps in menger and fuzzy metric spaces'),
#  ('T88564',
#   'T161654',
#   0.9834136149276229,
#   'On some advanced sequencing models and related problems (2017-01-01)',
#   'On some advanced sequencing models and related problems (2012-01-04)'),
#  ('T109823',
#   'T75226',
#   0.9217868011071189,
#   'Characterization of generalized continuity in topological spaces',
#   'Characterization of generalized convergence in some spaces'),
#  ('T173405',
#   'T48818',
#   0.910294750432171,
#   'On some special flow shop scheduling models',
#   'On some performance measures in flow shop scheduling'),
#  ('T99848',
#   'T94584',
#   0.8897942155094494,
#   'Mathematical analysis of queue models under stochastic and fuzzy environment',
#   'Advance study of queue and scheduling models under fuzzy system'),
#  ('T145230',
#   'T38608',
#   0.8848901674384004,
#   'Synthesis and characterization of some novel 1 3 4 oxadiazole derivatives and their biological evaluation',
#   'Synthesis structural and biological evaluation of some novel imidazole derivatives'),
#  ('T21120',
#   'T15908',
#   0.9070224958572418,
#   'Synthesis Characterization computational study and biological evaluation of some novel Pyridazinone derivatives',
#   'Synthesis characterisation and biological evaluation of some novel compounds containing pyrimidine nucleus'),
#  ('T21120',
#   'T38608',
#   0.9387095533257982,
#   'Synthesis Characterization computational study and biological evaluation of some novel Pyridazinone derivatives',
#   'Synthesis structural and biological evaluation of some novel imidazole derivatives'),
#  ('T21120',
#   'T145230',
#   0.9053892253781918,
#   'Synthesis Characterization computational study and biological evaluation of some novel Pyridazinone derivatives',
#   'Synthesis and characterization of some novel 1 3 4 oxadiazole derivatives and their biological evaluation'),
#  ('T33849',
#   'T15908',
#   0.9336048870705013,
#   'Synthesis and Biological evaluation of some novel Nitrogen containing small Heterocyclic derivatives',
#   'Synthesis characterisation and biological evaluation of some novel compounds containing pyrimidine nucleus'),
#  ('T33849',
#   'T38608',
#   0.9390013700297898,
#   'Synthesis and Biological evaluation of some novel Nitrogen containing small Heterocyclic derivatives',
#   'Synthesis structural and biological evaluation of some novel imidazole derivatives'),
#  ('T33849',
#   'T21120',
#   0.9235793038336562,
#   'Synthesis and Biological evaluation of some novel Nitrogen containing small Heterocyclic derivatives',
#   'Synthesis Characterization computational study and biological evaluation of some novel Pyridazinone derivatives'),
#  ('T62866',
#   'T15908',
#   0.9089902836142817,
#   'Synthesis Characterization biological evaluation and computational studies of some novel thiadiazole derivatives',
#   'Synthesis characterisation and biological evaluation of some novel compounds containing pyrimidine nucleus'),
#  ('T62866',
#   'T38608',
#   0.9404910808342066,
#   'Synthesis Characterization biological evaluation and computational studies of some novel thiadiazole derivatives',
#   'Synthesis structural and biological evaluation of some novel imidazole derivatives'),
#  ('T62866',
#   'T145230',
#   0.9028910257087327,
#   'Synthesis Characterization biological evaluation and computational studies of some novel thiadiazole derivatives',
#   'Synthesis and characterization of some novel 1 3 4 oxadiazole derivatives and their biological evaluation'),
#  ('T62866',
#   'T21120',
#   0.9974560920762214,
#   'Synthesis Characterization biological evaluation and computational studies of some novel thiadiazole derivatives',
#   'Synthesis Characterization computational study and biological evaluation of some novel Pyridazinone derivatives'),
#  ('T62866',
#   'T33849',
#   0.9224327164683909,
#   'Synthesis Characterization biological evaluation and computational studies of some novel thiadiazole derivatives',
#   'Synthesis and Biological evaluation of some novel Nitrogen containing small Heterocyclic derivatives'),
#  ('T181139',
#   'T115831',
#   0.9155517681238332,
#   'Design synthesis molecular modelling and biological evaluation of some Imidazole Derivatives',
#   'Design synthesis and biological evaluation of some novel heterocyclic compounds'),
#  ('T181139',
#   'T119077',
#   0.9529767671134037,
#   'Design synthesis molecular modelling and biological evaluation of some Imidazole Derivatives',
#   'Heterocyclic chemistry synthesis and biological evaluation of some azole derivatives'),
#  ('T105732',
#   'T45490',
#   0.855210544964023,
#   'Phytochemical and pharmacological studies on bark extracts of selected medicinal plants',
#   'Phytochemical and pharmacological evaluation of Some selected plants of himalaya region'),
#  ('T119301',
#   'T64370',
#   0.9256148226038113,
#   'Ormulation and evaluation of novel drug delivery systems for bioavailability enhancement',
#   'Formulation and evaluation of drug delivery systems for the treatment of periodontitis'),
#  ('T132111',
#   'T14001',
#   0.9192097239739222,
#   'Development and evaluation of colon targeted drug delivery system for the prevention treatment of local pathologies',
#   'Formulation and evaluation of periodontal drug delivery system of chlorhexidine for the treatment of gum disease'),
#  ('T44148',
#   'T170523',
#   0.9104001136074626,
#   'Inauthentic involvement in selected novels of R K Narayan',
#   'Narratology in the novels of R K Narayan'),
#  ('T162114',
#   'T157692',
#   0.999093976002518,
#   'A Study on Service Quality and Customer Satisfaction in Paid Direct To Home Service Providers in Himachal Pradesh (2015-09-12)',
#   'A Study on Service Quality and Customer Satisfaction in Paid Direct To Home Service Providers in Himachal Pradesh (2015-09-19)'),
#  ('T70980',
#   'T71915',
#   0.8893550503069065,
#   'Studies towards the total synthesis of balanol and its analogues',
#   'Studies towards the total synthesis of some piperidine alkaloids'),
#  ('T31028',
#   'T169806',
#   0.9485666945135502,
#   'Design and synthesis of various supported reusable catalysts and studies of their applications',
#   'Development of some solid supported catalysts and their applications in various organic transformations'),
#  ('T64525',
#   'T22916',
#   0.9752027589062497,
#   'Synthesis of heterocyclic compounds (2002-01-01)',
#   'Synthesis of heterocyclic compounds (2014-01-01)'),
#  ('T108544',
#   'T169806',
#   0.9245808277130856,
#   'Development of some new immobilized catalysts and their applications towards various catalytic reactions',
#   'Development of some solid supported catalysts and their applications in various organic transformations'),
#  ('T97732',
#   'T71915',
#   0.8546552625401889,
#   'Studies directed towards the total synthesis of bryostatin',
#   'Studies towards the total synthesis of some piperidine alkaloids'),
#  ('T97732',
#   'T70980',
#   0.9433001548947008,
#   'Studies directed towards the total synthesis of bryostatin',
#   'Studies towards the total synthesis of balanol and its analogues'),
#  ('T57657',
#   'T22916',
#   0.9725686883345425,
#   'Synthesis of heterocyclic compounds (1999-01-01)',
#   'Synthesis of heterocyclic compounds (2014-01-01)'),
#  ('T57657',
#   'T64525',
#   0.9986994797414837,
#   'Synthesis of heterocyclic compounds (1999-01-01)',
#   'Synthesis of heterocyclic compounds (2002-01-01)'),
#  ('T134412',
#   'T22916',
#   0.9769048746957539,
#   'Synthesis of heterocyclic compounds (2005-01-01)',
#   'Synthesis of heterocyclic compounds (2014-01-01)'),
#  ('T134412',
#   'T64525',
#   0.9984012748009803,
#   'Synthesis of heterocyclic compounds (2005-01-01)',
#   'Synthesis of heterocyclic compounds (2002-01-01)'),
#  ('T134412',
#   'T57657',
#   0.9957856340454551,
#   'Synthesis of heterocyclic compounds (2005-01-01)',
#   'Synthesis of heterocyclic compounds (1999-01-01)'),
#  ('T196134',
#   'T49171',
#   0.9316658867318774,
#   'Mechanistic studies on the mixed chelate complexes of cobalt III',
#   'Reaction mechanisms of mixed chelate complexes of cobalt III'),
#  ('T144353',
#   'T27979',
#   0.8968543323525101,
#   'Synthesis of heterocycles derived from 3 hydroxythiochromen 4 one',
#   'Synthesis of heterocycles derived from 4 hydroxy 6 methyl 2 pyrone'),
#  ('T68322',
#   'T57657',
#   0.9576517105565424,
#   'Synthesis of heterocyclic compounds and reaction mechanism (1999-01-01)',
#   'Synthesis of heterocyclic compounds (1999-01-01)'),
#  ('T39722',
#   'T68322',
#   0.962004410150777,
#   'Synthesis of heterocycles and reaction mechanism (2005-01-01)',
#   'Synthesis of heterocyclic compounds and reaction mechanism (1999-01-01)'),
#  ('T144825',
#   'T68322',
#   0.9568244431643378,
#   'Synthesis of heterocycles and reaction mechanism (2008-01-01)',
#   'Synthesis of heterocyclic compounds and reaction mechanism (1999-01-01)'),
#  ('T144825',
#   'T39722',
#   0.9977171811923801,
#   'Synthesis of heterocycles and reaction mechanism (2008-01-01)',
#   'Synthesis of heterocycles and reaction mechanism (2005-01-01)'),
#  ('T19816',
#   'T22916',
#   0.9715743025285503,
#   'Synthesis of heterocyclic compounds (1997-01-01)',
#   'Synthesis of heterocyclic compounds (2014-01-01)'),
#  ('T19816',
#   'T64525',
#   0.9976475604128102,
#   'Synthesis of heterocyclic compounds (1997-01-01)',
#   'Synthesis of heterocyclic compounds (2002-01-01)'),
#  ('T19816',
#   'T57657',
#   0.9994472960347159,
#   'Synthesis of heterocyclic compounds (1997-01-01)',
#   'Synthesis of heterocyclic compounds (1999-01-01)'),
#  ('T19816',
#   'T134412',
#   0.9941737842716192,
#   'Synthesis of heterocyclic compounds (1997-01-01)',
#   'Synthesis of heterocyclic compounds (2005-01-01)'),
#  ('T107157',
#   'T135230',
#   0.9411278495021527,
#   'Chemical investigation on plant products',
#   'Chemical investigation on natural products'),
#  ('T107157',
#   'T92281',
#   0.9547670167494626,
#   'Chemical investigation on plant products',
#   'Investigations on plant products'),
#  ('T169363',
#   'T165192',
#   0.9454781903736987,
#   'Synthesis of heterocyclic compounds by metal mediated cyclization',
#   'Synthesis of potentially bioactive heterocycles by metal mediated cyclization'),
#  ('T169363',
#   'T27103',
#   0.9116214378576606,
#   'Synthesis of heterocyclic compounds by metal mediated cyclization',
#   'Synthesis of heterocyclic compounds by ring closing metathesis'),
#  ('T144258',
#   'T192403',
#   0.9958718859334517,
#   'Synthesis of heterocycles (2006-01-01)',
#   'Synthesis of heterocycles (2001-01-01)'),
#  ('T106739',
#   'T22916',
#   0.9828557602386992,
#   'Synthesis of heterocyclic compounds (2010-01-01)',
#   'Synthesis of heterocyclic compounds (2014-01-01)'),
#  ('T106739',
#   'T64525',
#   0.9891283478716827,
#   'Synthesis of heterocyclic compounds (2010-01-01)',
#   'Synthesis of heterocyclic compounds (2002-01-01)'),
#  ('T106739',
#   'T57657',
#   0.9854266438687569,
#   'Synthesis of heterocyclic compounds (2010-01-01)',
#   'Synthesis of heterocyclic compounds (1999-01-01)'),
#  ('T106739',
#   'T134412',
#   0.9931650662524465,
#   'Synthesis of heterocyclic compounds (2010-01-01)',
#   'Synthesis of heterocyclic compounds (2005-01-01)'),
#  ('T106739',
#   'T19816',
#   0.9835738608436407,
#   'Synthesis of heterocyclic compounds (2010-01-01)',
#   'Synthesis of heterocyclic compounds (1997-01-01)'),
#  ('T95399',
#   'T39722',
#   0.9367631561489972,
#   'Synthesis of oxygen and nitrogen heterocycles (2010-01-01)',
#   'Synthesis of heterocycles and reaction mechanism (2005-01-01)'),
#  ('T95399',
#   'T144825',
#   0.9386056067915458,
#   'Synthesis of oxygen and nitrogen heterocycles (2010-01-01)',
#   'Synthesis of heterocycles and reaction mechanism (2008-01-01)'),
#  ('T29891',
#   'T187936',
#   0.9378582624915831,
#   'Synthesis of oxygen and nitrogen heterocycles with potential bioactivity',
#   'Synthesis of oxygen nitrogen and sulphur heterocycles'),
#  ('T30011',
#   'T64525',
#   0.9578988600924981,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2002-01-01)',
#   'Synthesis of heterocyclic compounds (2002-01-01)'),
#  ('T30011',
#   'T68322',
#   0.9990868772027723,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2002-01-01)',
#   'Synthesis of heterocyclic compounds and reaction mechanism (1999-01-01)'),
#  ('T30011',
#   'T39722',
#   0.9648128967349652,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2002-01-01)',
#   'Synthesis of heterocycles and reaction mechanism (2005-01-01)'),
#  ('T30011',
#   'T144825',
#   0.9603787802290514,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2002-01-01)',
#   'Synthesis of heterocycles and reaction mechanism (2008-01-01)'),
#  ('T148531',
#   'T70845',
#   0.9882575120886429,
#   'Studies on natural products (2003-01-01)',
#   'Studies on natural products (1984-01-01)'),
#  ('T154387',
#   'T68322',
#   0.9854900977018475,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2012-01-01)',
#   'Synthesis of heterocyclic compounds and reaction mechanism (1999-01-01)'),
#  ('T154387',
#   'T39722',
#   0.9581353323029217,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2012-01-01)',
#   'Synthesis of heterocycles and reaction mechanism (2005-01-01)'),
#  ('T154387',
#   'T144825',
#   0.9616177927738243,
# ...
#  ('T159987',
#   'T158233',
#   0.9332498066741428,
#   'Petrological mineralogical and geochemical studies of dyke rocks occurring around Chamarajnagar Kollegal district Karnataka state India',
#   'Petrological and mineralogical studies of the rocks around Nagamangala Mandya district Karnataka'),
#  ('T170497',
#   'T161064',
#   0.9871899900490039,
#   'Geology of the Sivasamudram area Bangalore district Mysore state',
#   'Geology of the area around Bidadi Harohalli Bangalore district Mysore state'),
#  ('T170497',
#   'T29633',
#   0.9088430881180062,
#   'Geology of the Sivasamudram area Bangalore district Mysore state',
#   'Geology of the area around Bellary Karnataka state'),
#  ('T170497',
#   'T6560',
#   0.9403670557567217,
#   'Geology of the Sivasamudram area Bangalore district Mysore state',
#   'Geology of the area East of Manoli Belgaum district Karnataka state'),
#  ('T170497',
#   'T72197',
#   0.9375893979746837,
#   'Geology of the Sivasamudram area Bangalore district Mysore state',
#   'Geology of the Vengurla area Ratnagiri district Maharashtra state'),
#  ('T150327',
#   'T142055',
#   0.8831232187970364,
#   'Hydrogeological studies of Hosur Halla basin Belgaum district Karnataka',
#   'Hydrogeological studies of Tupari Halla Basin Karnataka India'),
#  ('T150327',
#   'T26382',
#   0.9058583080571714,
#   'Hydrogeological studies of Hosur Halla basin Belgaum district Karnataka',
#   'Hydrogeochemical studies of Garani Halla upper basin Chitradurga district Karnataka India'),
#  ('T150327',
#   'T191913',
#   0.9093364901539285,
#   'Hydrogeological studies of Hosur Halla basin Belgaum district Karnataka',
#   'Hydrogeological studies of Madhura halla basin Bidar district Karnataka state India'),
#  ('T17133',
#   'T139208',
#   0.9410701150597182,
#   'A study of kinetics and mechanism of some oxidation reactions',
#   'Studies in kinetics and mechanism of some reactions in solution'),
#  ('T57681',
#   'T56463',
#   0.9354604910203335,
#   'Studies on organic liquid mixtures',
#   'Studies on liquids and liquid mixtures'),
#  ('T154200',
#   'T17133',
#   0.9881658137037503,
#   'A study of kinetics and mechanism of some catalysed and uncatalysed oxidation reactions',
#   'A study of kinetics and mechanism of some oxidation reactions'),
#  ('T159888',
#   'T138434',
#   0.9789812917833371,
#   'Kinetics and mechanism of some inorganic Redox reactions',
#   'Kinetics and mechanism of some redox reactions'),
#  ('T28176',
#   'T139208',
#   0.9132485678196942,
#   'A study of kinetics and mechanism of some catalysed redox reactions',
#   'Studies in kinetics and mechanism of some reactions in solution'),
#  ('T28176',
#   'T17133',
#   0.9689077795203818,
#   'A study of kinetics and mechanism of some catalysed redox reactions',
#   'A study of kinetics and mechanism of some oxidation reactions'),
#  ('T28176',
#   'T138434',
#   0.9681400347058979,
#   'A study of kinetics and mechanism of some catalysed redox reactions',
#   'Kinetics and mechanism of some redox reactions'),
#  ('T28176',
#   'T154200',
#   0.9800332076134421,
#   'A study of kinetics and mechanism of some catalysed redox reactions',
#   'A study of kinetics and mechanism of some catalysed and uncatalysed oxidation reactions'),
#  ('T161051',
#   'T141718',
#   0.9147144563576607,
#   'Kinetics and mechanism of a few reactions',
#   'Kinetics and mechanism of a few reactions in aqueous alkaline medium'),
#  ('T161051',
#   'T138434',
#   0.9327738546443799,
#   'Kinetics and mechanism of a few reactions',
#   'Kinetics and mechanism of some redox reactions'),
#  ('T161051',
#   'T159888',
#   0.8924358031919117,
#   'Kinetics and mechanism of a few reactions',
#   'Kinetics and mechanism of some inorganic Redox reactions'),
#  ('T107395',
#   'T141718',
#   0.935022623569965,
#   'Kinetics and mechanism of some reactions with alkaline permanganate',
#   'Kinetics and mechanism of a few reactions in aqueous alkaline medium'),
#  ('T107395',
#   'T138434',
#   0.9272070671866183,
#   'Kinetics and mechanism of some reactions with alkaline permanganate',
#   'Kinetics and mechanism of some redox reactions'),
#  ('T107395',
#   'T159888',
#   0.9250543867890617,
#   'Kinetics and mechanism of some reactions with alkaline permanganate',
#   'Kinetics and mechanism of some inorganic Redox reactions'),
#  ('T107395',
#   'T161051',
#   0.9025667660587444,
#   'Kinetics and mechanism of some reactions with alkaline permanganate',
#   'Kinetics and mechanism of a few reactions'),
#  ('T46843',
#   'T138434',
#   0.9282781572807701,
#   'Kinetics and mechanism of electron transfer reactions',
#   'Kinetics and mechanism of some redox reactions'),
#  ('T46843',
#   'T159888',
#   0.913714368135374,
#   'Kinetics and mechanism of electron transfer reactions',
#   'Kinetics and mechanism of some inorganic Redox reactions'),
#  ('T46843',
#   'T161051',
#   0.8965617396260052,
#   'Kinetics and mechanism of electron transfer reactions',
#   'Kinetics and mechanism of a few reactions'),
#  ('T46843',
#   'T107395',
#   0.8602732843845515,
#   'Kinetics and mechanism of electron transfer reactions',
#   'Kinetics and mechanism of some reactions with alkaline permanganate'),
#  ('T50545',
#   'T17133',
#   0.9784712883390491,
#   'A study of kinetics and mechanism of some catalysed and uncatalysed reactions',
#   'A study of kinetics and mechanism of some oxidation reactions'),
#  ('T50545',
#   'T154200',
#   0.986232977659035,
#   'A study of kinetics and mechanism of some catalysed and uncatalysed reactions',
#   'A study of kinetics and mechanism of some catalysed and uncatalysed oxidation reactions'),
#  ('T50545',
#   'T28176',
#   0.9700969305922581,
#   'A study of kinetics and mechanism of some catalysed and uncatalysed reactions',
#   'A study of kinetics and mechanism of some catalysed redox reactions'),
#  ('T29273',
#   'T177979',
#   0.9492136067738288,
#   'Studies in heterocyclic compounds of pharmacological interest (2008-07-05)',
#   'Studies in heterocyclic compounds of biological interest (2011-12-31)'),
#  ('T176509',
#   'T121933',
#   0.9103902007235487,
#   'Synthetic studies in nitrogen and sulfur heterocycles of pharmacological interest',
#   'Synthetic studies in mesoionic compounds of pharmacological interest'),
#  ('T20377',
#   'T121933',
#   0.9484724097948511,
#   'Synthetic studies in meso ionic compounds of pharmacological interest',
#   'Synthetic studies in mesoionic compounds of pharmacological interest'),
#  ('T20377',
#   'T176509',
#   0.8964569401816262,
#   'Synthetic studies in meso ionic compounds of pharmacological interest',
#   'Synthetic studies in nitrogen and sulfur heterocycles of pharmacological interest'),
#  ('T118988',
#   'T187936',
#   0.9273838493345226,
#   'Synthesis of nitrogen and sulphur heterocycles of pharmacological interest',
#   'Synthesis of oxygen nitrogen and sulphur heterocycles'),
#  ('T118988',
#   'T29891',
#   0.93185858785988,
#   'Synthesis of nitrogen and sulphur heterocycles of pharmacological interest',
#   'Synthesis of oxygen and nitrogen heterocycles with potential bioactivity'),
#  ('T118988',
#   'T21832',
#   0.919947500938096,
#   'Synthesis of nitrogen and sulphur heterocycles of pharmacological interest',
#   'Synthesis of nitrogen oxygen and sulfur heterocycles'),
#  ('T118988',
#   'T133384',
#   0.9465428717773621,
#   'Synthesis of nitrogen and sulphur heterocycles of pharmacological interest',
#   'Synthesis of nitrogen and sulphur heterocycles'),
#  ('T118988',
#   'T176509',
#   0.9537870005926938,
#   'Synthesis of nitrogen and sulphur heterocycles of pharmacological interest',
#   'Synthetic studies in nitrogen and sulfur heterocycles of pharmacological interest'),
#  ('T177530',
#   'T121933',
#   0.9671228609926477,
#   'Synthetic and pharmacological studies of mesoionic compounds',
#   'Synthetic studies in mesoionic compounds of pharmacological interest'),
#  ('T177530',
#   'T98948',
#   0.970447150322069,
#   'Synthetic and pharmacological studies of mesoionic compounds',
#   'Synthetic and pharmacological studies of sydnones'),
#  ('T177530',
#   'T20377',
#   0.931489161824182,
#   'Synthetic and pharmacological studies of mesoionic compounds',
#   'Synthetic studies in meso ionic compounds of pharmacological interest'),
#  ('T56787',
#   'T76494',
#   0.9150464418540524,
#   'Synthetic utility of sydnones synthesis of some triazole derivatives from sydnones their biological activity and computational studies',
#   'Synthesis of some N O and S heterocycles from sydnones and their physical biological and computational studies'),
#  ('T92603',
#   'T1711',
#   0.9626519242290378,
#   'Studies on unusual fatty acids and synthesis of some fatty acid derivatives of Biological interest',
#   'Studies on unusual fatty acids and synthesis of some oleochemicals'),
#  ('T181385',
#   'T143798',
#   0.9574076767792499,
#   'Chemical investigation of minor seed oils and synthesis of some oleochemicals',
#   'Chemical investigation of minor seed oils and synthesis of undecylenic acid derivatives'),
#  ('T130163',
#   'T15349',
#   0.9811802159351771,
#   'Studies in antibacterials (1959-10-31)',
#   'Studies in antibacterials (1961-06-30)'),
#  ('T89242',
#   'T24055',
#   0.9209767100026651,
#   'Synthesis reactions and pharmacological studies of sydnones',
#   'Synthesis and reactions of quinoxalines'),
#  ('T89242',
#   'T61278',
#   0.9209767100026651,
#   'Synthesis reactions and pharmacological studies of sydnones',
#   'Synthesis and reactions of Flavazoles'),
#  ('T89242',
#   'T98948',
#   0.9043609633984336,
#   'Synthesis reactions and pharmacological studies of sydnones',
#   'Synthetic and pharmacological studies of sydnones'),
#  ('T89242',
#   'T177530',
#   0.8989462094099611,
#   'Synthesis reactions and pharmacological studies of sydnones',
#   'Synthetic and pharmacological studies of mesoionic compounds'),
#  ('T44819',
#   'T126910',
#   0.9054387678535105,
#   'Synthetic studies in nitrogen and oxygen heterocycles of structural and biological interest',
#   'Synthetic studies on 4 substituted coumarins of structural and biological interest'),
#  ('T44819',
#   'T176509',
#   0.952998095973604,
#   'Synthetic studies in nitrogen and oxygen heterocycles of structural and biological interest',
#   'Synthetic studies in nitrogen and sulfur heterocycles of pharmacological interest'),
#  ('T150708',
#   'T178447',
#   0.8758605049248919,
#   'Synthesis and characterization of hydrogels for drug delivery applications',
#   'Synthesis characterization and applications of bioactive coordination compounds'),
#  ('T104212',
#   'T64370',
#   0.9064311642208426,
#   'Development and evaluation of novel polymeric drug delivery systems for controlled release applications',
#   'Formulation and evaluation of drug delivery systems for the treatment of periodontitis'),
#  ('T104212',
#   'T119301',
#   0.9330957618057845,
#   'Development and evaluation of novel polymeric drug delivery systems for controlled release applications',
#   'Ormulation and evaluation of novel drug delivery systems for bioavailability enhancement'),
#  ('T93992',
#   'T26866',
#   0.9503792406648839,
#   'Studies on polymeric membranes for the pervaporation separation of aqueous organic mixtures',
#   'Synthesis and characterization of polymeric membranes for the pervaporation separation of industrially important liquid mixtures'),
#  ('T187716',
#   'T169896',
#   0.9152538790285858,
#   'Development and evaluation of polymeric matrices for controlled release applications',
#   'Development of polymeric matrices for the controlled release of bioactive molecules'),
#  ('T187716',
#   'T104212',
#   0.9443724471469497,
#   'Development and evaluation of polymeric matrices for controlled release applications',
#   'Development and evaluation of novel polymeric drug delivery systems for controlled release applications'),
#  ('T32596',
#   'T150708',
#   0.8734434293124493,
#   'Synthesis and characterization of polymeric membranes for pervaporation',
#   'Synthesis and characterization of hydrogels for drug delivery applications'),
#  ('T32596',
#   'T26866',
#   0.9443214050562633,
#   'Synthesis and characterization of polymeric membranes for pervaporation',
#   'Synthesis and characterization of polymeric membranes for the pervaporation separation of industrially important liquid mixtures'),
#  ('T47229',
#   'T150708',
#   0.9660481437793077,
#   'Synthesis and characterization of biomaterials for drug delivery',
#   'Synthesis and characterization of hydrogels for drug delivery applications'),
#  ('T47229',
#   'T32596',
#   0.8528863896474431,
#   'Synthesis and characterization of biomaterials for drug delivery',
#   'Synthesis and characterization of polymeric membranes for pervaporation'),
#  ('T28461',
#   'T35604',
#   0.8769873037869641,
#   'Ancillarisation a case study of North Karnataka industrial area',
#   'Environmental impact analysis of Belur industrial area Dharwad a case study'),
#  ('T63615',
#   'T66218',
#   0.9319193352785411,
#   'Studies on microalgal lipids with special reference to botryococcus species',
#   'Studies on secondary metabolites from cassia species with special reference to anthraquinones'),
#  ('T112687',
#   'T77619',
#   0.9109268013280378,
#   'Synthesis and biological evaluation of curcumin analogues for their therapeutic properties',
#   'Synthesis of Fused dihydropyridine derivatives and evaluation of their biological activity'),
#  ('T112687',
#   'T188407',
#   0.8908671645993529,
#   'Synthesis and biological evaluation of curcumin analogues for their therapeutic properties',
#   'Synthesis of heterocyclic analogues for their biological applications'),
#  ('T112687',
#   'T195279',
#   0.909010666128336,
#   'Synthesis and biological evaluation of curcumin analogues for their therapeutic properties',
#   'Synthesis structural studies and biological evaluation of quinoline analogues and their metal complexes'),
#  ('T112687',
#   'T41609',
#   0.9215900967411945,
#   'Synthesis and biological evaluation of curcumin analogues for their therapeutic properties',
#   'Synthesis of oxadiazole and pyrimidone analogues for their biological applications'),
#  ('T143677',
#   'T48505',
#   0.8575724579571989,
#   'Studies on anxiolytic and neuroprotective properties of plant foods',
#   'Studies on phytochemicals and biological properties of bitter cumin'),
#  ('T55126',
#   'T71610',
#   0.9303224243615912,
#   'Synthesis characterization and biological studies of substituted pyrimidinone and thiazole derivatives',
#   'Synthesis and characterization of new benzamide derivatives and their biological applications'),
#  ('T55126',
#   'T64258',
#   0.9634010249090665,
#   'Synthesis characterization and biological studies of substituted pyrimidinone and thiazole derivatives',
#   'Synthesis characterization and in vitro biological studies of isoxazole and pyrazole derivatives'),
#  ('T55126',
#   'T106300',
#   0.9492791777192986,
#   'Synthesis characterization and biological studies of substituted pyrimidinone and thiazole derivatives',
#   'Synthesis and characterization of new benzothiazepine and benzimidazole derivatives and their biological studies'),
#  ('T55126',
#   'T98141',
#   0.9488939413725129,
#   'Synthesis characterization and biological studies of substituted pyrimidinone and thiazole derivatives',
#   'Synthesis characterization and biological activity studies on benzothiazole derivatives'),
#  ('T55126',
#   'T51209',
#   0.9838883576301565,
#   'Synthesis characterization and biological studies of substituted pyrimidinone and thiazole derivatives',
#   'Synthesis characterization and biological studies of hydantoin imidazopyridine and difluoropiperidine derivatives'),
#  ('T55126',
#   'T189453',
#   0.954520730901794,
#   'Synthesis characterization and biological studies of substituted pyrimidinone and thiazole derivatives',
#   'Synthesis and characterization of piperamide and quinazolinone derivatives of biological interest'),
#  ('T55126',
#   'T48662',
#   0.9594277972467187,
#   'Synthesis characterization and biological studies of substituted pyrimidinone and thiazole derivatives',
#   'Synthesis characterization and biological studies of substituted pyrimidine derivatives'),
#  ('T55126',
#   'T98879',
#   0.947382256448903,
#   'Synthesis characterization and biological studies of substituted pyrimidinone and thiazole derivatives',
#   'Synthesis characterisation and pharmacological studies of novel substituted homopiperazine derivatives'),
#  ...]

# %%
thesis_99 = [a for a in f_final_thesis if a[2] > 0.99]

# %%
thesis_99[0]
# Out:
# ('T155527',
#  'T132833',
#  0.9928626803485257,
#  'Fabrication electrical and structural characterization of metal schottky contacts on n type indium phosphide inp',
#  'Fabrication electrical and structural caracterization of metal schottky contacts on n type indium phosphide inp')

# %%
tmp={}
for a in thesis_99:
    n1, n10 = rm_splChar(a[3])
    n2, n20 = rm_splChar(a[4])
    n11, n21 = lcs(n1, n2)
    n101, n201 = lcs(n10,n20)
    if (len(n11) > 5 and len(n21)>5): 
        vec1 = calculate_feats(n11, n21)
        vec2 = calculate_feats(n11.lower(), n21.lower())
    else:
        vec1 = calculate_feats(n1, n2)
        vec2 = calculate_feats(n1.lower(), n2.lower())
    if (len(n101)>5 and len(n201)>5): 
        vec3=calculate_feats(n101, n201)
        vec4=calculate_feats(n101.lower(), n201.lower())
    else:
        vec3=calculate_feats(n10, n20)
        vec4=calculate_feats(n10.lower(), n20.lower())
    tmp[a]=(sum(vec1),sum(vec2),sum(vec3),sum(vec4))

# %%
tmp
# Out:
# {('T155527',
#   'T132833',
#   0.9928626803485257,
#   'Fabrication electrical and structural characterization of metal schottky contacts on n type indium phosphide inp',
#   'Fabrication electrical and structural caracterization of metal schottky contacts on n type indium phosphide inp'): (5.860719874804381,
#   5.860719874804381,
#   5.874683544303798,
#   5.874683544303798),
#  ('T4865',
#   'T32989',
#   1.0000001429913685,
#   'Toxicity Evaluation and Hypoglycemic Activity Of Indigenous Medicinal Plants Of Gujarat',
#   'Toxicity Evaluation And Hypoglycemic Activity Of Indigenous Medicinal Plants Of Gujarat'): (5.642105263157895,
#   6.0,
#   5.675324675324675,
#   6.0),
#  ('T82551',
#   'T91408',
#   0.9999999588854146,
#   'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS Gartn ELAEOCARPACEAE',
#   'THNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE'): (4.420805244603872,
#   5.735419630156472,
#   4.493589743589744,
#   5.748717948717949),
#  ('T98000',
#   'T91408',
#   0.9999999588854146,
#   'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE',
#   'THNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE'): (5.9720513903885575,
#   5.9720513903885575,
#   5.975833713490308,
#   5.975833713490308),
#  ('T98000',
#   'T82551',
#   0.9999999588854146,
#   'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE',
#   'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS Gartn ELAEOCARPACEAE'): (4.6060606060606055,
#   6.0,
#   4.672768878718536,
#   6.0),
#  ('T46495',
#   'T157330',
#   0.9916515400222001,
#   'Ecological Studies of Chhatri Lake, Amravati with Special Reference to Planktons and Productivity',
#   'Ecological Studies of Chattri Lake Amravati With Special Reference to Planktons and Productivity'): (5.574108818011257,
#   5.746153846153846,
#   5.629787234042553,
#   5.779710144927536),
#  ('T42449',
#   'T170278',
#   0.9964306260052318,
#   'Changing scenario of leadership in insurance sector a critical appraisal of life insurance Corporation of India and Bajaj Allianz',
#   'Changing scenario of leadership in insurance sector: a critical appraisal of Life Insurance Corporation of India and Bajaj Allianz'): (5.702898550724638,
#   6.0,
#   5.741337907375643,
#   6.0),
#  ('T68665',
#   'T128696',
#   1.0000000596887995,
#   'simulation of energy and water exchange processes at vegetation atmosphere interface in rice ecosystem',
#   'Simulation of energy and water exchange processes at vegetation atmosphere interface in rice ecosystem'): (5.921847690387016,
#   6.0,
#   5.931753283837807,
#   6.0),
#  ('T149608',
#   'T181467',
#   1.0000000119650503,
#   'studies on distribution of heavy metals in water sediment and biota in coastal areas of Sunderbans and its potential risk in the environment',
#   'Studies on distribution of heavy metals in water sediment and biota in coastal areas of Sunderbans and its potential risk in the environment'): (5.94096282580829,
#   6.0,
#   5.950202634245188,
#   6.0),
#  ('T15114',
#   'T54922',
#   0.9917173174552896,
#   'Modes of production, distribution and reception of writings in womenâ\x80\x99s magazines: a study in critical discourse analysis',
#   "Modes of production, distribution and reception of writings in women's Magazines: a study in critical discourse analysis"): (5.4649758454106285,
#   5.610463562544969,
#   5.53472093943792,
#   5.661721227758964),
#  ('T89509',
#   'T126037',
#   0.996476095119744,
#   'Production Purification and Characterization of Broad Spectrum Antimicrobial Compound from Streptomyces sp and Improvement of the Strain',
#   'Production Purification and Characterization of a Broad Spectrum Antimicrobial Compound from Streptomyces sp and Improvement of the Strain'): (5.886102403343783,
#   5.886102403343783,
#   5.795068027210884,
#   5.795068027210884),
#  ('T52413',
#   'T143079',
#   0.9915756919039597,
#   'Studies on electroluminescence using powder and thin film devices (1983-08-01)',
#   'Studies on electroluminescence using powder and thin film devices (1984-03-27)'): (2.1666666666666665,
#   2.1666666666666665,
#   2.1666666666666665,
#   2.1666666666666665),
#  ('T62866',
#   'T21120',
#   0.9974560920762214,
#   'Synthesis Characterization biological evaluation and computational studies of some novel thiadiazole derivatives',
#   'Synthesis Characterization computational study and biological evaluation of some novel Pyridazinone derivatives'): (4.153648335019425,
#   4.153648335019425,
#   4.299875689920939,
#   4.299875689920939),
#  ('T162114',
#   'T157692',
#   0.999093976002518,
#   'A Study on Service Quality and Customer Satisfaction in Paid Direct To Home Service Providers in Himachal Pradesh (2015-09-12)',
#   'A Study on Service Quality and Customer Satisfaction in Paid Direct To Home Service Providers in Himachal Pradesh (2015-09-19)'): (5.924880973373304,
#   5.924880973373304,
#   5.935741935483871,
#   5.935741935483871),
#  ('T57657',
#   'T64525',
#   0.9986994797414837,
#   'Synthesis of heterocyclic compounds (1999-01-01)',
#   'Synthesis of heterocyclic compounds (2002-01-01)'): (2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915),
#  ('T134412',
#   'T64525',
#   0.9984012748009803,
#   'Synthesis of heterocyclic compounds (2005-01-01)',
#   'Synthesis of heterocyclic compounds (2002-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T134412',
#   'T57657',
#   0.9957856340454551,
#   'Synthesis of heterocyclic compounds (2005-01-01)',
#   'Synthesis of heterocyclic compounds (1999-01-01)'): (2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915),
#  ('T144825',
#   'T39722',
#   0.9977171811923801,
#   'Synthesis of heterocycles and reaction mechanism (2008-01-01)',
#   'Synthesis of heterocycles and reaction mechanism (2005-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T19816',
#   'T64525',
#   0.9976475604128102,
#   'Synthesis of heterocyclic compounds (1997-01-01)',
#   'Synthesis of heterocyclic compounds (2002-01-01)'): (2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915),
#  ('T19816',
#   'T57657',
#   0.9994472960347159,
#   'Synthesis of heterocyclic compounds (1997-01-01)',
#   'Synthesis of heterocyclic compounds (1999-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T19816',
#   'T134412',
#   0.9941737842716192,
#   'Synthesis of heterocyclic compounds (1997-01-01)',
#   'Synthesis of heterocyclic compounds (2005-01-01)'): (2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915),
#  ('T144258',
#   'T192403',
#   0.9958718859334517,
#   'Synthesis of heterocycles (2006-01-01)',
#   'Synthesis of heterocycles (2001-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T106739',
#   'T134412',
#   0.9931650662524465,
#   'Synthesis of heterocyclic compounds (2010-01-01)',
#   'Synthesis of heterocyclic compounds (2005-01-01)'): (4.642857142857142,
#   4.642857142857142,
#   4.642857142857142,
#   4.642857142857142),
#  ('T30011',
#   'T68322',
#   0.9990868772027723,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2002-01-01)',
#   'Synthesis of heterocyclic compounds and reaction mechanism (1999-01-01)'): (2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915),
#  ('T99825',
#   'T39722',
#   0.9996257380038086,
#   'Synthesis of heterocycles and reaction mechanism (2006-01-01)',
#   'Synthesis of heterocycles and reaction mechanism (2005-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T99825',
#   'T144825',
#   0.9985500382017908,
#   'Synthesis of heterocycles and reaction mechanism (2006-01-01)',
#   'Synthesis of heterocycles and reaction mechanism (2008-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T150113',
#   'T68322',
#   0.997042496290835,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2005-01-01)',
#   'Synthesis of heterocyclic compounds and reaction mechanism (1999-01-01)'): (2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915,
#   2.9914529914529915),
#  ('T150113',
#   'T30011',
#   0.9988783066315381,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2005-01-01)',
#   'Synthesis of heterocyclic compounds and reaction mechanism (2002-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T150113',
#   'T154387',
#   0.9906918712949956,
#   'Synthesis of heterocyclic compounds and reaction mechanism (2005-01-01)',
#   'Synthesis of heterocyclic compounds and reaction mechanism (2012-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T110408',
#   'T97577',
#   0.9996143086478506,
#   'Synthesis and catalytic dehydrogenation of Spiro compounds (1992-01-01)',
#   'Synthesis and catalytic dehydrogenation of Spiro compounds (1991-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T21832',
#   'T187936',
#   0.9946080466353454,
#   'Synthesis of nitrogen oxygen and sulfur heterocycles',
#   'Synthesis of oxygen nitrogen and sulphur heterocycles'): (4.819333607568901,
#   4.819333607568901,
#   4.947908232118759,
#   4.947908232118759),
#  ('T18629',
#   'T192403',
#   0.9932951929240442,
#   'Synthesis of heterocycles (1991-01-01)',
#   'Synthesis of heterocycles (2001-01-01)'): (3.6666666666666665,
#   3.6666666666666665,
#   3.6666666666666665,
#   3.6666666666666665),
#  ('T58949',
#   'T31245',
#   0.9984107894103291,
#   'Chemical investigation on Indian medicinal plants (1991-01-01)',
#   'Chemical investigation on Indian medicinal plants (1984-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T17167',
#   'T163522',
#   0.994124364119271,
#   'Studies on triterpenoids (1980-01-01)',
#   'Studies on triterpenoids (1966-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T62536',
#   'T187175',
#   0.9991753896400738,
#   'Synthesis and catalytic dehydrogenation studies of Spiro compounds (1979-01-01)',
#   'Synthesis and catalytic dehydrogenation studies of Spiro compounds (1976-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T9363',
#   'T60111',
#   0.9991922092162356,
#   'Studies on some methods of organic synthesis (2003-01-01)',
#   'Studies on some methods of organic synthesis (2005-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T59765',
#   'T109965',
#   0.9986046904509531,
#   'Chemical and biological investigation of natural products (1982-01-01)',
#   'Chemical and biological investigation of natural products (1990-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T171043',
#   'T106739',
#   0.996631281390804,
#   'Synthesis of heterocyclic compounds (2012-01-01)',
#   'Synthesis of heterocyclic compounds (2010-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T96982',
#   'T60111',
#   0.9997098947938664,
#   'Studies on some methods of organic synthesis (2006-01-01)',
#   'Studies on some methods of organic synthesis (2005-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T96982',
#   'T9363',
#   0.9985177958889379,
#   'Studies on some methods of organic synthesis (2006-01-01)',
#   'Studies on some methods of organic synthesis (2003-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T63629',
#   'T31245',
#   0.9994542061340688,
#   'Chemical investigation on Indian medicinal plants (1985-01-01)',
#   'Chemical investigation on Indian medicinal plants (1984-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T63629',
#   'T58949',
#   0.9988634953840627,
#   'Chemical investigation on Indian medicinal plants (1985-01-01)',
#   'Chemical investigation on Indian medicinal plants (1991-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T67673',
#   'T109193',
#   0.9947634127965551,
#   'Studies on some methods of organic synthesis (2011-01-01)',
#   'Studies on some methods of organic synthesis (2013-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T67673',
#   'T60111',
#   0.9935133067973309,
#   'Studies on some methods of organic synthesis (2011-01-01)',
#   'Studies on some methods of organic synthesis (2005-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T67673',
#   'T9363',
#   0.9912268976552051,
#   'Studies on some methods of organic synthesis (2011-01-01)',
#   'Studies on some methods of organic synthesis (2003-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T67673',
#   'T96982',
#   0.9946367948395038,
#   'Studies on some methods of organic synthesis (2011-01-01)',
#   'Studies on some methods of organic synthesis (2006-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T89108',
#   'T109193',
#   0.9977051179137081,
#   'Studies on some methods of organic synthesis (2012-01-01)',
#   'Studies on some methods of organic synthesis (2013-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T89108',
#   'T60111',
#   0.9908806204988854,
#   'Studies on some methods of organic synthesis (2012-01-01)',
#   'Studies on some methods of organic synthesis (2005-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T89108',
#   'T96982',
#   0.9919541307304172,
#   'Studies on some methods of organic synthesis (2012-01-01)',
#   'Studies on some methods of organic synthesis (2006-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T89108',
#   'T67673',
#   0.9987121066537278,
#   'Studies on some methods of organic synthesis (2012-01-01)',
#   'Studies on some methods of organic synthesis (2011-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T49291',
#   'T80676',
#   0.9999999250397563,
#   'Structural investigations on Putranjivadione',
#   'Structural investigations on triterpenoids'): (2.0619047619047617,
#   2.280701754385965,
#   2.0619047619047617,
#   2.280701754385965),
#  ('T112537',
#   'T58192',
#   0.995786515048427,
#   'A study of hypolipidemic effect of linseed in the diet of cardiovascular patients',
#   'A study of Hypolipidemic effects of linseed in the diet of cardiovascular patients'): (5.5775190326914466,
#   5.820779220779221,
#   5.629689754689755,
#   5.843253968253968),
#  ('T130659',
#   'T57222',
#   0.9942309771237955,
#   'Comparative study of nutrition in take beneficiary and non beneficiary pregnant rural women under ICDS Programme',
#   'Comparative study of nutrition in take beneficiary and non-beneficiary pregnant rural women under ICDS Programme'): (6.0,
#   6.0,
#   5.9072343371408795,
#   5.9072343371408795),
#  ('T12467',
#   'T148346',
#   0.9905433624178327,
#   'Nutritional status of lactating mothers and composition of traditional supplimentary foods consumed by them',
#   'Nutritional status of lactating mothers and composition of traditional supplementary foods consumed by them'): (5.708994708994709,
#   5.708994708994709,
#   5.745967741935484,
#   5.745967741935484),
#  ('T163626',
#   'T33925',
#   0.9909676647033986,
#   'A clinical study of the effect of different endotracheal tubes on the incidence of post operative laryngo trachities',
#   'A clinical study of the effect of different endotracheal tubes on the incidence of post- operative laryngo-tracheitis'): (5.94949494949495,
#   5.94949494949495,
#   5.082251082251083,
#   5.082251082251083),
#  ('T91506',
#   'T62523',
#   0.9913979864017235,
#   'A clinical study of the effect of nifedipine as premedicant in pregnency induced hypertension',
#   'A clinical study of the effect of nifedipine as premedicant in pregnancy induced hypertension'): (5.659420289855072,
#   5.659420289855072,
#   5.686153846153847,
#   5.686153846153847),
#  ('T175547',
#   'T78338',
#   1.000000006238747,
#   'Sapkotar kavita me bhavnatmakta avam sanvedansilta',
#   'Sapkotar kavita me bhavnatmakta avam sanveda'): (5.323809523809524,
#   5.323809523809524,
#   5.3923404255319145,
#   5.3923404255319145),
#  ('T102592',
#   'T146365',
#   0.9939657105540515,
#   'A study of the effects of yogic exercises on physiological functions in young human volunteers',
#   'A study of the effects of yogic exercises on physiological functionas in young human volunteers'): (5.790780141843972,
#   5.790780141843972,
#   5.820779220779221,
#   5.820779220779221),
#  ('T33661',
#   'T17763',
#   0.991839186439991,
#   'A study of fasting and post prandial lipoprotein profile in cerebrovascular disease, central nervous system infections and malignant diseases',
#   'A study of fasting and post prandial lipoprotein profile in Cerebrovascular disease, peripheral vascular disease, central nervous system infections and malignant diseases'): (4.396385330759783,
#   4.420775574662222,
#   4.454320987654321,
#   4.4753736192332685),
#  ('T174521',
#   'T25434',
#   0.9953863944107052,
#   'Attenuation of the reflex response to laryngoscopy tracheal intubation with various drug combinations',
#   'Attenuation of the Reflex response to Laryngoscopy and tracheal intubation with various drug combinations'): (5.391629646948796,
#   5.678746785129764,
#   5.376678876678877,
#   5.626780626780627),
#  ('T106676',
#   'T17763',
#   0.990625608263532,
#   'A study of fasting and post prandial lipoprotein profile in cerebrovascular disease, central nervous system infections and malignant disease',
#   'A study of fasting and post prandial lipoprotein profile in Cerebrovascular disease, peripheral vascular disease, central nervous system infections and malignant diseases'): (4.3514629948364885,
#   4.375559380378657,
#   4.415005112474438,
#   4.435838445807771),
#  ('T106676',
#   'T33661',
#   0.998759625860421,
#   'A study of fasting and post prandial lipoprotein profile in cerebrovascular disease, central nervous system infections and malignant disease',
#   'A study of fasting and post prandial lipoprotein profile in cerebrovascular disease, central nervous system infections and malignant diseases'): (5.958982662079201,
#   5.958982662079201,
#   5.96426011264721,
#   5.96426011264721),
#  ('T104953',
#   'T151436',
#   0.990963511835238,
#   'The extended clinico-laboratory profile of the female partner of infertility in Bundelkhand Region',
#   'The extended clinico-laboratory profile of the male partner in infertility in Bundelkhand Region'): (5.430539436922416,
#   5.430539436922416,
#   5.496722160562339,
#   5.496722160562339),
#  ('T99902',
#   'T151436',
#   0.993441175301568,
#   'The extended clinico-laboratory profile of the Male partner of infertility in Bundelkhand region',
#   'The extended clinico-laboratory profile of the male partner in infertility in Bundelkhand Region'): (5.333993072736269,
#   5.6361757105943155,
#   5.412398921832884,
#   5.679871948779512),
#  ('T99902',
#   'T104953',
#   0.9980002598623925,
#   'The extended clinico-laboratory profile of the Male partner of infertility in Bundelkhand region',
#   'The extended clinico-laboratory profile of the female partner of infertility in Bundelkhand Region'): (5.475993982376961,
#   5.776767676767677,
#   5.536722160562338,
#   5.80313725490196),
#  ('T38345',
#   'T67961',
#   0.9938215502437546,
#   'Tatanus in Bundelkhand region - its incidence and the role of intrathecal human antitetanus immunoglobulin in its treatment',
#   'Tatanus in Bundelkhand region its incidence and the role of intrathecal human antitetanus immunoglobulin in its treatment'): (6.0,
#   6.0,
#   5.8327683615819215,
#   5.8327683615819215),
#  ('T135328',
#   'T136492',
#   0.9947646102529939,
#   'A study of childhood epilepsy and epileptic syndromes in a subset of population in India with emphasis on heriditary factors',
#   'A study of childhood epilepsy and epileptic syndromes in a subset of population in india with emphasis on hereditary factors'): (5.725225225225225,
#   5.7807807807807805,
#   5.758420441347271,
#   5.807200929152149),
#  ('T165345',
#   'T168418',
#   0.999999942390977,
#   'To assess the value of fine needle aspiration gytology FNAG in dignosis of various tumours',
#   'To assess the value of fine needle aspiration gytology in dignosis of various tumours'): (5.323809523809524,
#   5.323809523809524,
#   5.2747252747252755,
#   5.2747252747252755),
#  ('T43134',
#   'T177017',
#   0.9977598054080835,
#   'To test the reproducibility of changes induces in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals',
#   'To test the reproducibility of changes induced in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals'): (5.802439024390243,
#   5.802439024390243,
#   5.827937095282147,
#   5.827937095282147),
#  ('T92578',
#   'T44992',
#   0.9943287394276069,
#   'A comparative study of Ca++ Channel blockers, ACE inhibitors and alpha blokers in patients of systemic hypertension',
#   'A comparative study of Ca++ channel blockers, ACE inhibitors and Alpha blockers in patients of systemic hypertension'): (5.702915750915751,
#   5.920507936507937,
#   5.746523645019885,
#   5.932340503769075),
#  ('T73994',
#   'T183074',
#   1.0000000576966546,
#   'Supercondylar fracture of the Humerus: a conservative approach',
#   'Supracondylar fracture of the Humerus: a conservative approach'): (5.816161616161617,
#   5.816161616161617,
#   5.8371232152300365,
#   5.8371232152300365),
#  ('T143584',
#   'T188202',
#   0.9945675351192389,
#   'To evaluate the changes in lipid liprotein profile induced after ingestion of single high cholestrol test diet in healthy and human subject',
#   'To evaluate the changes in lipid liprotein profile induced after ingestion of single high cholestrol test diet in healthy and disease subject'): (3.262515262515262,
#   3.262515262515262,
#   3.433082706766917,
#   3.433082706766917),
#  ('T54529',
#   'T7840',
#   0.9935863426602032,
#   'Clinical profile of low body weight type- 2 diabetes mellitus in Bundelkhand region',
#   'Clinical profile of low body weight Type 2 Diabetes Mellitus in Bundelkhand region'): (5.495930232558139,
#   6.0,
#   5.559449866903283,
#   6.0),
#  ('T165609',
#   'T7840',
#   1.000000033758923,
#   'Clinical profile of low body weight type 2 diabetes mellitus in Bundelkhand region',
#   'Clinical profile of low body weight Type 2 Diabetes Mellitus in Bundelkhand region'): (5.495930232558139,
#   6.0,
#   5.559449866903283,
#   6.0),
#  ('T165609',
#   'T54529',
#   0.9935863426602032,
#   'Clinical profile of low body weight type 2 diabetes mellitus in Bundelkhand region',
#   'Clinical profile of low body weight type- 2 diabetes mellitus in Bundelkhand region'): (6.0,
#   6.0,
#   6.0,
#   6.0),
#  ('T193203',
#   'T83665',
#   0.9999999802062829,
#   'Amniotic membrane transplantation for ocular surface disorders',
#   'Aminiotic amniotic membrane transplantation for ocular surface disorders'): (5.297393515575335,
#   5.297393515575335,
#   5.295190713101162,
#   5.295190713101162),
#  ('T178753',
#   'T199620',
#   0.9970302083634007,
#   'A comparative evaluation of soya based lactose free formula and parenteral antibiotics therapy in management of secondary lactase deficient chronic diarrh',
#   'A comparative evaluation of Soya based lactose free formula and parenteral antibiotics therapy in management of secondary lactase deficient chronic diarrhoeal cases'): (4.636091724825524,
#   4.636091724825524,
#   4.680241327300151,
#   4.680241327300151),
#  ('T97128',
#   'T17763',
#   0.9925925668911967,
#   'A study of fasting ans post prandial lipoprotein profile in cerbrovascular disease, peripheral vascular disease, central nervous syastem infections and malignant diseases',
#   'A study of fasting and post prandial lipoprotein profile in Cerebrovascular disease, peripheral vascular disease, central nervous system infections and malignant diseases'): (5.743131868131869,
#   5.820202020202021,
#   5.777871148459384,
#   5.844645550527903),
#  ('T16352',
#   'T100460',
#   0.9954132137273362,
#   'Effect of caffeine, stress, cold pressor test, and physical activity on blood pressure in middle aged hypertensive individuals',
#   'Effect of caffeome, stress, cold pressor test, and physical activity on blood pressure in middle aged hypertensive individuals'): (4.996078431372549,
#   4.996078431372549,
#   5.108359133126935,
#   5.108359133126935),
#  ('T186558',
#   'T32034',
#   0.9998762923053746,
#   'Prospective study of effect of converting enzyme inhibitors lisinopril versus enalapril on protienuria and renal function in diabetic nephropathy (1993-01-01)',
#   'Prospective study of effect of converting enzyme inhibitors lisinopril versus enalapril on protienuria and renal function in diabetic nephropathy (1995-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T77636',
#   'T177993',
#   0.999999997630649,
#   'role of escharoclysis in management of deep burn',
#   'Role of escharoclysis in management of deep burn'): (5.831591173054588,
#   6.0,
#   5.855867346938775,
#   6.0),
#  ('T27684',
#   'T177017',
#   0.9950053188747403,
#   'To test the reprodusibility of changes induced in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals',
#   'To test the reproducibility of changes induced in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals'): (5.542483660130719,
#   5.542483660130719,
#   5.609523809523809,
#   5.609523809523809),
#  ('T27684',
#   'T43134',
#   0.9924000021481617,
#   'To test the reprodusibility of changes induced in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals',
#   'To test the reproducibility of changes induces in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals'): (5.727439024390243,
#   5.727439024390243,
#   5.762719703977799,
#   5.762719703977799),
#  ('T120742',
#   'T26852',
#   0.9901310014928723,
#   'Study of dermatogyphic in children with bronchil asthma, asthmatic bronchitis and bronchiolitis',
#   'Study of dermatogyphics in children with bronchial asthma, asthmatic bronchitis and bronchiolitis'): (5.766334440753045,
#   5.766334440753045,
#   5.795068027210884,
#   5.795068027210884),
#  ('T61278',
#   'T24055',
#   1.000000059874006,
#   'Synthesis and reactions of Flavazoles',
#   'Synthesis and reactions of quinoxalines'): (1.8155080213903745,
#   1.8155080213903745,
#   1.8155080213903745,
#   1.8155080213903745),
#  ('T198278',
#   'T131513',
#   0.9905898570886247,
#   'Studies on the synthesis and transformations of a few 2 3h and 3 2h furanones',
#   'Studies on the synthesis and transformations of a few 23h and 3 2H furanones'): (5.336363636363637,
#   6.0,
#   5.464288997150473,
#   5.7716701902748415),
#  ('T184139',
#   'T38794',
#   0.998499341064065,
#   'Economics of justice in Kerala (1988-06-01)',
#   'Economics of justice in Kerala (1994-05-01)'): (3.0857142857142854,
#   3.0857142857142854,
#   3.0857142857142854,
#   3.0857142857142854),
#  ('T90180',
#   'T124439',
#   0.9944850664895722,
#   'Role of transvaginal colour doppler in cases of primary infertility as compared with Endometrial Biopsy',
#   'Role of Transvaginal colour doppler in cases of primary infertility as compare with endometrial biopsy'): (5.1462870538415,
#   5.826981246218995,
#   5.266924518899936,
#   5.852502194907814),
#  ('T121039',
#   'T87696',
#   0.9999998596462659,
#   'To study the serum lipoprotein changes after hysterectomy with or without oopherectomy',
#   'To study the serum lipoprotein changes after hysterectomy with or without oophaerectomy'): (5.437908496732026,
#   5.437908496732026,
#   5.437908496732026,
#   5.437908496732026),
#  ('T138740',
#   'T151487',
#   0.9928125147444539,
#   'Crystal and molecular structure studies of some pharmaceutical compounds pharmaceutical intermediates and organic picrates',
#   'Crystal and molecular structure studies of some pharmaceutical compounds and pharmaceutical intermediates'): (3.92,
#   3.92,
#   3.767195767195767,
#   3.767195767195767),
#  ('T11044',
#   'T153425',
#   0.9999999716892155,
#   'A study of Trichomes and their taxonomic significance in verbenacease and lamiaceae',
#   'A study of trichomes and their taxonomic significance in verbenaceae and lamiaceae'): (5.487198067632851,
#   5.781642512077294,
#   5.5775190326914466,
#   5.820779220779221),
#  ('T92756',
#   'T5928',
#   1.0000000485846805,
#   'Bahrtiya rashtravad aur Dr Bhimrav Ambedkar ek vivechnatamak adyayan',
#   'Bhartiya rashtravad aur Dr Bhimrav Ambedkar ek vivechnatmak adhyayan'): (5.3047619047619055,
#   5.3047619047619055,
#   5.35,
#   5.35),
#  ('T40742',
#   'T162599',
#   0.9903233007075557,
#   'Effect of sowing dates and stages of fruit harvest on seed yield and quality of cucumber Cocumis sativus L CV Swarn Ageti',
#   'Effect of sowing dates and stages of fruit harvest on seed yield and quality of cucumber Cucumis sativus L CV Swarn Ageti'): (5.698005698005698,
#   5.698005698005698,
#   5.745967741935484,
#   5.745967741935484),
#  ('T93456',
#   'T176106',
#   0.9975470825381638,
#   'Performance evaluation of state public enterprises in the manufacturing sector of Kerala (1997-05-15)',
#   'Performance evaluation of state public enterprises in the manufacturing sector of Kerala (1996-11-01)'): (1.9999999999999996,
#   1.9999999999999996,
#   1.9999999999999996,
#   1.9999999999999996),
#  ('T98826',
#   'T6331',
#   0.9999999837796435,
#   'A study on the effect of psychological empowerment on job satisfaction and job related Stress among the bank employees',
#   'A Study on the effect of Psychological Empowerment on Job Satisfaction and Job Related Stress among the bank employees'): (5.308188785800726,
#   6.0,
#   5.41566091954023,
#   6.0),
#  ('T44860',
#   'T19825',
#   0.990210760389196,
#   'Environmentally-efficient development management system for greater Kochi in Kerala state',
#   'Environmentally efficient development management system for greater kochi in kerala state'): (5.2666666666666675,
#   6.0,
#   5.499235800605664,
#   5.864494631617919),
#  ('T171208',
#   'T56225',
#   0.9962241083050429,
#   'A study of Credit Guarantee fund Trust for Micro and Small Enterprises with particular reference to Bank of Baroda in state of Kerala (2010-02-01)',
#   'A study of Credit Guarantee fund Trust for Micro and Small Enterprises with particular reference to Bank of Baroda in state of Kerala (2010-08-16)'): (5.852314721494322,
#   5.852314721494322,
#   5.87576103500761,
#   5.87576103500761),
#  ('T168041',
#   'T163390',
#   0.9999999813506867,
#   'Fostering Independent Learning in the open Curriculum a case for Literary studies',
#   'Fostering Independent Learning in the open Curriculum a case for Literary Studies'): (5.071428571428571,
#   6.0,
#   5.071428571428571,
#   6.0),
#  ('T141093',
#   'T8706',
#   0.9999999409989134,
#   'Jhansi jelleme Gramin shramik rojgar guarantee yojana: ek mulyankan',
#   'Gramin shramik rojgar guarantee yojana: ek mulyankan'): (4.851021091396049,
#   4.851021091396049,
#   4.834498834498834,
#   4.834498834498834),
#  ('T102695',
#   'T189413',
#   1.0000000301332694,
#   'Synthesis and Characterization of Some Novel Organotin Compounds',
#   'Synthesis and Characterization of Some Novel Lanthanide Compounds'): (3.729482342754655,
#   3.729482342754655,
#   3.837179487179487,
#   3.837179487179487),
#  ('T154465',
#   'T8733',
#   0.9937009573336023,
#   'Impact of global recession on Indian banking sector',
#   'The impact of global recession on Indian Banking Sector'): (4.007020872865275,
#   5.1005692599620485,
#   3.94230227976358,
#   4.922600619195046),
#  ('T63837',
#   'T55871',
#   1.000000028480651,
#   'Kannada chalanachitrarangakke Nagathihalli Chandrashekarravara koduge ondu adhyayana',
#   'Kannada chalanachitrarangakke Shankaranag kodige ondu adhyayana'): (3.3419230769230763,
#   3.515,
#   3.445584747308885,
#   3.606641123882503),
#  ('T154405',
#   'T127317',
#   0.9999999603481028,
#   'Dharshanikaraagi Dr B R Ambedkar ondu vishleshanaatmaka adhyayana',
#   'Dr B R Ambedkar ravara nayakatwa mattu rajakiya chintate ondu adhyayana'): (3.1537439239745857,
#   3.1537439239745857,
#   3.1174825174825176,
#   3.1174825174825176),
#  ('T32036',
#   'T152696',
#   1.0000001017250424,
#   'Shriramkeertimahakavyam ka bhashik addhyayana',
#   'Gangeya mahakavya ka bhashik addhyayana'): (2.870441153049849,
#   2.870441153049849,
#   2.8151424287856077,
#   2.8151424287856077),
#  ('T38455',
#   'T145841',
#   1.0000000649693233,
#   'Paniniya dhatupathasth hinsarthak dhatuon ka bhashashastriya addhyayana',
#   'Paniniya dhatupathasth sananarthak dhatuon ka vivechanatmak addhyayan'): (4.000081314034802,
#   4.000081314034802,
#   4.159447821681864,
#   4.159447821681864),
#  ('T181162',
#   'T43583',
#   0.9999999780629568,
#   'Indias trade relations with china since 1995 problems and prospects',
#   'Indias trade relations with China since 1995 problems and prospects'): (5.726153846153847,
#   6.0,
#   5.763218390804599,
#   6.0),
#  ('T121235',
#   'T126824',
#   0.9996042082476213,
#   'Studies on certain plant essential oils for their antifungal activity and inhibition of virulence factors in drug resistant fungi (2011-01-01)',
#   'Studies on certain plant essential oils for their antifungal activity and inhibition of virulence factors in drug resistant fungi (2012-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T34393',
#   'T146599',
#   0.9919197168567165,
#   'A comparative study of the nutritional status of children of working women factory based and home based, in the city of Aligarh',
#   'Comparative study of the nutritional status of children of working women_factory based and home based, in the city of Aligarh'): (5.886162232338995,
#   5.952335383914331,
#   5.601207670833839,
#   5.725743415463041),
#  ('T175888',
#   'T146599',
#   0.9956388113886636,
#   'A comparative study of the nutritional status of children of working women_factory based and home based in the city of Aligarh',
#   'Comparative study of the nutritional status of children of working women_factory based and home based, in the city of Aligarh'): (5.886162232338995,
#   5.952335383914331,
#   5.864314388120841,
#   5.919870967741936),
#  ('T175888',
#   'T34393',
#   0.9912212453448136,
#   'A comparative study of the nutritional status of children of working women_factory based and home based in the city of Aligarh',
#   'A comparative study of the nutritional status of children of working women factory based and home based, in the city of Aligarh'): (6.0,
#   6.0,
#   5.903659447348767,
#   5.903659447348767),
#  ('T10408',
#   'T193725',
#   0.9999999961214235,
#   'Insect pest management strategies in brassica campestris variety brown sarson with special reference to bio_ecological studies on potential predators of lipaphis erysimi kaltenbach',
#   'Insect pest management strategies in brassica campestris variety brown sarson with special reference to bio_ecologlcal studies on potential predators of lipaphis erysimi kaltenbach'): (5.863237872589129,
#   5.863237872589129,
#   5.879692446856625,
#   5.879692446856625),
#  ('T4376',
#   'T50518',
#   1.0000000735789933,
#   'Effect of intermittent exposures of sulphur dioxide on Alternaria blight of mustard caused by Alternaria brassicae or a brassicicola',
#   'Effect of intermittent exposures of sulphur dioxide on alternaria blight of mustard caused by alternaria brassicae or A brassicicola'): (5.836698858647937,
#   6.0,
#   5.857808857808858,
#   6.0),
#  ('T137226',
#   'T138867',
#   0.9959229727451759,
#   'Thematic study of Modern British women playwrights with special reference to gertrude jennings dodie smith and G B Stern',
#   'A thematic study of modern British women playwrights with special reference to Gertrude Jennings Dodie Smith and G B Stern'): (5.161837757168746,
#   5.9054806828391735,
#   5.223015873015873,
#   5.843253968253968),
#  ('T58806',
#   'T178830',
#   1.0000000206869473,
#   'Feminist perspectives in the fiction of suniti namjoshi',
#   'Feminist perspectives in the fiction of Suniti Namjoshi'): (5.071428571428571,
#   6.0,
#   5.129411764705882,
#   6.0),
#  ('T197838',
#   'T77630',
#   0.9956710959839772,
#   'Treatment of Christianity and paganism myth and folklore in the plays of John Millington Synge',
#   'Treatment of Christianity paganism myth and folklore in the plays of John Millington Synge'): (5.416012558869701,
#   5.416012558869701,
#   5.3001277139208165,
#   5.3001277139208165),
#  ('T171486',
#   'T184177',
#   0.999999919927428,
#   'Idea of America in select novels of John Updike',
#   'Idea of America in select Novels of John Updike'): (5.62280701754386,
#   6.0,
#   5.675324675324675,
#   6.0),
#  ('T171228',
#   'T2506',
#   0.9946291698289919,
#   'Expatriate concerns in the works of V S Naipaul',
#   'Expatriate Concern In the Works of V S NaiPaul'): (4.898538961038961,
#   5.820779220779221,
#   5.028769841269841,
#   5.843253968253968),
#  ('T141708',
#   'T138867',
#   0.9957935894693783,
#   'A thematic study of modern british women playwrights with special reference to gertrude jennings, Dodie Smith and G B Stern',
#   'A thematic study of modern British women playwrights with special reference to Gertrude Jennings Dodie Smith and G B Stern'): (5.6539092400218705,
#   6.0,
#   5.711077274457556,
#   6.0),
#  ('T141708',
#   'T137226',
#   0.9908987258599815,
#   'A thematic study of modern british women playwrights with special reference to gertrude jennings, Dodie Smith and G B Stern',
#   'Thematic study of Modern British women playwrights with special reference to gertrude jennings dodie smith and G B Stern'): (5.12142042863657,
#   5.8834473324213405,
#   5.187440568540113,
#   5.810595065312047),
#  ('T103019',
#   'T197838',
#   0.9939483482251795,
#   'Treatment of christianity and paganism, myth and folklore in the plays of John Millington Synge',
#   'Treatment of Christianity and paganism myth and folklore in the plays of John Millington Synge'): (5.4423076923076925,
#   6.0,
#   5.519047619047619,
#   6.0),
#  ('T45389',
#   'T78181',
#   0.9936905776058222,
#   'Indian English women novelists of the post_independence period with special reference to : Santha Rama Rao, Kamla Markandaya, Nayantara Sahgal and Anita Desai',
#   'Indian English women novelists of the post_independence period with special reference to Santha Rama Rao, Kamla Markandaya, Imayantara Sahgal and Anita Desai'): (5.556805807622505,
#   5.556805807622505,
#   5.73083778966132,
#   5.73083778966132),
#  ('T1049',
#   'T184242',
#   0.9999999790367949,
#   'Magic realism and gothic tradition in the novels of Angela Carter',
#   'Magic realism and Gothic tradition in the novels of Angela carter'): (5.3939393939393945,
#   6.0,
#   5.463703703703704,
#   6.0),
#  ('T73798',
#   'T66207',
#   0.9999999337648225,
#   'Mohan rakesh ke natya sahitya mein samajik yatarth',
#   'Mohan Rakesh ke natya sahitya mein samajik yatharth'): (4.945887445887445,
#   5.541125541125541,
#   5.0312151616499445,
#   5.579710144927536),
#  ('T175374',
#   'T52788',
#   0.9999999358616214,
#   'Hindi natay_kavya me samskrutik ev samajik chetana',
#   'Hindi natya_kavya me samskruthik ev samajik chethana'): (5.5632183908045985,
#   5.5632183908045985,
#   5.572916666666667,
#   5.572916666666667),
#  ('T57184',
#   'T128193',
#   1.0000000214574705,
#   'Swachhandtabadi kavya drashti aur aggeya ka kavya',
#   'Swachhandatawadi kavya drishti aur aggeya ka kavya'): (5.339787234042553,
#   5.339787234042553,
#   5.390145801910508,
#   5.390145801910508),
#  ('T87975',
#   'T44458',
#   0.9986853827773718,
#   'Linguistic study of basic Urdu vocabolary of Urdu speaking children of class V in Aligarh (2013-01-01)',
#   'Linguistic study of basic Urdu vocabolary of Urdu speaking children of class V in Aligarh (2012-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T23555',
#   'T81824',
#   0.9981659073149622,
#   'Morphological analysis of modern standard Urdu (2008-01-01)',
#   'Morphological analysis of modern standard Urdu (2010-01-01)'): (4.642857142857142,
#   4.642857142857142,
#   4.642857142857142,
#   4.642857142857142),
#  ('T83144',
#   'T117650',
#   0.996507204578332,
#   'Study of customer relationship marketing practices CRMP of Indian oil corporation IOC (2014-01-01)',
#   'Study of customer relationship marketing practices CRMP of Indian oil corporation IOC (2015-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T89384',
#   'T21865',
#   0.9957104086038149,
#   'Human resource policies and practices in hospitality industry in India: a case study of selected hotels',
#   'Human Resource policies and practices in hospitality industry in India a case study of selected hotels'): (4.928571428571429,
#   6.0,
#   5.071428571428571,
#   6.0),
#  ('T40561',
#   'T142444',
#   1.0000000110098062,
#   'Cost benefit analysis of planned urban development a case study of Aligarh',
#   'cost benefit analysis of planned urban development A case study of Aligarh'): (5.336363636363637,
#   6.0,
#   5.4423076923076925,
#   6.0),
#  ('T112345',
#   'T129965',
#   0.9933811342783849,
#   'Sustainability and development of water resources in U P With special reference to Bulandshahr district',
#   'Sustainability and developmewt of water resources in U P with special reference to Bulandshahr district'): (5.700280112044817,
#   5.838367346938775,
#   5.745977011494253,
#   5.863237872589129),
#  ('T142274',
#   'T67491',
#   0.9905379962185694,
#   'A critique of the various aspects of managerial economics, part 4',
#   'A critique of the various aspects of managerial economics part 5'): (5.853198653198654,
#   5.853198653198654,
#   5.875961538461539,
#   5.875961538461539),
#  ('T67489',
#   'T67491',
#   0.9987846556758441,
#   'A critique of the various aspects of managerial economics part 6',
#   'A critique of the various aspects of managerial economics part 5'): (5.853198653198654,
#   5.853198653198654,
#   5.875961538461539,
#   5.875961538461539),
#  ('T67489',
#   'T142274',
#   0.9914032912125961,
#   'A critique of the various aspects of managerial economics part 6',
#   'A critique of the various aspects of managerial economics, part 4'): (5.853198653198654,
#   5.853198653198654,
#   5.875961538461539,
#   5.875961538461539),
#  ('T67487',
#   'T67491',
#   0.9962287511214099,
#   'A critique of the various aspects of managerial economics part 2',
#   'A critique of the various aspects of managerial economics part 5'): (5.853198653198654,
#   5.853198653198654,
#   5.875961538461539,
#   5.875961538461539),
#  ('T67487',
#   'T142274',
#   0.9900697893855217,
#   'A critique of the various aspects of managerial economics part 2',
#   'A critique of the various aspects of managerial economics, part 4'): (5.853198653198654,
#   5.853198653198654,
#   5.875961538461539,
#   5.875961538461539),
#  ('T67487',
#   'T67489',
#   0.9961934774115311,
#   'A critique of the various aspects of managerial economics part 2',
#   'A critique of the various aspects of managerial economics part 6'): (5.853198653198654,
#   5.853198653198654,
#   5.875961538461539,
#   5.875961538461539),
#  ('T67488',
#   'T67491',
#   0.9953178297635438,
#   'A critique of the various aspects of managerial economics part 1',
#   'A critique of the various aspects of managerial economics part 5'): (5.853198653198654,
#   5.853198653198654,
#   5.875961538461539,
#   5.875961538461539),
#  ('T67488',
#   'T67489',
#   0.9951799381797867,
#   'A critique of the various aspects of managerial economics part 1',
#   'A critique of the various aspects of managerial economics part 6'): (5.853198653198654,
#   5.853198653198654,
#   5.875961538461539,
#   5.875961538461539),
#  ('T67488',
#   'T67487',
#   0.9977594406933921,
#   'A critique of the various aspects of managerial economics part 1',
#   'A critique of the various aspects of managerial economics part 2'): (5.853198653198654,
#   5.853198653198654,
#   5.875961538461539,
#   5.875961538461539),
#  ('T145398',
#   'T111619',
#   0.9919936505325714,
#   'Impact of FIIs on Indian Stock Market since 2000 (2014-01-01)',
#   'Impact of FIIs on Indian Stock Market since 2000 (2013-01-01)'): (4.761904761904762,
#   4.761904761904762,
#   4.761904761904762,
#   4.761904761904762),
#  ('T167120',
#   'T43380',
#   1.0000000445925512,
#   'Studies in the reclamation of lube oils',
#   'Studies in the reclamation of Lube Oils'): (4.45,
#   6.0,
#   4.6060606060606055,
#   6.0),
#  ('T81019',
#   'T12204',
#   1.0000000327002179,
#   'Design and performance investigation of nano scale SOI mosfets for low power GHz applications',
#   'Design and performance investigation of nano scale SOI Mosfets for low power GHz applications'): (5.79144385026738,
#   6.0,
#   5.818488529014846,
#   6.0),
#  ('T37614',
#   'T112123',
#   1.0000000176259318,
#   'Digital watermarking of multimedia data',
#   'Digital watermarking of Multimedia data'): (5.519047619047619,
#   6.0,
#   5.550000000000001,
#   6.0),
#  ('T27826',
#   'T105547',
#   1.0000001035583093,
#   'Ultra fast speed measurement by rotating magnetic field',
#   'Ultra fast speed measurement by Rotating Magnetic field'): (5.366459627329193,
#   6.0,
#   5.419130434782608,
#   6.0),
#  ('T143199',
#   'T178326',
#   0.9999998929589247,
#   'Chromatographic and Electroanalytical applications of newly prepared composite materials',
#   'Chromatographic and Electroanalytical applications of newly prepared composite Materials'): (5.2666666666666675,
#   6.0,
#   5.2666666666666675,
#   6.0),
#  ('T105811',
#   'T101472',
#   1.0000000132146472,
#   'Physico chemical studies on some corrosion inhibitors',
#   'Physico Chemical studies on some corrosion inhibitors'): (5.180555555555555,
#   6.0,
#   5.2666666666666675,
#   6.0),
#  ('T181535',
#   'T65362',
#   0.9901868066348426,
#   'Studies on some non_conventional adsorbents and their possible use in the removal of heavy metals and organic pollutants from wastewater',
#   'Studies On some non-conventional adsorbents and their Possible use in the removal of heavy metals and organic Pollutants from wastewater'): (5.711077274457556,
#   6.0,
#   5.742921686746988,
#   6.0),
#  ('T161095',
#   'T78073',
#   0.9910754764636297,
#   'Separation studies of organic and inorganic compounds',
#   'Separation studies of organic and inorganic compounds with surfactant_mediated eluents'): (4.002139495079161,
#   4.002139495079161,
#   4.030349531116794,
#   4.030349531116794),
#  ('T154700',
#   'T174253',
#   0.9928568647284163,
#   'Existence and it evative approximation of common solution of generalized equilibrium problems generalized variational inequality problems and fixed point problems',
#   'Existence and Iterative approximation of common solution of generalized equilibrium problems generalized variational inequality problems and fixed point problems'): (5.118055555555555,
#   5.514705882352941,
#   4.991803833909097,
#   5.3273115220483644),
#  ('T67433',
#   'T185751',
#   0.9981866576033723,
#   'A study of derivations in rings (2011-01-01)',
#   'A study of derivations in rings (2009-01-01)'): (3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684,
#   3.9682539682539684),
#  ('T50034',
#   'T18321',
#   0.9917692941960763,
#   'Integrability of functions represented by trigonometric series (1980-01-01)',
#   'Integrability of functions represented by trigonometric series (2001-01-01)'): (3.828282828282828,
#   3.828282828282828,
#   3.828282828282828,
#   3.828282828282828),
#  ('T189215',
#   'T169156',
#   0.9907005713213253,
#   'On certain problems in the theory of absolute summability of trigonometric series',
#   'On certain problems in the theory of intergrability of trigonometric series'): (4.433333333333334,
#   4.433333333333334,
#   4.4566948730711795,
#   4.4566948730711795),
#  ('T64894',
#   'T95968',
#   0.999999976687957,
#   'On some problems of hypergeometric polynomials',
#   'On some problems of hypergeometric Polynomials'): (5.3939393939393945,
#   6.0,
# ...
#   6.0),
#  ('T182419',
#   'T189608',
#   0.9926137233549032,
#   'Some problems on fixed point theorems (1987-06-30)',
#   'Some problems on fixed point theorem (1984-06-30)'): (4.85064935064935,
#   4.85064935064935,
#   4.944258639910814,
#   4.944258639910814),
#  ('T71040',
#   'T19502',
#   0.9949388206996591,
#   'Effects of different intensities of aerobic running on resting state blood glucose platelet count and plasma fibrinogen among type 2 diabetics',
#   'Effects of different intensities of aerobic running on resting state blood glucose platelet and plasma fibrinogen among type two diabetics'): (5.231959550676278,
#   5.231959550676278,
#   5.238039215686275,
#   5.238039215686275),
#  ('T100886',
#   'T73284',
#   0.9939044295405225,
#   'Comparative study of selected physical fitness components among rural and urban school boys',
#   'Comparative study of physical fitness components among rural and urban school boys'): (4.405594405594406,
#   4.405594405594406,
#   4.391273750879662,
#   4.391273750879662),
#  ('T173857',
#   'T146474',
#   0.993869895537745,
#   'The theme of quest in the novels of Paule Marshall (1994-09-30)',
#   'The theme of quest in the novels of Paule Marshall (2000-07-31)'): (2.213675213675214,
#   2.213675213675214,
#   2.213675213675214,
#   2.213675213675214),
#  ('T70286',
#   'T26120',
#   0.9969723977036611,
#   'The autobiographical element in the novels of M V Rama Sarma A study (2005-03-31)',
#   'The autobiographical element in the novels of M V Rama Sarma A study (2001-01-31)'): (3.6666666666666665,
#   3.6666666666666665,
#   3.6666666666666665,
#   3.6666666666666665),
#  ('T45001',
#   'T33517',
#   0.9946353138724012,
#   'Some studies on the effect of temperature on metabolic activity in a uni and a multicellular organism',
#   'Some studies on the effect of temperature on metabolic acitivity in a uni and a multicellular organism'): (5.868070175438596,
#   5.868070175438596,
#   5.888639200998751,
#   5.888639200998751),
#  ('T79917',
#   'T155503',
#   1.000000014395319,
#   'Biochemical and morphological alterations during cyclosporine A induced nephrotoxicity role of sulphated polysaccharides',
#   'Biochemical and morphological alterations during cyclosporine a induced nephrotoxicity role of sulphated polysaccharides'): (5.866835994194485,
#   6.0,
#   5.880479251899474,
#   6.0),
#  ('T144286',
#   'T34788',
#   0.9999999839530712,
#   'Poaceae in Rayalaseema Andhra Pradesh India',
#   'Cyperaceae in Andhra Pradesh India'): (2.2451086956521737,
#   2.835119047619048,
#   2.3402597402597403,
#   2.7889328063241106),
#  ('T154673',
#   'T34788',
#   1.0000000016137627,
#   'Poaceae in Andhra Pradesh India',
#   'Cyperaceae in Andhra Pradesh India'): (5.018640350877193,
#   5.235314091680816,
#   5.1323780794369025,
#   5.325145442792502),
#  ('T154673',
#   'T144286',
#   0.9999999839530712,
#   'Poaceae in Andhra Pradesh India',
#   'Poaceae in Rayalaseema Andhra Pradesh India'): (3.0413793103448272,
#   3.0413793103448272,
#   3.0681818181818183,
#   3.0681818181818183),
#  ('T199712',
#   'T99073',
#   1.000000008873941,
#   'Ethnobotany of Nellore district Andhra Pradesh India',
#   'Agrestals of Nellore district Andhra Pradesh India'): (1.0858585858585856,
#   1.316577540106952,
#   1.0858585858585856,
#   1.316577540106952),
#  ('T14295',
#   'T46176',
#   0.9953907065370327,
#   'Influence of salt stress on seed germination and seedling growth of some pulse crops',
#   'Influence of salt stress on seed germination and early seedling growth of some pulse crops'): (5.2747252747252755,
#   5.2747252747252755,
#   5.2567394094993585,
#   5.2567394094993585),
#  ('T91269',
#   'T43527',
#   0.9999999624865116,
#   'Flora of Adilabad district Andhra Pradesh India',
#   'Flora of Medak district Andhra Pradesh India'): (3.3259259259259255,
#   3.3259259259259255,
#   3.631309297912714,
#   3.631309297912714),
#  ('T67228',
#   'T123315',
#   0.9999999768225861,
#   'Selathu pudhu kavithaikal Oru aaivu',
#   'Mithravin pudhu kavithaigal Oru aaivu'): (3.4557894736842103,
#   3.4557894736842103,
#   3.6738816738816737,
#   3.6738816738816737),
#  ('T192846',
#   'T46184',
#   0.9999999482481381,
#   'Dharmapuri vattara nattupura padalgal oru aaivu',
#   'Dharmapuri mavatta nattupura padalgal oru aaivu'): (5.077205882352941,
#   5.077205882352941,
#   5.1307189542483655,
#   5.1307189542483655),
#  ('T57614',
#   'T57612',
#   0.995509694577934,
#   'A study on english teaching - Volume 2',
#   'A study on english teaching - Volume 1'): (5.73763440860215,
#   5.73763440860215,
#   5.786628733997155,
#   5.786628733997155),
#  ('T163465',
#   'T163467',
#   0.9970394622576881,
#   'A critical study of essay type examinations - Volume 2',
#   'A critical study of essay type examinations - Volume 1'): (5.820202020202021,
#   5.820202020202021,
#   5.850454227812718,
#   5.850454227812718),
#  ('T100564',
#   'T100563',
#   0.9943510598873931,
#   'An english vocabulary study - Volume 2',
#   'An english vocabulary study - Volume 1'): (5.745967741935484,
#   5.745967741935484,
#   5.786628733997155,
#   5.786628733997155),
#  ('T20600',
#   'T12225',
#   0.997829480510338,
#   'RISK OF METABOLIC SYNDROME IN LAW ENFORCEMENT PERSONNEL AND THE EFFECT OF DIET AND EXERCISE INTERVENTION ON THEIR ANTHROPOMETRIC MEASUREMENTS BIOCHEMICAL PARAMETERS AND BLOOD PRESSURE LEVELS (2016-08-20)',
#   'RISK OF METABOLIC SYNDROME IN LAW ENFORCEMENT PERSONNEL AND THE EFFECT OF DIET AND EXERCISE INTERVENTION ON THEIR ANTHROPOMETRIC MEASUREMENTS BIOCHEMICAL PARAMETERS AND BLOOD PRESSURE LEVELS (2017-09-08)'): (2.8333333333333335,
#   2.8333333333333335,
#   2.8333333333333335,
#   2.8333333333333335),
#  ('T149754',
#   'T63243',
#   0.9923495998548607,
#   'The socialist movement in india with special reference samajvadi party to and Mulayam singh yadav in Uttar Pradesh from 1989 2004',
#   'The socialist movement in India with special reference to samajvadi party and Mulayam singh yadav in Uttar Pradesh from 1989 se 2004'): (5.667257337717696,
#   5.767263427109974,
#   5.612371235354249,
#   5.698566878980892),
#  ('T45201',
#   'T121677',
#   0.9999999597676401,
#   'Political and Administrative Development In Rajputana 1930 Onwards With Special Reference to the Mewar State',
#   'Political And Administrative Development in Rajputana 1930 Onwards with special reference to the Mewar State'): (5.498341625207297,
#   6.0,
#   5.566728452270621,
#   6.0),
#  ('T82688',
#   'T125668',
#   0.9979181933657151,
#   'Developing new framework for face recognition systems (2015-01-01)',
#   'Developing new framework for face recognition systems (2015-04-01)'): (5.8608590441621295,
#   5.8608590441621295,
#   5.875961538461539,
#   5.875961538461539),
#  ('T149588',
#   'T64253',
#   0.99885221512515,
#   'Non specific and specific immunomodulatory efficacy of potential plant extracts in controlling major bacterial diseases in freshwater fish Labeo rohita (2010-08-01)',
#   'Non specific and specific immunomodulatory efficacy of potential plant extracts in controlling major bacterial diseases in freshwater fish Labeo rohita (2010-01-01)'): (5.943858957943465,
#   5.943858957943465,
#   5.950768764674695,
#   5.950768764674695),
#  ('T34830',
#   'T41164',
#   0.9942887535707009,
#   'A study on labour welfare practices in private spinning mills in tirunelveli district tamilnadu',
#   'A study on labour welfare practices in private spinning mills in tirunelveli district, tamilnadu'): (6.0,
#   6.0,
#   6.0,
#   6.0),
#  ('T52089',
#   'T177238',
#   1.000000078405603,
#   'Studies on medicinal plants in traditional healing arts of South India',
#   'Studies on medicinal plants in traditional healing Arts of south india'): (4.805921052631579,
#   6.0,
#   4.980861244019139,
#   6.0),
#  ('T95739',
#   'T56758',
#   0.995247125031898,
#   'Synthesis characterization acoustical and physic chemical properties of 1 3 4 oxadiazole and thiadiazole derivatives by ultrasound irradiation method and their biological activities',
#   'Synthesis characterization acoustical and Physico chemical properties of 1 3 4 oxadiazole and Thiadiazole derivatives by ultrasound irradiation Method and their biological activities'): (5.778755389303057,
#   5.9568592327213015,
#   5.806719768344279,
#   5.962377642218755),
#  ('T195317',
#   'T61167',
#   0.9943878443662492,
#   'Adsorption kinetics involving low cost carbon (2012-04-01)',
#   'Adsorption kinetics involving low cost carbon (2010-01-01)'): (3.6666666666666665,
#   3.6666666666666665,
#   3.6666666666666665,
#   3.6666666666666665),
#  ('T36165',
#   'T45013',
#   0.9938383773029258,
#   'Studies on phytopharmaceuticals (2011-01-01)',
#   'Studies on phytopharmaceuticals (2011-09-01)'): (5.797435897435897,
#   5.797435897435897,
#   5.8117386489479514,
#   5.8117386489479514),
#  ('T57725',
#   'T67158',
#   0.9999999845363233,
#   'Admissibility over function fields of p adic curves',
#   'Admissibility over function fields of P adic curves'): (5.3939393939393945,
#   6.0,
#   5.483516483516484,
#   6.0),
#  ('T30334',
#   'T187913',
#   0.9999998822628869,
#   'Development and characterisation of Biphasic calcium phosphate ceramic coatings on type 316L ss for orthopaedic application',
#   'Development and characterisation of Biphasic calcium phosphate ceramic coatings on type 316L SS for orthopaedic application'): (5.50191570881226,
#   6.0,
#   5.550000000000001,
#   6.0),
#  ('T135622',
#   'T27652',
#   0.999999978163835,
#   'Production purification and characterization of laccase from stereum ostrea',
#   'Production purification and characterization of hemicellulases from Pencillium janthinellum'): (2.351358695652174,
#   2.351358695652174,
#   2.6119601328903657,
#   2.6119601328903657),
#  ('T67983',
#   'T152529',
#   0.9918580933029544,
#   'Interactions between fungicides propiconazole and chlorothalonil and microorganisms in groundnut arachis hypogeae L soils',
#   'Interactions between fungicides and microorganisms in groundnut arachis hypogeae L soils'): (3.2842835130970727,
#   3.2842835130970727,
#   3.2427631578947373,
#   3.2427631578947373),
#  ('T47634',
#   'T135932',
#   1.0000000590718856,
#   'Studies of the religious sect founded by Shriman Nrusinhacharya its contribution towards the social and literary activities in Gujarat _Part_II_',
#   'Studies of the religious sect founded by Shriman Nrusinhacharya its contribution towards the social and literary activities in Gujarat _Part_I_'): (5.958982662079201,
#   5.958982662079201,
#   5.964513767951339,
#   5.964513767951339),
#  ('T164644',
#   'T35755',
#   1.000000001931626,
#   'Sant Nivruttinath _ a critical study',
#   'Sant Janabai _ a critical study'): (2.287962962962963,
#   2.287962962962963,
#   2.502269873466628,
#   2.502269873466628),
#  ('T110380',
#   'T200008',
#   0.9999999366506371,
#   'Eknathi Bhagvat _ ek chikitsak abhyas',
#   'Vyankatesh Madgulkar _ ek chikitsak abhyas'): (2.18066985645933,
#   2.5314471950627553,
#   2.2065934065934067,
#   2.545238095238095),
#  ('T119750',
#   'T153564',
#   1.0000000501874087,
#   'Pandharpurchi vaari ek samajshastriya abhyas',
#   'Shivdharm chalval ek samajshastriya abhyas'): (2.558823529411765,
#   2.558823529411765,
#   2.672397660818713,
#   2.672397660818713),
#  ('T105081',
#   'T118953',
#   0.998523327687753,
#   'Development of a multiskilling training module for caregivers in augmentative and alternative communication to enhance the language and communication skills of children with developmental disabilities',
#   'Development of multiskilling training module for caregivers in augmentative and alternative communication to enhance the language and communication skills of children with developmental disabilities'): (5.640211640211641,
#   5.640211640211641,
#   5.366666666666667,
#   5.366666666666667),
#  ('T43577',
#   'T1864',
#   1.000000025057215,
#   'Tourism potential of Ratnagiri district _ a geographical study',
#   'Tourism potential of Ratnagiri District _ a geographical study'): (5.736467236467237,
#   6.0,
#   5.770967741935484,
#   6.0),
#  ('T14135',
#   'T90152',
#   0.9975029659927311,
#   'Treatment of nature in medieval Oriya Kavya literature A comparative study with 17th 18th century English poetry',
#   'Treatment of nature in medieval Oriya Kavya literature A comparative study with 17th and 18th century English poetry'): (5.437908496732026,
#   5.437908496732026,
#   5.345939933259177,
#   5.345939933259177),
#  ('T79828',
#   'T118021',
#   1.0000000235658204,
#   'University finances A case study of Sambalpur University',
#   'University finances a case study of Utkal university'): (4.688677655307244,
#   4.753193784339502,
#   4.814241486068111,
#   4.925352597179222),
#  ('T149070',
#   'T4454',
#   1.0000000081112272,
#   'Studies on random fourier stielties series related to stochastic integrals and a class of random algebraic polynomial',
#   'Studies on random fourier Stieltjes series related to stochastic integrals and a class of random algebraic polynomial'): (5.500556173526141,
#   5.728735632183908,
#   5.559307359307359,
#   5.76114081996435),
#  ('T100965',
#   'T28836',
#   0.9999998784012101,
#   'The studies on homogenisation of dead burnt natural magnesites and its effect on the properties of magnesia refractories',
#   'Studies on the homogenisation of dead burnt natural magnesites and its effect on the properties of magnesia refractories'): (3.8452380952380953,
#   4.75,
#   3.7857142857142856,
#   4.571428571428571),
#  ('T138309',
#   'T172184',
#   1.0000000005300582,
#   'Studies on transition metal complexes',
#   'Studies on multinuclear transition metal complexes'): (2.914285714285714,
#   2.914285714285714,
#   2.951251646903821,
#   2.951251646903821),
#  ('T38480',
#   'T32918',
#   1.0000000004549372,
#   'A critical study of Bharavis Kiratarjuniyam',
#   'A critical study of antyesti Apara Samskara'): (2.160535588442565,
#   2.3968068819712767,
#   2.048913043478261,
#   2.272089761570827),
#  ('T38480',
#   'T199644',
#   1.0000000858404674,
#   'A critical study of Bharavis Kiratarjuniyam',
#   'A critical study of upanayana samskara'): (1.9582084582084582,
#   2.1126651126651126,
#   1.9940761326653744,
#   2.1438418421451297),
#  ('T38480',
#   'T156789',
#   1.0000000105238882,
#   'A critical study of Bharavis Kiratarjuniyam',
#   'A critical study of Kanthapuranam'): (2.4906926406926404,
#   2.4906926406926404,
#   2.4017391304347826,
#   2.4017391304347826),
#  ('T38480',
#   'T2805',
#   1.0000000105238882,
#   'A critical study of Bharavis Kiratarjuniyam',
#   'A critical study of Venisamhara'): (1.9924242424242424,
#   2.1725955204216074,
#   1.9194884910485932,
#   2.0916453537936914),
#  ('T38480',
#   'T115687',
#   1.0000000858404674,
#   'A critical study of Bharavis Kiratarjuniyam',
#   'A critical study of Vamanas Kavyalamkarasutravritti'): (2.5921568627450977,
#   2.5921568627450977,
#   2.6663594470046084,
#   2.6663594470046084),
#  ('T84811',
#   'T99216',
#   1.0000001397327007,
#   'Transcriptional Modulation and Antimicrobial Role of Immune Molecules during Infection with Aphanomyces Invadans in Striped Murrel',
#   'Transcriptional Modulation and Antimicrobial Role of Immune Molecules during Infection with Aphanomyces Invadans in Striped'): (5.7377329192546584,
#   5.7377329192546584,
#   5.729279416235938,
#   5.729279416235938),
#  ('T158953',
#   'T97206',
#   0.9913035844760625,
#   'Studies on the Bioefficacy of Essential oils and Isolated Compound in chosen Stored Product Pests Management (2014-02-02)',
#   'Studies on the Bioefficacy of Essential oils and Isolated Compound in chosen Stored Product Pests Management (2015-04-15)'): (2.1666666666666665,
#   2.1666666666666665,
#   2.1666666666666665,
#   2.1666666666666665),
#  ('T61842',
#   'T13286',
#   1.0000000262077604,
#   'Studies on interaction between a symiotic fungus piriformospora indica rhizobacteria and selected plants',
#   'Studies on Interaction between a symiotic fungus Piriformospora indica rhizobacteria and selected Plants'): (5.585557299843014,
#   6.0,
#   5.6358958837772395,
#   6.0),
#  ('T4550',
#   'T62468',
#   0.9933792461140617,
#   'Studies on interaction between a symbiotic fungus _Piriformospora indica_, rhizobacteria and selected plants',
#   'Studies on interaction between a symbiotic fungus _Piriformospora indica_ rhizobacteria and selected plants'): (6.0,
#   6.0,
#   6.0,
#   6.0),
#  ('T137913',
#   'T45895',
#   0.9932000589404552,
#   'PUNJABI SUBA AND THE SIKH STRUGGLE 1947 A D 1966 A D',
#   'PUNJABI SUBA AND THE SIKH STRUGGLE 1947 A D to 1966 A D'): (4.714285714285714,
#   4.714285714285714,
#   4.5933014354066986,
#   4.5933014354066986),
#  ...}

# %%
for a in tmp:
    if len([b for b in tmp[a] if b > 5.00]) >0:
        print(str(a)+":"+str(tmp[a]))
        print("\n")
# Out:
# ('T155527', 'T132833', 0.9928626803485257, 'Fabrication electrical and structural characterization of metal schottky contacts on n type indium phosphide inp', 'Fabrication electrical and structural caracterization of metal schottky contacts on n type indium phosphide inp'):(5.860719874804381, 5.860719874804381, 5.874683544303798, 5.874683544303798)
#
#
# ('T4865', 'T32989', 1.0000001429913685, 'Toxicity Evaluation and Hypoglycemic Activity Of Indigenous Medicinal Plants Of Gujarat', 'Toxicity Evaluation And Hypoglycemic Activity Of Indigenous Medicinal Plants Of Gujarat'):(5.642105263157895, 6.0, 5.675324675324675, 6.0)
#
#
# ('T82551', 'T91408', 0.9999999588854146, 'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS Gartn ELAEOCARPACEAE', 'THNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE'):(4.420805244603872, 5.735419630156472, 4.493589743589744, 5.748717948717949)
#
#
# ('T98000', 'T91408', 0.9999999588854146, 'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE', 'THNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE'):(5.9720513903885575, 5.9720513903885575, 5.975833713490308, 5.975833713490308)
#
#
# ('T98000', 'T82551', 0.9999999588854146, 'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS GARTN ELAEOCARPACEAE', 'ETHNOMEDICINAL SURVEY OF TRADITIONAL MEDICINAL PLANTS USED BY FOLK VILLAGE PEOPLES OF WESTERN GHATS SOUTHERN INDIA AND ASSESSMENT OF NUTRITIVE VALUES OF THE FRUITS OF ELEOCARPUS OBLONGUS Gartn ELAEOCARPACEAE'):(4.6060606060606055, 6.0, 4.672768878718536, 6.0)
#
#
# ('T46495', 'T157330', 0.9916515400222001, 'Ecological Studies of Chhatri Lake, Amravati with Special Reference to Planktons and Productivity', 'Ecological Studies of Chattri Lake Amravati With Special Reference to Planktons and Productivity'):(5.574108818011257, 5.746153846153846, 5.629787234042553, 5.779710144927536)
#
#
# ('T42449', 'T170278', 0.9964306260052318, 'Changing scenario of leadership in insurance sector a critical appraisal of life insurance Corporation of India and Bajaj Allianz', 'Changing scenario of leadership in insurance sector: a critical appraisal of Life Insurance Corporation of India and Bajaj Allianz'):(5.702898550724638, 6.0, 5.741337907375643, 6.0)
#
#
# ('T68665', 'T128696', 1.0000000596887995, 'simulation of energy and water exchange processes at vegetation atmosphere interface in rice ecosystem', 'Simulation of energy and water exchange processes at vegetation atmosphere interface in rice ecosystem'):(5.921847690387016, 6.0, 5.931753283837807, 6.0)
#
#
# ('T149608', 'T181467', 1.0000000119650503, 'studies on distribution of heavy metals in water sediment and biota in coastal areas of Sunderbans and its potential risk in the environment', 'Studies on distribution of heavy metals in water sediment and biota in coastal areas of Sunderbans and its potential risk in the environment'):(5.94096282580829, 6.0, 5.950202634245188, 6.0)
#
#
# ('T15114', 'T54922', 0.9917173174552896, 'Modes of production, distribution and reception of writings in womenâ\x80\x99s magazines: a study in critical discourse analysis', "Modes of production, distribution and reception of writings in women's Magazines: a study in critical discourse analysis"):(5.4649758454106285, 5.610463562544969, 5.53472093943792, 5.661721227758964)
#
#
# ('T89509', 'T126037', 0.996476095119744, 'Production Purification and Characterization of Broad Spectrum Antimicrobial Compound from Streptomyces sp and Improvement of the Strain', 'Production Purification and Characterization of a Broad Spectrum Antimicrobial Compound from Streptomyces sp and Improvement of the Strain'):(5.886102403343783, 5.886102403343783, 5.795068027210884, 5.795068027210884)
#
#
# ('T162114', 'T157692', 0.999093976002518, 'A Study on Service Quality and Customer Satisfaction in Paid Direct To Home Service Providers in Himachal Pradesh (2015-09-12)', 'A Study on Service Quality and Customer Satisfaction in Paid Direct To Home Service Providers in Himachal Pradesh (2015-09-19)'):(5.924880973373304, 5.924880973373304, 5.935741935483871, 5.935741935483871)
#
#
# ('T112537', 'T58192', 0.995786515048427, 'A study of hypolipidemic effect of linseed in the diet of cardiovascular patients', 'A study of Hypolipidemic effects of linseed in the diet of cardiovascular patients'):(5.5775190326914466, 5.820779220779221, 5.629689754689755, 5.843253968253968)
#
#
# ('T130659', 'T57222', 0.9942309771237955, 'Comparative study of nutrition in take beneficiary and non beneficiary pregnant rural women under ICDS Programme', 'Comparative study of nutrition in take beneficiary and non-beneficiary pregnant rural women under ICDS Programme'):(6.0, 6.0, 5.9072343371408795, 5.9072343371408795)
#
#
# ('T12467', 'T148346', 0.9905433624178327, 'Nutritional status of lactating mothers and composition of traditional supplimentary foods consumed by them', 'Nutritional status of lactating mothers and composition of traditional supplementary foods consumed by them'):(5.708994708994709, 5.708994708994709, 5.745967741935484, 5.745967741935484)
#
#
# ('T163626', 'T33925', 0.9909676647033986, 'A clinical study of the effect of different endotracheal tubes on the incidence of post operative laryngo trachities', 'A clinical study of the effect of different endotracheal tubes on the incidence of post- operative laryngo-tracheitis'):(5.94949494949495, 5.94949494949495, 5.082251082251083, 5.082251082251083)
#
#
# ('T91506', 'T62523', 0.9913979864017235, 'A clinical study of the effect of nifedipine as premedicant in pregnency induced hypertension', 'A clinical study of the effect of nifedipine as premedicant in pregnancy induced hypertension'):(5.659420289855072, 5.659420289855072, 5.686153846153847, 5.686153846153847)
#
#
# ('T175547', 'T78338', 1.000000006238747, 'Sapkotar kavita me bhavnatmakta avam sanvedansilta', 'Sapkotar kavita me bhavnatmakta avam sanveda'):(5.323809523809524, 5.323809523809524, 5.3923404255319145, 5.3923404255319145)
#
#
# ('T102592', 'T146365', 0.9939657105540515, 'A study of the effects of yogic exercises on physiological functions in young human volunteers', 'A study of the effects of yogic exercises on physiological functionas in young human volunteers'):(5.790780141843972, 5.790780141843972, 5.820779220779221, 5.820779220779221)
#
#
# ('T174521', 'T25434', 0.9953863944107052, 'Attenuation of the reflex response to laryngoscopy tracheal intubation with various drug combinations', 'Attenuation of the Reflex response to Laryngoscopy and tracheal intubation with various drug combinations'):(5.391629646948796, 5.678746785129764, 5.376678876678877, 5.626780626780627)
#
#
# ('T106676', 'T33661', 0.998759625860421, 'A study of fasting and post prandial lipoprotein profile in cerebrovascular disease, central nervous system infections and malignant disease', 'A study of fasting and post prandial lipoprotein profile in cerebrovascular disease, central nervous system infections and malignant diseases'):(5.958982662079201, 5.958982662079201, 5.96426011264721, 5.96426011264721)
#
#
# ('T104953', 'T151436', 0.990963511835238, 'The extended clinico-laboratory profile of the female partner of infertility in Bundelkhand Region', 'The extended clinico-laboratory profile of the male partner in infertility in Bundelkhand Region'):(5.430539436922416, 5.430539436922416, 5.496722160562339, 5.496722160562339)
#
#
# ('T99902', 'T151436', 0.993441175301568, 'The extended clinico-laboratory profile of the Male partner of infertility in Bundelkhand region', 'The extended clinico-laboratory profile of the male partner in infertility in Bundelkhand Region'):(5.333993072736269, 5.6361757105943155, 5.412398921832884, 5.679871948779512)
#
#
# ('T99902', 'T104953', 0.9980002598623925, 'The extended clinico-laboratory profile of the Male partner of infertility in Bundelkhand region', 'The extended clinico-laboratory profile of the female partner of infertility in Bundelkhand Region'):(5.475993982376961, 5.776767676767677, 5.536722160562338, 5.80313725490196)
#
#
# ('T38345', 'T67961', 0.9938215502437546, 'Tatanus in Bundelkhand region - its incidence and the role of intrathecal human antitetanus immunoglobulin in its treatment', 'Tatanus in Bundelkhand region its incidence and the role of intrathecal human antitetanus immunoglobulin in its treatment'):(6.0, 6.0, 5.8327683615819215, 5.8327683615819215)
#
#
# ('T135328', 'T136492', 0.9947646102529939, 'A study of childhood epilepsy and epileptic syndromes in a subset of population in India with emphasis on heriditary factors', 'A study of childhood epilepsy and epileptic syndromes in a subset of population in india with emphasis on hereditary factors'):(5.725225225225225, 5.7807807807807805, 5.758420441347271, 5.807200929152149)
#
#
# ('T165345', 'T168418', 0.999999942390977, 'To assess the value of fine needle aspiration gytology FNAG in dignosis of various tumours', 'To assess the value of fine needle aspiration gytology in dignosis of various tumours'):(5.323809523809524, 5.323809523809524, 5.2747252747252755, 5.2747252747252755)
#
#
# ('T43134', 'T177017', 0.9977598054080835, 'To test the reproducibility of changes induces in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals', 'To test the reproducibility of changes induced in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals'):(5.802439024390243, 5.802439024390243, 5.827937095282147, 5.827937095282147)
#
#
# ('T92578', 'T44992', 0.9943287394276069, 'A comparative study of Ca++ Channel blockers, ACE inhibitors and alpha blokers in patients of systemic hypertension', 'A comparative study of Ca++ channel blockers, ACE inhibitors and Alpha blockers in patients of systemic hypertension'):(5.702915750915751, 5.920507936507937, 5.746523645019885, 5.932340503769075)
#
#
# ('T73994', 'T183074', 1.0000000576966546, 'Supercondylar fracture of the Humerus: a conservative approach', 'Supracondylar fracture of the Humerus: a conservative approach'):(5.816161616161617, 5.816161616161617, 5.8371232152300365, 5.8371232152300365)
#
#
# ('T54529', 'T7840', 0.9935863426602032, 'Clinical profile of low body weight type- 2 diabetes mellitus in Bundelkhand region', 'Clinical profile of low body weight Type 2 Diabetes Mellitus in Bundelkhand region'):(5.495930232558139, 6.0, 5.559449866903283, 6.0)
#
#
# ('T165609', 'T7840', 1.000000033758923, 'Clinical profile of low body weight type 2 diabetes mellitus in Bundelkhand region', 'Clinical profile of low body weight Type 2 Diabetes Mellitus in Bundelkhand region'):(5.495930232558139, 6.0, 5.559449866903283, 6.0)
#
#
# ('T165609', 'T54529', 0.9935863426602032, 'Clinical profile of low body weight type 2 diabetes mellitus in Bundelkhand region', 'Clinical profile of low body weight type- 2 diabetes mellitus in Bundelkhand region'):(6.0, 6.0, 6.0, 6.0)
#
#
# ('T193203', 'T83665', 0.9999999802062829, 'Amniotic membrane transplantation for ocular surface disorders', 'Aminiotic amniotic membrane transplantation for ocular surface disorders'):(5.297393515575335, 5.297393515575335, 5.295190713101162, 5.295190713101162)
#
#
# ('T97128', 'T17763', 0.9925925668911967, 'A study of fasting ans post prandial lipoprotein profile in cerbrovascular disease, peripheral vascular disease, central nervous syastem infections and malignant diseases', 'A study of fasting and post prandial lipoprotein profile in Cerebrovascular disease, peripheral vascular disease, central nervous system infections and malignant diseases'):(5.743131868131869, 5.820202020202021, 5.777871148459384, 5.844645550527903)
#
#
# ('T16352', 'T100460', 0.9954132137273362, 'Effect of caffeine, stress, cold pressor test, and physical activity on blood pressure in middle aged hypertensive individuals', 'Effect of caffeome, stress, cold pressor test, and physical activity on blood pressure in middle aged hypertensive individuals'):(4.996078431372549, 4.996078431372549, 5.108359133126935, 5.108359133126935)
#
#
# ('T77636', 'T177993', 0.999999997630649, 'role of escharoclysis in management of deep burn', 'Role of escharoclysis in management of deep burn'):(5.831591173054588, 6.0, 5.855867346938775, 6.0)
#
#
# ('T27684', 'T177017', 0.9950053188747403, 'To test the reprodusibility of changes induced in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals', 'To test the reproducibility of changes induced in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals'):(5.542483660130719, 5.542483660130719, 5.609523809523809, 5.609523809523809)
#
#
# ('T27684', 'T43134', 0.9924000021481617, 'To test the reprodusibility of changes induced in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals', 'To test the reproducibility of changes induces in lipid lipoprotein profile after high cholesterol fat diet in healthy individuals'):(5.727439024390243, 5.727439024390243, 5.762719703977799, 5.762719703977799)
#
#
# ('T120742', 'T26852', 0.9901310014928723, 'Study of dermatogyphic in children with bronchil asthma, asthmatic bronchitis and bronchiolitis', 'Study of dermatogyphics in children with bronchial asthma, asthmatic bronchitis and bronchiolitis'):(5.766334440753045, 5.766334440753045, 5.795068027210884, 5.795068027210884)
#
#
# ('T198278', 'T131513', 0.9905898570886247, 'Studies on the synthesis and transformations of a few 2 3h and 3 2h furanones', 'Studies on the synthesis and transformations of a few 23h and 3 2H furanones'):(5.336363636363637, 6.0, 5.464288997150473, 5.7716701902748415)
#
#
# ('T90180', 'T124439', 0.9944850664895722, 'Role of transvaginal colour doppler in cases of primary infertility as compared with Endometrial Biopsy', 'Role of Transvaginal colour doppler in cases of primary infertility as compare with endometrial biopsy'):(5.1462870538415, 5.826981246218995, 5.266924518899936, 5.852502194907814)
#
#
# ('T121039', 'T87696', 0.9999998596462659, 'To study the serum lipoprotein changes after hysterectomy with or without oopherectomy', 'To study the serum lipoprotein changes after hysterectomy with or without oophaerectomy'):(5.437908496732026, 5.437908496732026, 5.437908496732026, 5.437908496732026)
#
#
# ('T11044', 'T153425', 0.9999999716892155, 'A study of Trichomes and their taxonomic significance in verbenacease and lamiaceae', 'A study of trichomes and their taxonomic significance in verbenaceae and lamiaceae'):(5.487198067632851, 5.781642512077294, 5.5775190326914466, 5.820779220779221)
#
#
# ('T92756', 'T5928', 1.0000000485846805, 'Bahrtiya rashtravad aur Dr Bhimrav Ambedkar ek vivechnatamak adyayan', 'Bhartiya rashtravad aur Dr Bhimrav Ambedkar ek vivechnatmak adhyayan'):(5.3047619047619055, 5.3047619047619055, 5.35, 5.35)
#
#
# ('T40742', 'T162599', 0.9903233007075557, 'Effect of sowing dates and stages of fruit harvest on seed yield and quality of cucumber Cocumis sativus L CV Swarn Ageti', 'Effect of sowing dates and stages of fruit harvest on seed yield and quality of cucumber Cucumis sativus L CV Swarn Ageti'):(5.698005698005698, 5.698005698005698, 5.745967741935484, 5.745967741935484)
#
#
# ('T98826', 'T6331', 0.9999999837796435, 'A study on the effect of psychological empowerment on job satisfaction and job related Stress among the bank employees', 'A Study on the effect of Psychological Empowerment on Job Satisfaction and Job Related Stress among the bank employees'):(5.308188785800726, 6.0, 5.41566091954023, 6.0)
#
#
# ('T44860', 'T19825', 0.990210760389196, 'Environmentally-efficient development management system for greater Kochi in Kerala state', 'Environmentally efficient development management system for greater kochi in kerala state'):(5.2666666666666675, 6.0, 5.499235800605664, 5.864494631617919)
#
#
# ('T171208', 'T56225', 0.9962241083050429, 'A study of Credit Guarantee fund Trust for Micro and Small Enterprises with particular reference to Bank of Baroda in state of Kerala (2010-02-01)', 'A study of Credit Guarantee fund Trust for Micro and Small Enterprises with particular reference to Bank of Baroda in state of Kerala (2010-08-16)'):(5.852314721494322, 5.852314721494322, 5.87576103500761, 5.87576103500761)
#
#
# ('T168041', 'T163390', 0.9999999813506867, 'Fostering Independent Learning in the open Curriculum a case for Literary studies', 'Fostering Independent Learning in the open Curriculum a case for Literary Studies'):(5.071428571428571, 6.0, 5.071428571428571, 6.0)
#
#
# ('T154465', 'T8733', 0.9937009573336023, 'Impact of global recession on Indian banking sector', 'The impact of global recession on Indian Banking Sector'):(4.007020872865275, 5.1005692599620485, 3.94230227976358, 4.922600619195046)
#
#
# ('T181162', 'T43583', 0.9999999780629568, 'Indias trade relations with china since 1995 problems and prospects', 'Indias trade relations with China since 1995 problems and prospects'):(5.726153846153847, 6.0, 5.763218390804599, 6.0)
#
#
# ('T34393', 'T146599', 0.9919197168567165, 'A comparative study of the nutritional status of children of working women factory based and home based, in the city of Aligarh', 'Comparative study of the nutritional status of children of working women_factory based and home based, in the city of Aligarh'):(5.886162232338995, 5.952335383914331, 5.601207670833839, 5.725743415463041)
#
#
# ('T175888', 'T146599', 0.9956388113886636, 'A comparative study of the nutritional status of children of working women_factory based and home based in the city of Aligarh', 'Comparative study of the nutritional status of children of working women_factory based and home based, in the city of Aligarh'):(5.886162232338995, 5.952335383914331, 5.864314388120841, 5.919870967741936)
#
#
# ('T175888', 'T34393', 0.9912212453448136, 'A comparative study of the nutritional status of children of working women_factory based and home based in the city of Aligarh', 'A comparative study of the nutritional status of children of working women factory based and home based, in the city of Aligarh'):(6.0, 6.0, 5.903659447348767, 5.903659447348767)
#
#
# ('T10408', 'T193725', 0.9999999961214235, 'Insect pest management strategies in brassica campestris variety brown sarson with special reference to bio_ecological studies on potential predators of lipaphis erysimi kaltenbach', 'Insect pest management strategies in brassica campestris variety brown sarson with special reference to bio_ecologlcal studies on potential predators of lipaphis erysimi kaltenbach'):(5.863237872589129, 5.863237872589129, 5.879692446856625, 5.879692446856625)
#
#
# ('T4376', 'T50518', 1.0000000735789933, 'Effect of intermittent exposures of sulphur dioxide on Alternaria blight of mustard caused by Alternaria brassicae or a brassicicola', 'Effect of intermittent exposures of sulphur dioxide on alternaria blight of mustard caused by alternaria brassicae or A brassicicola'):(5.836698858647937, 6.0, 5.857808857808858, 6.0)
#
#
# ('T137226', 'T138867', 0.9959229727451759, 'Thematic study of Modern British women playwrights with special reference to gertrude jennings dodie smith and G B Stern', 'A thematic study of modern British women playwrights with special reference to Gertrude Jennings Dodie Smith and G B Stern'):(5.161837757168746, 5.9054806828391735, 5.223015873015873, 5.843253968253968)
#
#
# ('T58806', 'T178830', 1.0000000206869473, 'Feminist perspectives in the fiction of suniti namjoshi', 'Feminist perspectives in the fiction of Suniti Namjoshi'):(5.071428571428571, 6.0, 5.129411764705882, 6.0)
#
#
# ('T197838', 'T77630', 0.9956710959839772, 'Treatment of Christianity and paganism myth and folklore in the plays of John Millington Synge', 'Treatment of Christianity paganism myth and folklore in the plays of John Millington Synge'):(5.416012558869701, 5.416012558869701, 5.3001277139208165, 5.3001277139208165)
#
#
# ('T171486', 'T184177', 0.999999919927428, 'Idea of America in select novels of John Updike', 'Idea of America in select Novels of John Updike'):(5.62280701754386, 6.0, 5.675324675324675, 6.0)
#
#
# ('T171228', 'T2506', 0.9946291698289919, 'Expatriate concerns in the works of V S Naipaul', 'Expatriate Concern In the Works of V S NaiPaul'):(4.898538961038961, 5.820779220779221, 5.028769841269841, 5.843253968253968)
#
#
# ('T141708', 'T138867', 0.9957935894693783, 'A thematic study of modern british women playwrights with special reference to gertrude jennings, Dodie Smith and G B Stern', 'A thematic study of modern British women playwrights with special reference to Gertrude Jennings Dodie Smith and G B Stern'):(5.6539092400218705, 6.0, 5.711077274457556, 6.0)
#
#
# ('T141708', 'T137226', 0.9908987258599815, 'A thematic study of modern british women playwrights with special reference to gertrude jennings, Dodie Smith and G B Stern', 'Thematic study of Modern British women playwrights with special reference to gertrude jennings dodie smith and G B Stern'):(5.12142042863657, 5.8834473324213405, 5.187440568540113, 5.810595065312047)
#
#
# ('T103019', 'T197838', 0.9939483482251795, 'Treatment of christianity and paganism, myth and folklore in the plays of John Millington Synge', 'Treatment of Christianity and paganism myth and folklore in the plays of John Millington Synge'):(5.4423076923076925, 6.0, 5.519047619047619, 6.0)
#
#
# ('T45389', 'T78181', 0.9936905776058222, 'Indian English women novelists of the post_independence period with special reference to : Santha Rama Rao, Kamla Markandaya, Nayantara Sahgal and Anita Desai', 'Indian English women novelists of the post_independence period with special reference to Santha Rama Rao, Kamla Markandaya, Imayantara Sahgal and Anita Desai'):(5.556805807622505, 5.556805807622505, 5.73083778966132, 5.73083778966132)
#
#
# ('T1049', 'T184242', 0.9999999790367949, 'Magic realism and gothic tradition in the novels of Angela Carter', 'Magic realism and Gothic tradition in the novels of Angela carter'):(5.3939393939393945, 6.0, 5.463703703703704, 6.0)
#
#
# ('T73798', 'T66207', 0.9999999337648225, 'Mohan rakesh ke natya sahitya mein samajik yatarth', 'Mohan Rakesh ke natya sahitya mein samajik yatharth'):(4.945887445887445, 5.541125541125541, 5.0312151616499445, 5.579710144927536)
#
#
# ('T175374', 'T52788', 0.9999999358616214, 'Hindi natay_kavya me samskrutik ev samajik chetana', 'Hindi natya_kavya me samskruthik ev samajik chethana'):(5.5632183908045985, 5.5632183908045985, 5.572916666666667, 5.572916666666667)
#
#
# ('T57184', 'T128193', 1.0000000214574705, 'Swachhandtabadi kavya drashti aur aggeya ka kavya', 'Swachhandatawadi kavya drishti aur aggeya ka kavya'):(5.339787234042553, 5.339787234042553, 5.390145801910508, 5.390145801910508)
#
#
# ('T89384', 'T21865', 0.9957104086038149, 'Human resource policies and practices in hospitality industry in India: a case study of selected hotels', 'Human Resource policies and practices in hospitality industry in India a case study of selected hotels'):(4.928571428571429, 6.0, 5.071428571428571, 6.0)
#
#
# ('T40561', 'T142444', 1.0000000110098062, 'Cost benefit analysis of planned urban development a case study of Aligarh', 'cost benefit analysis of planned urban development A case study of Aligarh'):(5.336363636363637, 6.0, 5.4423076923076925, 6.0)
#
#
# ('T112345', 'T129965', 0.9933811342783849, 'Sustainability and development of water resources in U P With special reference to Bulandshahr district', 'Sustainability and developmewt of water resources in U P with special reference to Bulandshahr district'):(5.700280112044817, 5.838367346938775, 5.745977011494253, 5.863237872589129)
#
#
# ('T142274', 'T67491', 0.9905379962185694, 'A critique of the various aspects of managerial economics, part 4', 'A critique of the various aspects of managerial economics part 5'):(5.853198653198654, 5.853198653198654, 5.875961538461539, 5.875961538461539)
#
#
# ('T67489', 'T67491', 0.9987846556758441, 'A critique of the various aspects of managerial economics part 6', 'A critique of the various aspects of managerial economics part 5'):(5.853198653198654, 5.853198653198654, 5.875961538461539, 5.875961538461539)
#
#
# ('T67489', 'T142274', 0.9914032912125961, 'A critique of the various aspects of managerial economics part 6', 'A critique of the various aspects of managerial economics, part 4'):(5.853198653198654, 5.853198653198654, 5.875961538461539, 5.875961538461539)
#
#
# ('T67487', 'T67491', 0.9962287511214099, 'A critique of the various aspects of managerial economics part 2', 'A critique of the various aspects of managerial economics part 5'):(5.853198653198654, 5.853198653198654, 5.875961538461539, 5.875961538461539)
#
#
# ('T67487', 'T142274', 0.9900697893855217, 'A critique of the various aspects of managerial economics part 2', 'A critique of the various aspects of managerial economics, part 4'):(5.853198653198654, 5.853198653198654, 5.875961538461539, 5.875961538461539)
#
#
# ('T67487', 'T67489', 0.9961934774115311, 'A critique of the various aspects of managerial economics part 2', 'A critique of the various aspects of managerial economics part 6'):(5.853198653198654, 5.853198653198654, 5.875961538461539, 5.875961538461539)
#
#
# ('T67488', 'T67491', 0.9953178297635438, 'A critique of the various aspects of managerial economics part 1', 'A critique of the various aspects of managerial economics part 5'):(5.853198653198654, 5.853198653198654, 5.875961538461539, 5.875961538461539)
#
#
# ('T67488', 'T67489', 0.9951799381797867, 'A critique of the various aspects of managerial economics part 1', 'A critique of the various aspects of managerial economics part 6'):(5.853198653198654, 5.853198653198654, 5.875961538461539, 5.875961538461539)
#
#
# ('T67488', 'T67487', 0.9977594406933921, 'A critique of the various aspects of managerial economics part 1', 'A critique of the various aspects of managerial economics part 2'):(5.853198653198654, 5.853198653198654, 5.875961538461539, 5.875961538461539)
#
#
# ('T167120', 'T43380', 1.0000000445925512, 'Studies in the reclamation of lube oils', 'Studies in the reclamation of Lube Oils'):(4.45, 6.0, 4.6060606060606055, 6.0)
#
#
# ('T81019', 'T12204', 1.0000000327002179, 'Design and performance investigation of nano scale SOI mosfets for low power GHz applications', 'Design and performance investigation of nano scale SOI Mosfets for low power GHz applications'):(5.79144385026738, 6.0, 5.818488529014846, 6.0)
#
#
# ('T37614', 'T112123', 1.0000000176259318, 'Digital watermarking of multimedia data', 'Digital watermarking of Multimedia data'):(5.519047619047619, 6.0, 5.550000000000001, 6.0)
#
#
# ('T27826', 'T105547', 1.0000001035583093, 'Ultra fast speed measurement by rotating magnetic field', 'Ultra fast speed measurement by Rotating Magnetic field'):(5.366459627329193, 6.0, 5.419130434782608, 6.0)
#
#
# ('T143199', 'T178326', 0.9999998929589247, 'Chromatographic and Electroanalytical applications of newly prepared composite materials', 'Chromatographic and Electroanalytical applications of newly prepared composite Materials'):(5.2666666666666675, 6.0, 5.2666666666666675, 6.0)
#
#
# ('T105811', 'T101472', 1.0000000132146472, 'Physico chemical studies on some corrosion inhibitors', 'Physico Chemical studies on some corrosion inhibitors'):(5.180555555555555, 6.0, 5.2666666666666675, 6.0)
#
#
# ('T181535', 'T65362', 0.9901868066348426, 'Studies on some non_conventional adsorbents and their possible use in the removal of heavy metals and organic pollutants from wastewater', 'Studies On some non-conventional adsorbents and their Possible use in the removal of heavy metals and organic Pollutants from wastewater'):(5.711077274457556, 6.0, 5.742921686746988, 6.0)
#
#
# ('T154700', 'T174253', 0.9928568647284163, 'Existence and it evative approximation of common solution of generalized equilibrium problems generalized variational inequality problems and fixed point problems', 'Existence and Iterative approximation of common solution of generalized equilibrium problems generalized variational inequality problems and fixed point problems'):(5.118055555555555, 5.514705882352941, 4.991803833909097, 5.3273115220483644)
#
#
# ('T64894', 'T95968', 0.999999976687957, 'On some problems of hypergeometric polynomials', 'On some problems of hypergeometric Polynomials'):(5.3939393939393945, 6.0, 5.3939393939393945, 6.0)
#
#
# ('T152337', 'T139497', 0.9999999329027889, 'Putative anticancer mechanisms of Plant derived polyphenolic compounds', 'Putative anticancer mechanisms of plant derived polyphenolic compounds'):(5.778225806451613, 6.0, 5.803174603174604, 6.0)
#
#
# ('T48255', 'T68507', 0.9953491828536627, 'A study on the role of reactive oxygen species and its scavengers on osteoporosis', 'Study on the role of reactive Oxygen species and its scavengers on Osteoporosis'):(5.3413436029097126, 5.868070175438596, 5.33080808080808, 5.776767676767677)
#
#
# ('T6922', 'T15537', 0.9907974365707838, 'Immunochemical studies on peroxynitrite damaged human serum albumin: possible role in cancer', 'Immunochemical studies on peroxynitrite damaged human serum albumin Possible role in cancer'):(5.65952380952381, 6.0, 5.702898550724638, 6.0)
#
#
# ('T17255', 'T9869', 1.0, 'Immobilization and stabilization of enzymes: role of polyclonal and epitope_specific antibodies', 'Immobilization and stabilization of enzymes : role of polyclonal and epitope_specific antibodies'):(6.0, 6.0, 5.886102403343783, 5.886102403343783)
#
#
# ('T139217', 'T138570', 1.0000000848661008, 'Evaluation of mutants of linium species linseed developed through gamma rays and chemical mutagens', 'Evaluation of Mutants of Linum species Linseed developed through Gamma rays and chemical Mutagens'):(5.389994397759104, 5.920507936507937, 5.4708065356152265, 5.931412376003779)
#
#
# ('T114362', 'T100518', 0.9999999812241099, 'Effect of city wastewater on mustard Brassica juncea L Czern and Coss', 'Effect of city wastewater on mustard Brassica juncea L czern and coss'):(4.928571428571429, 6.0, 5.071428571428571, 6.0)
#
#
# ('T97763', 'T128846', 1.000000006861283, 'Studies on interaction of some air pollutants, Sphaerotheca fuliginea and Meloidogyne javanica on cucumber', 'Studies on interaction of some air pollutants, sphaerotheca fuliginea and Meloidogyne javanica on cucumber'):(5.827439024390244, 6.0, 5.852836879432624, 6.0)
#
#
# ('T161553', 'T50159', 1.0000001008720132, 'Establishment of dose dependent responses of brassinosteroids and proline against salinity stress in Brassica juncea', 'Establishment of dose dependent responses of Brassinosteroids and Proline against salinity stress in Brassica juncea'):(5.767157543762156, 6.0, 5.794505732208523, 6.0)
#
#
# ('T176284', 'T131364', 0.9999999517504876, 'Saur janjati ke samajik avem arthik star utstham me panchayati raj ki bhumika- ek samajshastriya adyanan', 'Saur janjati ke samajik avem arthik star utstham me panchayati raj ki bhumika ek samajshastriya adyanan'):(6.0, 6.0, 6.0, 6.0)
#
#
# ('T15006', 'T80900', 0.9999999547560259, 'Home and school environment as determinants of aggression and self concept of advantaged and disadvantaged school children', 'Home and School Environment as determinants of aggression and self concept of advantaged and disadvantaged School Children'):(5.071428571428571, 6.0, 5.180555555555555, 6.0)
#
#
# ('T31953', 'T195345', 0.992396372758533, 'A comparative study of job satisfaction as a function of organizational commitment, personality type and self_concept of bank employees of Iran and India', 'Comparative study of job satisfaction as a function of organizational commitment personality type and self concept of bank employees of Iran and India'):(5.907274199573539, 5.9612101468947, 5.719449837858718, 5.82560917343526)
#
#
# ('T163654', 'T176130', 0.9929125496171838, 'Sources of stress, perceived impact, management styles amongst individuals experiencing sense of well_being', 'Sources of stress, perceived impact, managenent styles amongst individuals experiencing sense of well_being'):(5.786628733997155, 5.786628733997155, 5.8117386489479514, 5.8117386489479514)
#
#
# ('T93367', 'T40027', 0.9999999690898559, 'A study of some socio_cultural factors in hysteria with special reference to case _ studies from Indian life, vol_I', 'A study of some socio_cultural factors in hysteria with special reference to case _ studies from Indian life, vol_II'):(5.946751621344863, 5.946751621344863, 5.955317104420244, 5.955317104420244)
#
#
# ('T68110', 'T171551', 0.9999999093662749, 'Impact of parenting practice and coping behaviour on adjustment pattern among adolescents', 'Impact of Parenting practice and coping behaviour on adjustment pattern among adolescents'):(5.2666666666666675, 6.0, 5.3939393939393945, 6.0)
#
#
# ('T131615', 'T177021', 0.9949997348396047, 'Impact of meditation and cognitive intervention in alleviating problems of individual high on neuroticism', 'Impact of meditation and cognitive intervention in alleviating the problems of individuals high on neuroticism'):(5.507191994996873, 5.507191994996873, 5.462108534544584, 5.462108534544584)
#
#
# ('T74412', 'T170219', 0.9999999329866822, 'Kashmir conflict and the role of national conference', 'Kashmir conflict and the role of National conference'):(5.62280701754386, 6.0, 5.642105263157895, 6.0)
#
#
# ('T185035', 'T67933', 1.0000000154848652, 'Judicial activism and protection of human rights', 'Judicial activism and protection of Human rights'):(5.3939393939393945, 6.0, 5.4423076923076925, 6.0)
#
#
# ('T1922', 'T43639', 0.9999999995035701, 'Problems and prospects of the negotiated settlement of Sino_Indian border dispute', 'Problems and prospects of the negotiated settlement of sinoIndian border dispute'):(5.702898550724638, 6.0, 5.726153846153847, 6.0)
#
#
# ('T150612', 'T53152', 0.9934328405236401, 'The U S Policy towards Latin America _ a study of co_operation and conflict _1958_1982', 'The U S policy towards Latin America: a study of co_operation and conflict _1958_1982_'):(4.928571428571429, 6.0, 5.679202634501841, 5.864494631617919)
#
#
# ('T116725', 'T175550', 1.000000041057429, 'Comparative study of selected coordinative abilities of male combative athletes belonging to uttar pradesh and uttarakhand state police', 'Comparative study of Selected coordinative abilities of male combative athletes belonging to Uttar Pradesh and Uttarakhand state police'):(5.519047619047619, 6.0, 5.577205882352941, 6.0)
#
#
# ('T113122', 'T192560', 0.9999999610841508, 'A study of physical and physiological differences between elite middle and long distance runners of India', 'A study of physical and physiological differences between Elite middle and long distance runners of India'):(5.827439024390244, 6.0, 5.852836879432624, 6.0)
#
#
# ('T4237', 'T16028', 1.0000000178215913, 'Freedom of press in a democratic society the case of India', 'Freedom of Press in a Democratic society The case of India'):(5.3758928571428575, 6.0, 5.495930232558139, 6.0)
#
#
# ('T57247', 'T42341', 0.9934677994434069, 'Diversity and distribution of herbaceous flora of high altitude grasslands at Bandipora, Kashmir', 'Diversity and distribution of herbaceous flora of high altitude grasslands at bandipora kashmir'):(5.180555555555555, 6.0, 5.226006191950464, 6.0)
#
#
# ('T2218', 'T111155', 0.9999999832275186, 'The influence of Hindu scriptures on the writings of henry David thoreau', 'The influence of Hindu scriptures on the writings of Henry David Thoreau'):(5.226006191950464, 6.0, 5.303258145363408, 6.0)
#
#
# ('T145234', 'T101071', 0.999999934573258, 'The theme of quest in the novels of Saul bellow', 'The theme of quest in the novels of saul bellow'):(5.336363636363637, 6.0, 5.3939393939393945, 6.0)
#
#
# ('T194093', 'T20071', 0.9903217280159061, 'Theodore Dreiser and the city a study of ambivalent response', 'Theodore dreiser and the city a study ambivalent response'):(5.419293924466339, 5.652709359605911, 5.3158221559860905, 5.5266393442622945)
#
#
# ('T31837', 'T157178', 0.990289249746719, 'Studies of the nutritive values of certain non cultivated edible herbs', 'Studies of the nutritive values of certain non-cultivated edible herbs'):(6.0, 6.0, 5.790780141843972, 5.790780141843972)
#
#
# ('T5339', 'T139636', 0.992295137784846, 'Studies on plant regeneration from in vitro cultures and agrobacterium mediated genetic transformation of grasspea lathyrus Sativus L', 'Studies on plant regeneration from in vitro cultures and Agrobacterium Mediated genertic transformation of grasspea Lathyrus Sativus L'):(5.631219365986107, 5.927430445361261, 5.66881631440455, 5.934980052627111)
#
#
# ('T88053', 'T51715', 0.9982853547265115, 'Studies on factors influencing susceptibility or resistance of rice varieties to sheath blight disease with special reference to biochemical factors', 'Studies on factors influencing susceptibility or resistance of rice varieties to sheath blight disease with special reference to biochemical factor'):(5.9612101468947, 5.9612101468947, 5.966193311956023, 5.966193311956023)
#
#
# ('T185968', 'T55773', 0.9999999301612719, 'Physiological studies on rice oryza sativa L under upland and drought conditions', 'Physiological studies on Rice Oryza Sativa L under upland and drought conditions'):(5.3758928571428575, 6.0, 5.456756756756757, 6.0)
#
#
# ('T102186', 'T20222', 0.9999999983081802, 'Information needs of different communities a survey in the Puri district of Orissa', 'Information needs of different communities a survey in the Puri District of Orissa'):(5.577205882352941, 6.0, 5.62280701754386, 6.0)
#
#
# ('T50246', 'T138924', 0.9909627545039117, 'Responses of herbaceous dicot leaves to synthetic growth regulating substance', 'Responses of herbaceous dicot leaves to synthetic growth regulating substances'):(5.927430445361261, 5.927430445361261, 5.9358147229114975, 5.9358147229114975)
#
#
# ('T99321', 'T47770', 0.9984689029533779, 'Fragmentation dynamics in intermediate energy heavy ion reactions (2000-01-01)', 'Fragmentation dynamics in intermediate energy heavy ion reactions (2000-02-01)'):(5.883205456095482, 5.883205456095482, 5.895420369104579, 5.895420369104579)
#
#
# ('T196524', 'T116818', 0.9908099178486821, 'Spatial structure of urban rural relationship in Orissa a geographic analysis', 'Spatial structure of urban rural relationship on Orissa a geographic analysis'):(5.708994708994709, 5.708994708994709, 5.745967741935484, 5.745967741935484)
#
#
# ('T26916', 'T13360', 0.9999999739078539, 'Tourism and its impact on the economic socio cultural and environmental set up of Puri a study in geography of tourism', 'Tourism and its impact on the economic socio cultural and environmental set up of Puri A study in geography of tourism'):(5.736467236467237, 6.0, 5.778225806451613, 6.0)
#
#
# ('T16566', 'T14208', 1.0000000665631992, 'Cuttack standard Urban area a study on Urban geography', 'Cuttack standard urban area a study on urban geography'):(5.550000000000001, 6.0, 5.58961038961039, 6.0)
#
#
# ('T61206', 'T105974', 0.9999999828628919, 'Industrial relations in state undertakings of Orissa a case study of IDCOL', 'Industrial relations in state undertakings of Orissa A case study of IDCOL'):(5.601307189542483, 6.0, 5.675324675324675, 6.0)
#
#
# ('T129997', 'T72232', 0.9944993688798756, 'Cognitive abilities and academic achievement of children effects of social disadvantage and maternal emplloyment', 'Cognitive abilities and academic achievement of children effects of social disadvantage and maternal employment'):(5.2747252747252755, 5.2747252747252755, 5.2747252747252755, 5.2747252747252755)
#
#
# ('T25173', 'T134523', 0.996520885176403, 'Heavy metal speciation in aquatic sediment interacted by iron mines discharge and its effect on hydrosphere of Daitari iron ore mines Orissa', 'Heavy metal speciation in aquatic sediment interacted by iron mines discharge and its effect on hydrosphere of daitariiron ore mines Orissa'):(5.726153846153847, 6.0, 5.59189352692075, 5.826981246218995)
#
#
# ('T188209', 'T155322', 0.9999999809253521, 'Studies on Vinyl polymerization and grafting', 'Studies on vinyl polymerization and grafting'):(5.336363636363637, 6.0, 5.4423076923076925, 6.0)
#
#
# ('T77856', 'T144623', 0.9905005425546364, 'Hydrolysis of some iron salts and study of the compounds obtained there from (1990-01-01)', 'Hydrolysis of some iron salts and study of the compounds obtained there from (1990-04-30)'):(5.759601706970128, 5.759601706970128, 5.795169830814929, 5.795169830814929)
#
#
# ('T88792', 'T119485', 0.9932781898085707, 'Emerging pattern of leadership in a tribal district in Orissa a case study of Mayurbhanj', 'Emerging pattern of leadership in a tribal district in Orissa - A case study of Mayurbhanj'):(5.6897233201581034, 6.0, 5.56209443945293, 5.814116002795248)
#
#
# ('T196083', 'T169569', 0.9999999320921311, 'Status and role of sevakas of lord Jagannath Puri with special reference to Navakalevar and Rathayatra ritual complexes', 'Status and role of sevakas of Lord Jagannath Puri with special reference to Navakalevar and Rathayatra ritual complexes'):(5.726153846153847, 6.0, 5.778225806451613, 6.0)
#
#
# ('T70194', 'T106898', 0.9999999063159279, 'Aligning Textual and Visual Data Towards Scalable Multimedia Retrieval', 'Aligning Textual and Visual Data towards Scalable Multimedia Retrieval'):(5.763218390804599, 6.0, 5.797478991596639, 6.0)
#
#
# ('T17596', 'T41427', 0.9914635452797952, 'Molecular association in the binary mixtures with acetone as one of the constituents from microwave absorption data', 'Molecular association in the binary mixtures with N_methylacetamide as one of the constituents from microwave absorption data'):(4.944365667633472, 5.02350923381965, 5.058602726988073, 5.129858020767112)
#
#
# ('T97040', 'T31370', 1.0000000389246, 'A Study of certain factors contributing to mental health of professionals', 'A study of certain factors contributing to mental health of professionals'):(5.8898809523809526, 6.0, 5.904850055534988, 6.0)
#
#
# ('T29314', 'T38508', 0.9989641325053883, 'A comparative study of school climate and satisfaction as mediating variables of educational environment and their relationship with students academic achievement in demonstration and non demonstration schools of Thailand', 'Comparative study of school climate and satisfaction as mediating variables of educational environment and their relationship with students academic achievement in demonstration and non demonstration schools of Thailand'):(5.937957165957807, 5.974079806204159, 5.923178279060632, 5.954709995886467)
#
#
# ('T177304', 'T159957', 1.0000000277000805, 'Functional characterization of novel genes encoding for wall associated kinase wak stress associated protein sap and pectin methyl esterase pme from oryza sativa var indica', 'Functional characterization of novel genes encoding for wall associated kinase WAK stress associated protein SAP and pectin methyl esterase PME from oryza sativa Var Indica'):(5.09338959212377, 6.0, 5.222084367245658, 6.0)
#
#
# ('T26661', 'T95624', 0.9999999573538563, 'Computational approach towards classification and annotation of genomes and proteomes analysis of hnh domain proteins', 'Computational approach towards classification and annotation of genomes and proteomes Analysis of HNH domain proteins'):(5.039426523297491, 6.0, 5.155760368663595, 6.0)
#
#
# ('T26716', 'T87831', 0.9999999806693965, 'Studies on the physico chemical and biological parameters of manakudy estuary Kanyakumari district south west coast of India Tamil Nadu', 'Studies on the physico chemical and biological parameters of manakudy estuary kanyakumari district south west coast of India Tamil Nadu'):(5.858775510204082, 6.0, 5.878402903811253, 6.0)
#
#
# ('T62067', 'T7000', 0.9941500541567698, 'quotA Study on the Influence of Demographics Psychographics Shopping Orientation Mall Shopping Attitude and Shopping Patterns on Mall Patronage quot', 'A Study on the Influence of Demographics Psychographics Shopping Orientation Mall Shopping Attitude and Shopping Patterns on Mall Patronage'):(5.6879379844961235, 5.6879379844961235, 5.694038986721914, 5.694038986721914)
#
#
# ('T57641', 'T95212', 1.0000000111880407, 'quotImprovement of Prediction of Customer Response in Direct Marketing quot', 'quotImprovement of Prediction of Customer Response in Direct marketing quot'):(5.483516483516484, 6.0, 5.519047619047619, 6.0)
#
#
# ('T26779', 'T54045', 1.0000000270407023, 'Customer relationship management in Banking sector', 'Customer relationship management in banking sector'):(5.483516483516484, 6.0, 5.519047619047619, 6.0)
#
#
# ('T93993', 'T117566', 0.9906288688923762, 'Subscribers attitude towards direct to home television a study with reference to Theni district', 'Subscribers attitude towards direct to home television a study with reference to theni district'):(5.483516483516484, 6.0, 5.519047619047619, 6.0)
#
#
# ('T121526', 'T112276', 1.000000125996831, 'A study on the ordered structure Of rough sets', 'A study on the ordered structure of rough sets'):(5.3939393939393945, 6.0, 5.483516483516484, 6.0)
#
#
# ('T94970', 'T175621', 1.0000000200787795, 'A stuty on management accounting practices in co operative sugar industries in tamil nadu', 'A stuty on management accounting practices in co operative sugar industries in Tamil Nadu'):(4.6060606060606055, 6.0, 4.733333333333333, 6.0)
#
#
# ('T81806', 'T144853', 0.9999999669507121, 'Customers preference for quality services In public and private sector banks of Dindigul district', 'Customers preference for quality services in public and private sector banks of Dindigul district'):(5.818488529014846, 6.0, 5.839323467230444, 6.0)
#
#
# ('T88467', 'T28817', 0.9915704704743541, 'Studies on the induction of variation through in vitro culture in Jatropha curcas L', 'Studies on the induction of variation through in vitro culture in Jatropha curcas L.'):(6.0, 6.0, 6.0, 6.0)
#
#
# ('T160643', 'T84161', 0.9933432619265715, 'Dopamine receptor subtypes functional regulation in insulin induced hypoglycemic neonatal rats: effect of glucose, bacopa monnieri and bacoside a resuscitation', 'Dopamine receptor subtypes functional regulation in insulin induced hypoglycemic neonatal rats effect of glucose bacopa monnieri and bacoside a resuscitation'):(6.0, 6.0, 6.0, 6.0)
#
#
# ('T116559', 'T101115', 0.9940438654050994, 'Special features of Indian tribal art and its influence on the Contemporary trends of art _ volume II', 'Special features of Indian tribal art and its influence on the Contemporary trends of art _ volume I'):(5.93968601679445, 5.93968601679445, 5.949949748743719, 5.949949748743719)
#
#
# ('T153666', 'T30275', 0.9909206682800372, 'Dr Bhayyasaheb Omkar an artist a proponent of the fine arts and an acclaimed art critic', 'Dr Bhayyasaheb Omkar _ an artist a proponent of the fine arts and an acclaimed art critic'):(6.0, 6.0, 5.760743321718931, 5.760743321718931)
#
#
# ('T2468', 'T87940', 1.000000056453699, 'Impact of Western Ghats Orography on the Weather and Climate Over Southern Peninsular India A Mesoscale Modelling Study', 'Impact of Western Ghats Orography on the weather and climate Over Southern peninsular India a Mesoscale modelling study'):(5.410969793322734, 6.0, 5.483516483516484, 6.0)
#
#
# ('T191202', 'T18331', 0.9999998941084471, 'Kamaleswar ke katha sahithya mein Jeevan moolya', 'Kamaleswar ke katha sahithya mein jeevan moolya'):(5.4423076923076925, 6.0, 5.483516483516484, 6.0)
#
#
# ('T192142', 'T43306', 0.9916889120210483, 'Some topics in graph theory (2010-02-05)', 'Some topics in graph theory (2010-01-01)'):(5.529004329004329, 5.529004329004329, 5.589473684210526, 5.589473684210526)
#
#
# ('T190986', 'T10193', 1.0000000330916226, 'A study on matrix and bi matrix Games with fuzzy goals and Fuzzy payoffs', 'A study on Matrix and Bi Matrix games with fuzzy goals and fuzzy payoffs'):(5.14014687882497, 6.0, 5.281756180733162, 6.0)
#
#
# ...
#
#
# ('T3622', 'T142176', 0.9941950323236056, 'Reliability analysis of some communication networks, software and shared load models', 'Reliability analysis of Some communication networks Software and shared load models'):(5.709075119409466, 6.0, 5.741337907375643, 6.0)
#
#
# ('T22967', 'T153267', 0.9980384225245593, 'A study of the kinetics of oxidation of naphthyl styryl ketones by pyridinium chlorochromate and of substituent effects on their 1H NMR infrared frequencies', 'A study of the kinetics of oxidation of styryl ketones by pyridinium chlorochromate and of substituent effects on their 1H NMR and infrared frequencies'):(5.387785610719464, 5.387785610719464, 5.424402751475632, 5.424402751475632)
#
#
# ('T199264', 'T77326', 0.9968175520892413, 'Studies on the preparation and applications of metal oxide impregnated silica alumina catalysts', 'Studies on the preparation and application of metal oxide impregnated silica alumina catalysts'):(5.868070175438596, 5.868070175438596, 5.8834473324213405, 5.8834473324213405)
#
#
# ('T93776', 'T6116', 0.9937279947770102, 'Investigations on the grain growth machanism in P As and B doped polysilicon intrinsic polysilicon aluminium lead cadmium and Al2O3 ZrO2', 'Investigation on the grain growth mechanism in P as and B doped polysilicon intrinsic polysilicon aluminium lead cadmium and Al2O3 ZrO2'):(5.653513244621315, 5.700024872528292, 5.707562385197796, 5.746778071472306)
#
#
# ('T142097', 'T48179', 0.9988194166037142, 'Lipid lipid peroxidation and collagen changes in myocardial lesions induced by high fat and diet and immobilisation stress cardioprotective effects of the herbomineral drug Anna Pavala Sindhooram', 'Lipid lipid peroxidation and collagen changes in myocardial lesions induced by high fat diet and immobilisation stress cardioprotective effects of the herbomineral drug anna pavala sindhooram'):(5.672453038144528, 5.839907993099482, 5.665227030536128, 5.812372051624388)
#
#
# ('T43515', 'T146124', 1.0000000238419768, 'Southerness in the novels of carson mccullers', 'Southernness in the novels of carson mccullers'):(5.366666666666667, 5.366666666666667, 5.366666666666667, 5.366666666666667)
#
#
# ('T170139', 'T19536', 0.9980228215220004, 'Molecular basis sporulation in bacillus studies on the formation and characterization of the crystal proteins of bacillus thuringiensis var israelensis', 'Molecular basis of sporulation in bacillus studies on the formation and characterization of the crystal proteins of bacillus thuringiensis var israelensis'):(5.366666666666667, 5.366666666666667, 5.151515151515151, 5.151515151515151)
#
#
# ('T77228', 'T125682', 0.9912370264525215, 'Influence of waterproofing compounds on the strength and durability of concrete: an experimental investigation', 'Influence of waterproofing compounds on the strength and durability of concrete - an experimental investigation'):(6.0, 6.0, 5.8327683615819215, 5.8327683615819215)
#
#
# ('T54622', 'T181351', 0.9999998292101044, 'Studies on the properties of high volume fly ash gypsum slurry with quarry waste and its use in pavement base course', 'Studies on the properties of High volume fly ash gypsum slurry With quarry waste and its use in Pavement base course'):(5.702898550724638, 6.0, 5.752031381339311, 6.0)
#
#
# ('T1496', 'T172996', 0.9999999863237935, 'Multi criteria decision making based Green supplier evaluation and Selection in process industry', 'Multi criteria decision making based green supplier evaluation and selection in process industry'):(5.736467236467237, 6.0, 5.767157543762156, 6.0)
#
#
# ('T148906', 'T13900', 0.9977939093377798, 'Analytical and experimental investigations of ethanol diesel dual fuel combustion system for A C I engine', 'Analytical and experimental investigations of ethanol diesel dual fuel combustion systems for a C I Engine'):(4.631794871794871, 5.612307692307692, 4.995238095238094, 5.720634920634921)
#
#
# ('T76598', 'T157334', 0.9951016046164807, 'Electronic structure and properties of some oxide and chalcogenide systems', 'Electronic structures and properties of some oxide and chalcogenide systems'):(5.748717948717949, 5.748717948717949, 5.760743321718931, 5.760743321718931)
#
#
# ('T161758', 'T581', 1.0000000591196987, 'Perspectives and attributes of environmental quality in transitional urban areas a study in thiruvanmiyur chennai india', 'Perspectives and attributes of Environmental quality in Transitional urban areas a study in Thiruvanmiyur chennai india'):(5.726153846153847, 6.0, 5.754926108374384, 6.0)
#
#
# ('T93082', 'T90857', 0.9905241146353415, 'Development and validation of analytical methods for quantification of new drug molecules by using high performance liquid chromatography', 'Development and validation of analytical methods for quantification of new drugs by using high performacne liquid chromatography'):(5.1222361284939515, 5.1222361284939515, 5.140670319046085, 5.140670319046085)
#
#
# ('T44738', 'T123111', 0.9954388366690463, 'A Comparative Study Of Some Personality Dimensions Of Alcohol Abusers', 'A Comparative Study Of Some Personality Dimensions Of Alcohol Abusers And'):(5.760743321718931, 5.760743321718931, 5.724483889639205, 5.724483889639205)
#
#
# ('T14170', 'T91605', 0.9928484901714733, 'Development Of Computer Program For Test Generation Testing and Scoring Through Internet And It s Application On Valid Question Bnk Of Mathematics For Standard 6th', 'Development Of Computer Program For Test Generation Testing And Scoring Through Internet And Its Application On Valid Question Bank Of Science For Standard 7th'):(5.192040462188924, 5.301980320106538, 5.285678002199436, 5.394176374356427)
#
#
# ('T96675', 'T38318', 0.9957015906059311, 'A Study On The Role Of Banks In The Development Of Ship Breaking Industry At Alang and Sosiya And Its Resultant Impact On The Economy Of Bhavnagar District', 'A Study On The Role Of Banks In The Development Of Ship Breaking Industry At Alang and Sosiya And Its Resul Tant Impact On The Economy Of Bhavnagar District'):(5.831591173054588, 6.0, 5.757130233536714, 5.897748790237745)
#
#
# ('T62907', 'T151871', 0.9934038568682152, 'Use of potential probiotic bacteria bacillus coagulans and duckweed in feeds for growth promotion and immunomodulatory effects in catla catla', 'Use of potential probiotic bacteria bacillus coagulans and duckweed in feeds for growth promotion and immunomodulatory effects in catla catla Hamilton'):(5.690354090354091, 5.690354090354091, 5.698144329896907, 5.698144329896907)
#
#
# ('T15664', 'T132080', 1.000000038616963, 'Community based tourism development a case study of sikkim', 'Community based tourism development a case study of Sikkim'):(4.928571428571429, 6.0, 4.928571428571429, 6.0)
#
#
# ('T151867', 'T200967', 0.9967738955083093, 'Investigation of air swirl inducement techniques in a di diesel engine with mamey sapote bio diesel to improve the performance and emission', 'Investigation of air swirl inducement techniques in a di diesel engine with mamey sapote bio diesel to improve the performance and emissions'):(5.957947736056449, 5.957947736056449, 5.96426011264721, 5.96426011264721)
#
#
# ('T63284', 'T118820', 0.9999999678311434, 'Development and property evaluation of aluminum alloy reinforced with nano zro2 metal matrix composites nmmcs for automotive applications', 'Development and property Evaluation of aluminum alloy reinforced with nano zro2 Metal matrix composites for automotive applications'):(5.476066607645555, 5.65979965979966, 5.4719347980155915, 5.635843373493977)
#
#
# ('T31515', 'T175196', 0.9960685098642293, 'Study analysis and optimization of integrated reliability model for redundant systems', 'Study analysis and optimization of integrated reliability model for redundant system'):(5.933243847874721, 5.933243847874721, 5.941106856943961, 5.941106856943961)
#
#
# ('T176529', 'T137638', 1.000000001714528, 'Models for legacy system evolution And migration to modern system', 'Models for legacy system evolution and migration to modern system'):(5.736467236467237, 6.0, 5.770967741935484, 6.0)
#
#
# ('T83668', 'T45172', 0.9999999837548967, 'Characterization of phenolics extracted from Amla Emblica officinalis and its processing waste and development of amla lemon based RTS drink', 'Characterization of phenolics extracted from amla emblica officinalis and its processing waste and development of amla lemon based rts drink'):(5.372153545868575, 6.0, 5.4423076923076925, 6.0)
#
#
# ('T111004', 'T171093', 0.9916452024823877, 'Physicochemical changes in bamboo shoot of Assam during processing and its quality study by application of antimicrobial antibrowning edible coating', 'Physicochemical changes in bamboo shoot of assam during processing and its quality study by application of antimicrobialantibrowning edible coating'):(5.818488529014846, 6.0, 5.834280635650498, 5.930458430458431)
#
#
# ('T100928', 'T149714', 1.000000072611334, 'Investigation on power loss minimization By network reconfiguration with wap Enabled optimal capacitor switching in Radial distribution system', 'Investigation on power loss minimization by network reconfiguration with WAP enabled optimal capacitor switching in radial distribution system'):(5.545121230041396, 6.0, 5.597483112797261, 6.0)
#
#
# ('T168346', 'T136577', 0.9981076263513973, 'Characterisation of epoxy resin components and development of a new system model for endurance estimation under aggravated services conditions', 'Characterisation of epoxy resin components and development of a new system model for endurance estimation under aggravated service conditions'):(5.541125541125541, 5.541125541125541, 5.579710144927536, 5.579710144927536)
#
#
# ('T158009', 'T146966', 0.9913968675847477, 'Certain investigations on particle Swarm optimization techniques for Multiprocessor scheduling problems', 'Certain investigations on particle swarm optimization techniques for multiprocessor scheduling'):(5.281423804226919, 5.345939933259177, 5.270032422417787, 5.328855951829551)
#
#
# ('T4976', 'T32811', 0.9907882426584824, 'Analytical modeling and simulation Of fully depleted triple material Surrounding gate mosfets Considering short channel effects', 'Analytical modeling and simulation Of a fully depleted dual material Surrounding gate mosfets Considering short channel effects'):(5.2730449162488, 5.2730449162488, 5.280720338983051, 5.280720338983051)
#
#
# ('T151590', 'T103956', 0.999579339089241, 'Investigations on performance Improvements of self biased Adaptive bandwidth PLLS (2014-08-01)', 'Investigations on performance Improvements of self biased Adaptive bandwidth PLLS (2014-09-01)'):(5.903026741110786, 5.903026741110786, 5.913510986442263, 5.913510986442263)
#
#
# ('T174309', 'T187274', 0.9960351631788659, 'Knowledge representation for computer based legal consultation systems an experiment with lay off and retrenchment compensation disputes', 'Knowledge representation for computer based legal consultation systems an experimental with lay off and retrenchment compensation disputes'):(5.786308973172988, 5.786308973172988, 5.814116002795248, 5.814116002795248)
#
#
# ('T26908', 'T73927', 0.9933405035544928, 'Development of rotating polarizing technique to determine the phase transitions, optical polarization and electro-optic modulator properties in liquid crystals', 'Development of rotating polarizing technique to determine the phase transitions optical polarization and electro optic modulator properties in liquid crystals'):(6.0, 6.0, 5.891065456282847, 5.891065456282847)
#
#
# ('T41883', 'T2568', 0.9908854135606959, 'Freedom Movement in Kashmir 1931-1940', 'Freedom Movement in Kashmir 1939-1947'):(5.514705882352941, 5.514705882352941, 5.567251461988304, 5.567251461988304)
#
#
# ('T36298', 'T36283', 0.9944173475069009, 'Tracheid length variations in Abies pindrow Royle _vol 2_', 'Tracheid length variations in Abies pindrow Royle _vol 1_'):(5.831560283687944, 5.831560283687944, 5.855844155844156, 5.855844155844156)
#
#
# ('T82334', 'T199155', 0.990623317147459, 'A study of managerial effectiveness of public sector bank officers with special reference to State Bank of India in Himachal Pradesh', 'A study of managerial effectiveness of Public Sector Bank Officers with special reference to Punjab National Bank in Himachal Pradesh'):(4.851678457483701, 5.095136228182205, 4.9276887371350115, 5.11672612818228)
#
#
# ('T84961', 'T130019', 1.0000000163959581, 'A study of co_operative banks in Himachal Pradesh with special reference to Jogindra Central Co_operative Bank', 'A study of Co_operative banks in Himachal Pradesh with special reference to Jogindra central Co_operative Bank'):(5.903225806451613, 6.0, 5.916666666666667, 6.0)
#
#
# ('T109673', 'T25400', 0.9999999864216551, 'Impact of globalisation on the performance and quality of services in Commercial Banks in India', 'Impact of Globalisation on the performance and quality of services in commercial banks in India'):(5.35673624288425, 6.0, 5.4423076923076925, 6.0)
#
#
# ('T146823', 'T153541', 0.9999999447011109, 'Impact of financial sector reforms on Indian economy', 'Impact of financial sector reforms on Indian Economy'):(5.071428571428571, 6.0, 5.071428571428571, 6.0)
#
#
# ('T180536', 'T3301', 0.995531642341747, 'Problem and prospects of tea industry in himachal pradesh', 'Problems and prospects of tea industry in Himachal Pradesh'):(5.205797101449276, 5.781642512077294, 5.23772504091653, 5.790780141843972)
#
#
# ('T112035', 'T164148', 0.9957028950597426, 'Determining the predictors of investors intent skill and success in the mutual fund industry', 'Determining the predictors of Investors intents skill and success in the mutual fund industry'):(5.717034249956637, 5.880665519219736, 5.746882864333105, 5.89338824067719)
#
#
# ('T22909', 'T102156', 0.999164440390622, 'A study to assess the awareness and utilization of national rural health mission services among people of selected rural areas in the state of Maharashtra', 'A study to assess the awareness utilization of national rural health mission services among people of selected rural areas in the state of Maharashtra'):(5.477115987460815, 5.477115987460815, 5.421645021645022, 5.421645021645022)
#
#
# ('T87662', 'T100402', 0.9927367353215866, 'Development of novel antiinflammatory agents by rational design synthesis and pharmacological evaluation', 'Sevelopment of novel antiinflammatory agents by rational design synthesis and pharmacological evaluation'):(5.914436055822466, 5.914436055822466, 5.923443223443224, 5.923443223443224)
#
#
# ('T79392', 'T142682', 1.0000000975460075, 'Study of difficulties in adopting ICT for teaching and measures thereby with specific reference to select higher education institutions in Pune', 'Study of difficulties in adopting ict for teaching and measures thereby with specific reference to select higher education institutions in Pune'):(5.3758928571428575, 6.0, 5.456756756756757, 6.0)
#
#
# ('T13802', 'T174525', 1.0000000062316328, 'An analytical study of accrual accounting system and its usefulness to analyse the future cash flow in Indian pharmaceutical industry', 'An analytical study of accrual accounting system and its usefulness to analyse the future cash flow in indian pharmaceutical industry'):(5.754926108374384, 6.0, 5.770967741935484, 6.0)
#
#
# ('T48925', 'T115405', 0.9999999770899253, 'The geographical aspects of ill_health in the rural areas of Pune district Maharashtra state', 'The geographical aspects of ill_health in the rural areas of Pune District Maharashtra State'):(5.4423076923076925, 6.0, 5.483516483516484, 6.0)
#
#
# ('T59143', 'T152590', 0.9999999062916859, 'Plant geography of Western Ghats in Maharashtra', 'Plant geography of western ghats in Maharashtra'):(5.4423076923076925, 6.0, 5.519047619047619, 6.0)

# %%
ment = pd.read_csv("index_files4/final_mod_ment_w_baseline_gen4_2.csv",sep=",")

# %%
ment[ment['thesisId']=='T160261']
# Out:
#         advisorId  researcherId  advisor_name researcher_name  \
# 149065      71851        235382  Gupta, Madhu           Seema
#
#        dc.date.submitted[] dc.language.iso[]           publisher_dept  \
# 149065          2012-01-01               eng  department of education
#
#        DepartmentId         publisher_institution instituteId  ...  \
# 149065        D1418  Maharshi Dayanand University         I35  ...
#
#                              dc.source.uri dc.description.abstract  \
# 149065  http://shodhganga.inflibnet.ac.in/                     NaN
#
#        dc.title.alternative       advisor_inst_dept   stud_inst_dept  \
# 149065                  NaN  Gupta, Madhu@I35@D1418  Seema@I35@D1418
#
#              adv_names_rid res_names_rid  advId   resId N_DepartmentId
# 149065  Gupta, Madhu@71851  Seema@235382  71851  235382          D1418
#
# [1 rows x 25 columns]

# %%
ment[ment['thesisId']=='T177031']
# Out:
#         advisorId  researcherId  advisor_name researcher_name  \
# 149052      71851        235241  Gupta, Madhu    Seema, Seema
#
#        dc.date.submitted[] dc.language.iso[]           publisher_dept  \
# 149052          2012-12-31               eng  department of education
#
#        DepartmentId         publisher_institution instituteId  ...  \
# 149052        D1418  Maharshi Dayanand University         I35  ...
#
#                              dc.source.uri dc.description.abstract  \
# 149052  http://shodhganga.inflibnet.ac.in/                     NaN
#
#        dc.title.alternative       advisor_inst_dept          stud_inst_dept  \
# 149052                  NaN  Gupta, Madhu@I35@D1418  Seema, Seema@I35@D1418
#
#              adv_names_rid        res_names_rid  advId   resId N_DepartmentId
# 149052  Gupta, Madhu@71851  Seema, Seema@235241  71851  235241          D1418
#
# [1 rows x 25 columns]
