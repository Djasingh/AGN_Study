# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
from collections import Counter

# %%
# %matplotlib inline

# %%
ment2 = pd.read_csv('mod1_shodhganga_mentorship.csv', sep =",")# with grouping researchers based on institute

# %%
ment2.columns
# Out:
# Index(['advisorId', 'researcherId', 'advId_1', 'studId_1', 'advisor_name',
#        'researcher_name', 'dc.date.submitted[]', 'dc.language.iso[]',
#        'dc.publisher.department[]', 'DepartmentId',
#        'dc.publisher.institution[]', 'instituteId', 'dc.title[]', 'thesisId',
#        'dc.type.degree', 'dc.date.awarded', 'dc.subject.ddc', 'dc.source.uri',
#        'dc.description.abstract', 'dc.title.alternative'],
#       dtype='object')

# %%
graph = nx.convert_matrix.from_pandas_edgelist(ment2, 'advisorId','researcherId', create_using=nx.DiGraph())

# %%
len(graph.nodes())
# Out:
# 238442

# %%
graph1 = nx.convert_matrix.from_pandas_edgelist(ment2, 'advId_1','studId_1', create_using=nx.DiGraph())

# %%
len(graph1.nodes())
# Out:
# 236874

# %%
components = list(nx.weakly_connected_components(graph))

# %%
components1 = list(nx.weakly_connected_components(graph1))

# %%
components.sort(key=len, reverse=True)

# %%
components1.sort(key=len, reverse=True)

# %%
len(components)
# Out:
# 46370

# %%
len(components[0])
# Out:
# 92530

# %%
len(components1)
# Out:
# 44123

# %%
len(components1[0])
# Out:
# 94541

# %%
comp_len=[len(c) for c in components1]

# %%
comp_size_dist=Counter(comp_len)

# %%
#comp_size_dist

# %%
in_dgr = graph1.in_degree()

# %%
in_dgr = dict(in_dgr)

# %%
sorted_in_dgr = dict(sorted(in_dgr.items(), key=lambda item: item[1],reverse=True))

# %%
#sorted_in_dgr

# %%
in_dgr_val = in_dgr.values()

# %%
in_dgr_dist = Counter(in_dgr_val)

# %%
plt.hist(in_dgr_val, bins=np.arange(0,20,1))
plt.show()

# %%
in_dgr_dist #indgree, no.nodes
# Out:
# Counter({1: 154107,
#          0: 65213,
#          2: 13099,
#          3: 2319,
#          4: 864,
#          5: 431,
#          12: 35,
#          29: 1,
#          35: 2,
#          7: 152,
#          11: 22,
#          13: 19,
#          6: 244,
#          17: 16,
#          24: 4,
#          8: 103,
#          14: 21,
#          55: 1,
#          27: 3,
#          9: 70,
#          15: 17,
#          28: 2,
#          10: 60,
#          21: 4,
#          20: 10,
#          18: 12,
#          49: 2,
#          33: 3,
#          48: 1,
#          19: 5,
#          16: 9,
#          22: 7,
#          34: 2,
#          39: 2,
#          52: 1,
#          45: 1,
#          42: 1,
#          23: 4,
#          25: 2,
#          31: 2,
#          40: 1})

# %%
#list(sorted_fecundity.keys())[-5:]

# %%
#ment[ment['advId_1']==75844]

# %%
out_dgr = graph1.out_degree()

# %%
out_dgr = dict(out_dgr)

# %%
sorted_out_dgr = dict(sorted(out_dgr.items(), key=lambda item: item[1],reverse=True))

# %%
sorted_out_dgr
# Out:
# {'393_I333': 129,
#  '71609': 67,
#  '1708': 61,
#  '20913': 60,
#  '8561_I306': 59,
#  '24250_I293': 58,
#  '12741_I251': 55,
#  '2423_I306': 54,
#  '6108_I306': 52,
#  '7566_I87': 50,
#  '21471_I306': 50,
#  '25284_I61': 50,
#  '15072_I107': 49,
#  '6776_I250': 48,
#  '7474': 46,
#  '557_I281': 46,
#  '1775_I306': 46,
#  '30796_I281': 46,
#  '14906_I58': 45,
#  '14225_I351': 45,
#  '42281_I333': 45,
#  '54262': 45,
#  '42365_I250': 45,
#  '52333': 44,
#  '1331_I302': 43,
#  '2548': 43,
#  '7347': 43,
#  '42128': 43,
#  '64721': 43,
#  '71624': 43,
#  '12778': 42,
#  '3770_I20': 41,
#  '65860': 41,
#  '17685': 40,
#  '14131_I306': 40,
#  '65049': 40,
#  '50397': 39,
#  '65870': 39,
#  '40039_I306': 38,
#  '6732': 38,
#  '6712': 38,
#  '4159_I35': 38,
#  '17693': 38,
#  '22190': 38,
#  '19475_I61': 38,
#  '26713_I333': 38,
#  '53828': 38,
#  '64252': 38,
#  '24150': 37,
#  '40306': 37,
#  '58042': 37,
#  '2706': 36,
#  '5738_I103': 36,
#  '8572': 36,
#  '12886': 36,
#  '35747': 36,
#  '26712_I333': 36,
#  '58037': 36,
#  '64841': 36,
#  '2422_I306': 35,
#  '8404': 35,
#  '16698_I281': 35,
#  '17117': 35,
#  '1384_I281': 35,
#  '17813': 35,
#  '24101': 35,
#  '46491_I58': 35,
#  '54819': 35,
#  '71788': 35,
#  '1393': 34,
#  '40777': 34,
#  '4809_I292': 34,
#  '5240_I313': 34,
#  '3948_I85': 34,
#  '36694': 34,
#  '11533_I26': 34,
#  '696_I302': 33,
#  '9818': 33,
#  '12885': 33,
#  '16696_I281': 33,
#  '17166': 33,
#  '9914_I281': 33,
#  '20581_I160': 33,
#  '6426_I61': 33,
#  '31997': 33,
#  '39838': 33,
#  '61494': 33,
#  '6750_I250': 32,
#  '12905': 32,
#  '15330_I351': 32,
#  '16727': 32,
#  '23717': 32,
#  '22299_I348': 32,
#  '13802_I313': 32,
#  '36687_I313': 32,
#  '54236': 32,
#  '64260': 32,
#  '64828': 32,
#  '65864': 32,
#  '380': 31,
#  '1262_I35': 31,
#  '5083': 31,
#  '7479': 31,
#  '16983': 31,
#  '15306_I351': 31,
#  '17793': 31,
#  '24440': 31,
#  '24990': 31,
#  '27276_I351': 31,
#  '9816_I343': 31,
#  '2351_I61': 31,
#  '39770': 31,
#  '39931': 31,
#  '43718': 31,
#  '58965': 31,
#  '64722': 31,
#  '28966_I87': 31,
#  '71790': 31,
#  '4157_I35': 30,
#  '5084': 30,
#  '72630': 30,
#  '11127_I85': 30,
#  '12553': 30,
#  '14435': 30,
#  '15668': 30,
#  '12137_I306': 30,
#  '22132': 30,
#  '23708': 30,
#  '26912': 30,
#  '34965_I313': 30,
#  '35107': 30,
#  '35861_I333': 30,
#  '37087': 30,
#  '40325': 30,
#  '52216_I293': 30,
#  '61038': 30,
#  '8569_I107': 30,
#  '7146': 29,
#  '12434_I20': 29,
#  '14438_I49': 29,
#  '14446': 29,
#  '17923': 29,
#  '21440': 29,
#  '23844_I160': 29,
#  '27409': 29,
#  '28483': 29,
#  '38942': 29,
#  '1240_I306': 29,
#  '52255': 29,
#  '53853': 29,
#  '56581': 29,
#  '58743': 29,
#  '58750': 29,
#  '64219': 29,
#  '65873': 29,
#  '8351_I250': 29,
#  '55607_I250': 29,
#  '75461': 29,
#  '1809': 28,
#  '24164': 28,
#  '7477': 28,
#  '7545': 28,
#  '13164': 28,
#  '13651_I20': 28,
#  '16257_I351': 28,
#  '17100_I281': 28,
#  '21711': 28,
#  '28998_I160': 28,
#  '32017': 28,
#  '33474': 28,
#  '39718': 28,
#  '39833': 28,
#  '32358_I306': 28,
#  '46068': 28,
#  '54838': 28,
#  '57896': 28,
#  '58130': 28,
#  '49347_I285': 28,
#  '67127': 28,
#  '67696': 28,
#  '2750_I250': 28,
#  '625_I265': 27,
#  '1688_I224': 27,
#  '2424': 27,
#  '4634': 27,
#  '7469_I87': 27,
#  '8231_I165': 27,
#  '11956': 27,
#  '13848': 27,
#  '14300': 27,
#  '2854_I306': 27,
#  '4196_I306': 27,
#  '24208': 27,
#  '27484': 27,
#  '2357_I351': 27,
#  '34056': 27,
#  '25305_I313': 27,
#  '39908_I306': 27,
#  '42326': 27,
#  '50667': 27,
#  '52244': 27,
#  '52273': 27,
#  '18079_I302': 27,
#  '27095_I35': 27,
#  '57980': 27,
#  '6192_I26': 27,
#  '61035': 27,
#  '61053': 27,
#  '35065_I285': 27,
#  '4200_I85': 27,
#  '64849': 27,
#  '788': 26,
#  '1207': 26,
#  '1405_I172': 26,
#  '2114': 26,
#  '2198_I333': 26,
#  '2549': 26,
#  '6708': 26,
#  '4134': 26,
#  '5088_I292': 26,
#  '5041': 26,
#  '5536': 26,
#  '6768_I250': 26,
#  '8846': 26,
#  '11059_I85': 26,
#  '11076_I85': 26,
#  '13871': 26,
#  '10264_I85': 26,
#  '15531': 26,
#  '64683': 26,
#  '2349_I306': 26,
#  '39960_I306': 26,
#  '21947': 26,
#  '22189': 26,
#  '23396': 26,
#  '25833': 26,
#  '29095': 26,
#  '32029_I351': 26,
#  '35060_I351': 26,
#  '42258': 26,
#  '39860_I306': 26,
#  '41473': 26,
#  '46376': 26,
#  '48272': 26,
#  '57410': 26,
#  '65048': 26,
#  '67801': 26,
#  '70664': 26,
#  '72062': 26,
#  '8254_I250': 26,
#  '21121_I250': 26,
#  '4327': 25,
#  '4897': 25,
#  '7211': 25,
#  '10561': 25,
#  '12239_I357': 25,
#  '12544_I201': 25,
#  '13532': 25,
#  '54826': 25,
#  '17826_I281': 25,
#  '2738_I364': 25,
#  '22139': 25,
#  '24217': 25,
#  '27410_I107': 25,
#  '34968': 25,
#  '35778': 25,
#  '38743': 25,
#  '18252_I71': 25,
#  '24820_I300': 25,
#  '46371': 25,
#  '52332': 25,
#  '53067_I86': 25,
#  '54277': 25,
#  '56579': 25,
#  '58163': 25,
#  '61158': 25,
#  '62169': 25,
#  '911_I87': 25,
#  '69436': 25,
#  '71517': 25,
#  '73256': 25,
#  '114': 24,
#  '4795': 24,
#  '5620': 24,
#  '2793_I250': 24,
#  '6743_I250': 24,
#  '7486_I87': 24,
#  '10519_I241': 24,
#  '13489': 24,
#  '13503': 24,
#  '3948_I49': 24,
#  '15675': 24,
#  '17102': 24,
#  '17789': 24,
#  '18536': 24,
#  '22188': 24,
#  '24103': 24,
#  '24256': 24,
#  '26706': 24,
#  '27153': 24,
#  '29763': 24,
#  '30336': 24,
#  '32049': 24,
#  '35776': 24,
#  '37957': 24,
#  '39101': 24,
#  '38082_I306': 24,
#  '7340_I306': 24,
#  '24319_I253': 24,
#  '70563': 24,
#  '41489_I306': 24,
#  '46125': 24,
#  '52242': 24,
#  '41952_I89': 24,
#  '53927': 24,
#  '7882_I333': 24,
#  '57889': 24,
#  '58038': 24,
#  '64918': 24,
#  '64940': 24,
#  '66715': 24,
#  '45806_I160': 24,
#  '69933': 24,
#  '71904': 24,
#  '72194': 24,
#  '44069_I250': 24,
#  '51990_I250': 24,
#  '38196_I49': 24,
#  '1697_I115': 23,
#  '1808': 23,
#  '1814': 23,
#  '3770_I309': 23,
#  '4171': 23,
#  '5360': 23,
#  '6478_I75': 23,
#  '6798_I250': 23,
#  '7212': 23,
#  '8477_I357': 23,
#  '12718_I71': 23,
#  '12757': 23,
#  '12179_I201': 23,
#  '13258': 23,
#  '13890': 23,
#  '14108': 23,
#  '14216_I58': 23,
#  '15493_I351': 23,
#  '2933_I85': 23,
#  '17118': 23,
#  '17909': 23,
#  '24484': 23,
#  '25099': 23,
#  '25826': 23,
#  '27490': 23,
#  '29146': 23,
#  '34962_I313': 23,
#  '21593_I351': 23,
#  '39851': 23,
#  '28000_I333': 23,
#  '2242_I266': 23,
#  '32094_I103': 23,
#  '2274_I86': 23,
#  '54249': 23,
#  '54543': 23,
#  '56572': 23,
#  '57888': 23,
#  '59046': 23,
#  '59923': 23,
#  '61151': 23,
#  '15493_I285': 23,
#  '64256': 23,
#  '65763': 23,
#  '67437': 23,
#  '73254': 23,
#  '1164': 22,
#  '1703': 22,
#  '39901': 22,
#  '40255_I306': 22,
#  '2474': 22,
#  '61366': 22,
#  '4143': 22,
#  '5357': 22,
#  '5468': 22,
#  '5697_I250': 22,
#  '7478': 22,
#  '7498': 22,
#  '10619_I273': 22,
#  '11035': 22,
#  '11058': 22,
#  '13543': 22,
#  '13592_I20': 22,
#  '14018': 22,
#  '14504': 22,
#  '16181_I120': 22,
#  '13200_I281': 22,
#  '17791': 22,
#  '21949': 22,
#  '24092': 22,
#  '25067': 22,
#  '27012': 22,
#  '28554': 22,
#  '32026_I351': 22,
#  '34726': 22,
#  '54117': 22,
#  '35746_I333': 22,
#  '38941': 22,
#  '3901_I306': 22,
#  '40137': 22,
#  '40319': 22,
#  '47146_I35': 22,
#  '42123': 22,
#  '3441_I333': 22,
#  '7922_I333': 22,
#  '42395_I333': 22,
#  '43393': 22,
#  '45303_I313': 22,
#  '46566': 22,
#  '51126': 22,
#  '14952_I103': 22,
#  '52245': 22,
#  '52270': 22,
#  '53572': 22,
#  '54816': 22,
#  '16145_I251': 22,
#  '57983': 22,
#  '58755': 22,
#  '61152': 22,
#  '63324': 22,
#  '64707': 22,
#  '64847': 22,
#  '67114': 22,
#  '5117_I107': 22,
#  '70762': 22,
#  '71631': 22,
#  '72078': 22,
#  '2780_I250': 22,
#  '72811': 22,
#  '73964': 22,
#  '33771_I49': 22,
#  '75334': 22,
#  '1240_I224': 21,
#  '1722': 21,
#  '1733_I224': 21,
#  '2199': 21,
#  '5145': 21,
#  '5985': 21,
#  '7240': 21,
#  '7465': 21,
#  '7779_I271': 21,
#  '3441_I165': 21,
#  '8216_I165': 21,
#  '8360': 21,
#  '9652': 21,
#  '5666_I241': 21,
#  '10786': 21,
#  '12560_I201': 21,
#  '13412': 21,
#  '14453': 21,
#  '15425': 21,
#  '15699': 21,
#  '17519': 21,
#  '17916': 21,
#  '21402_I306': 21,
#  '814_I306': 21,
#  '40246_I306': 21,
#  '3135_I115': 21,
#  '5651_I293': 21,
#  '25496_I138': 21,
#  '25383_I103': 21,
#  '32040': 21,
#  '32083': 21,
#  '34969': 21,
#  '8866_I333': 21,
#  '31723_I124': 21,
#  '26060_I313': 21,
#  '39103': 21,
#  '42284': 21,
#  '23154_I333': 21,
#  '45213': 21,
#  '19024_I266': 21,
#  '49463': 21,
#  '50398': 21,
#  '50651': 21,
#  '727_I316': 21,
#  '53415': 21,
#  '53841': 21,
#  '54278': 21,
#  '54914': 21,
#  '56695': 21,
#  '18414_I35': 21,
#  '58791': 21,
#  '59021': 21,
#  '46096_I89': 21,
#  '62667': 21,
#  '64508': 21,
#  '370_I87': 21,
#  '64917': 21,
#  '65538': 21,
#  '65628': 21,
#  '71101': 21,
#  '75317': 21,
#  '75511': 20,
#  '1170': 20,
#  '27966': 20,
#  '359_I49': 20,
#  '56541': 20,
#  '4463': 20,
#  '4776': 20,
#  '7475': 20,
#  '9308': 20,
#  '12531': 20,
#  '12622': 20,
#  '12628_I201': 20,
#  '12634': 20,
#  '14215_I58': 20,
#  '35044_I351': 20,
#  '16686': 20,
#  '17697': 20,
#  '17792': 20,
#  '54821': 20,
#  '17946_I281': 20,
#  '19400': 20,
#  '19429': 20,
#  '19585_I281': 20,
#  '20973': 20,
#  '21400_I306': 20,
#  '21438_I306': 20,
#  '1044_I293': 20,
#  '23751': 20,
#  '23790': 20,
#  '23835_I160': 20,
#  '24042': 20,
#  '24247': 20,
#  '24248': 20,
#  '24971': 20,
#  '24979_I357': 20,
#  '25025': 20,
#  '26222_I357': 20,
#  '26894_I313': 20,
#  '36_I115': 20,
#  '27274_I351': 20,
#  '28127': 20,
#  '31218_I16': 20,
#  '18161_I351': 20,
#  '32035_I351': 20,
#  '35056': 20,
#  '35985': 20,
#  '36119': 20,
#  '36696': 20,
#  '37080': 20,
#  '2778_I348': 20,
#  '37736_I348': 20,
#  '38578': 20,
#  '39111': 20,
#  '40294': 20,
#  '40009': 20,
#  '13666_I306': 20,
#  '40350': 20,
#  '36221_I253': 20,
#  '41288': 20,
#  '41562': 20,
#  '36164_I285': 20,
#  '25354_I351': 20,
#  '44795': 20,
#  '45028': 20,
#  '45190': 20,
#  '45355': 20,
#  '46508': 20,
#  '51001': 20,
#  '29856_I103': 20,
#  '51220': 20,
#  '52247': 20,
#  '53056': 20,
#  '21035_I61': 20,
#  '54339': 20,
#  '54537': 20,
#  '54539': 20,
#  '54815': 20,
#  '57134_I35': 20,
#  '59064': 20,
#  '25655_I26': 20,
#  '33728_I259': 20,
#  '60168': 20,
#  '60505': 20,
#  '61410': 20,
#  '62670': 20,
#  '620_I87': 20,
#  '64682': 20,
#  '67755': 20,
#  '69454': 20,
#  '33323_I160': 20,
#  '69937': 20,
#  '70000': 20,
#  '70569': 20,
#  '32848_I250': 20,
#  '75311': 20,
#  '75316': 20,
#  '793': 19,
#  '1346_I302': 19,
#  '33476': 19,
#  '2550': 19,
#  '55517': 19,
#  '3340': 19,
#  '4521': 19,
#  '5121': 19,
#  '5838': 19,
#  '5983_I75': 19,
#  '7452_I87': 19,
#  '7886': 19,
#  '8309_I165': 19,
#  '8849': 19,
#  '9536': 19,
#  '10287': 19,
#  '11079': 19,
#  '12538': 19,
#  '12760': 19,
#  '12817': 19,
#  '12893': 19,
#  '13482_I357': 19,
#  '14454': 19,
#  '14456': 19,
#  '4670_I351': 19,
#  '16688': 19,
#  '16694': 19,
#  '2319_I281': 19,
#  '17622_I281': 19,
#  '17818': 19,
#  '17905': 19,
#  '17937': 19,
#  '18444': 19,
#  '18718': 19,
#  '19433': 19,
#  '71614': 19,
#  '21447_I306': 19,
#  '21454': 19,
#  '21473': 19,
#  '23712': 19,
#  '24181': 19,
#  '24209': 19,
#  '24213': 19,
#  '17100_I115': 19,
#  '27235_I351': 19,
#  '27182_I351': 19,
#  '27419': 19,
#  '27422': 19,
#  '28736': 19,
#  '29275': 19,
#  '29769': 19,
#  '30461': 19,
#  '30860': 19,
#  '35043': 19,
#  '32037': 19,
#  '32332': 19,
#  '25305_I288': 19,
#  '36065': 19,
#  '36234': 19,
#  '36641': 19,
#  '17106_I71': 19,
#  '39969': 19,
#  '40029': 19,
#  '40138': 19,
#  '24717_I306': 19,
#  '42192': 19,
#  '42774': 19,
#  '43844': 19,
#  '45770': 19,
#  '48163': 19,
#  '51088': 19,
#  '52220_I293': 19,
#  '43776_I293': 19,
#  '52311': 19,
#  '52446': 19,
#  '53678': 19,
#  '53820': 19,
#  '59008': 19,
#  '60717': 19,
#  '60832': 19,
#  '61102': 19,
#  '62321': 19,
#  '64813': 19,
#  '66062': 19,
#  '67086': 19,
#  '67093': 19,
#  '67094': 19,
#  '67438': 19,
#  '67797': 19,
#  '66_I300': 19,
#  '2771_I250': 19,
#  '2767_I250': 19,
#  '72752': 19,
#  '20839_I250': 19,
#  '14103_I250': 19,
#  '75337': 19,
#  '9': 18,
#  '1099': 18,
#  '1161': 18,
#  '1167': 18,
#  '1337': 18,
#  '2170': 18,
#  '2179_I251': 18,
#  '2476_I26': 18,
#  '2319_I49': 18,
#  '5209': 18,
#  '6022_I75': 18,
#  '6396': 18,
#  '6756': 18,
#  '41294': 18,
#  '8220_I165': 18,
#  '8629_I165': 18,
#  '11091': 18,
#  '11104': 18,
#  '11244': 18,
#  '12440_I20': 18,
#  '12895_I201': 18,
#  '13069': 18,
#  '2793_I357': 18,
#  '13627_I20': 18,
#  '13858': 18,
#  '13883_I85': 18,
#  '14346': 18,
#  '14441': 18,
#  '14445': 18,
#  '16234': 18,
#  '16528': 18,
#  '16663': 18,
#  '16761': 18,
#  '17137': 18,
#  '13191_I281': 18,
#  '4704_I281': 18,
#  '17630': 18,
#  '17887': 18,
#  '17954': 18,
#  '18024_I281': 18,
#  '19290_I250': 18,
#  '20070': 18,
#  '21462': 18,
#  '23654': 18,
#  '5647_I293': 18,
#  '24117': 18,
#  '24198': 18,
#  '24204': 18,
#  '24385_I61': 18,
#  '24441': 18,
#  '22152_I357': 18,
#  '2941_I241': 18,
#  '28794': 18,
#  '29256': 18,
#  '22605_I348': 18,
#  '30800': 18,
#  '31078_I16': 18,
#  '31169': 18,
#  '29222_I351': 18,
#  '32047': 18,
#  '4025_I351': 18,
#  '32326': 18,
#  '33255': 18,
#  '34741': 18,
#  '8254_I333': 18,
#  '35766': 18,
#  '35869': 18,
#  '26730_I333': 18,
#  '35987_I89': 18,
#  '36055': 18,
#  '36292': 18,
#  '36688_I313': 18,
#  '13802_I285': 18,
#  '38584_I351': 18,
#  '40288': 18,
#  '40321': 18,
#  '35144_I306': 18,
#  '40841': 18,
#  '52351_I253': 18,
#  '11744_I333': 18,
#  '42863': 18,
#  '43311': 18,
#  '44832': 18,
#  '46460': 18,
#  '2783_I103': 18,
#  '51406': 18,
#  '52217_I293': 18,
#  '52251': 18,
#  '3135_I86': 18,
#  '53831': 18,
#  '53861': 18,
#  '56424': 18,
#  '28427_I251': 18,
#  '57978': 18,
#  '5518_I35': 18,
#  '58160': 18,
#  '58834': 18,
#  '61039': 18,
#  '61153': 18,
#  '64524': 18,
#  '64827': 18,
#  '64832': 18,
#  '65053': 18,
#  '65323': 18,
#  '65869': 18,
#  '37362_I271': 18,
#  '66330': 18,
#  '66692': 18,
#  '67232': 18,
#  '39997_I85': 18,
#  '27010_I311': 18,
#  '72057': 18,
#  '72061': 18,
#  '72772': 18,
#  '73125': 18,
#  '74198': 18,
#  '75474': 18,
#  '1512_I224': 17,
#  '1686': 17,
#  '1735': 17,
#  '2421_I306': 17,
#  '2429_I306': 17,
#  '72613': 17,
#  '3343': 17,
#  '4140': 17,
#  '4165': 17,
#  '4379': 17,
#  '4710': 17,
#  '4826': 17,
#  '68753': 17,
#  '5268': 17,
#  '23279_I35': 17,
#  '6313': 17,
#  '229_I250': 17,
#  '7231_I49': 17,
#  '7709': 17,
#  '8623': 17,
#  '8695': 17,
#  '9407': 17,
#  '10536': 17,
#  '51040': 17,
#  '10863': 17,
#  '54340': 17,
#  '12542': 17,
#  '14442': 17,
#  '14515': 17,
#  '14424_I351': 17,
#  '15992': 17,
#  '15996': 17,
#  '56422': 17,
#  '16972': 17,
#  '17123_I281': 17,
#  '17136_I281': 17,
#  '17486': 17,
#  '17674': 17,
#  '17684': 17,
#  '17810': 17,
#  '17919_I281': 17,
#  '18120': 17,
#  '18787': 17,
#  '19080': 17,
#  '19463': 17,
#  '40158': 17,
#  '51407': 17,
#  '20801': 17,
#  '22129_I364': 17,
#  '22433': 17,
#  '23227': 17,
#  '23728': 17,
#  '24045_I364': 17,
#  '24141': 17,
#  '24143': 17,
#  '24978_I357': 17,
#  '25098': 17,
#  '6077_I138': 17,
#  '26267': 17,
#  '27132': 17,
#  '27277': 17,
#  '28571': 17,
#  '16581_I343': 17,
#  '29725': 17,
#  '19050_I343': 17,
#  '31403': 17,
#  '5855_I351': 17,
#  '32096_I351': 17,
#  '59790': 17,
#  '35054': 17,
#  '35219_I351': 17,
#  '35907_I89': 17,
#  '36191': 17,
#  '36376': 17,
#  '36912': 17,
#  '36929': 17,
#  '1638_I266': 17,
#  '37503': 17,
#  '37728_I348': 17,
#  '2760_I348': 17,
#  '51442_I103': 17,
#  '39849': 17,
#  '41469': 17,
#  '42097': 17,
#  '262_I333': 17,
#  '42931': 17,
#  '57051': 17,
#  '15522_I293': 17,
#  '44089': 17,
#  '38538_I313': 17,
#  '46379': 17,
#  '46451': 17,
#  '46462_I58': 17,
#  '46499': 17,
#  '46776': 17,
#  '46799': 17,
#  '51093': 17,
#  '51212': 17,
#  '16007_I103': 17,
#  '52218': 17,
#  '45936_I49': 17,
#  '53070_I86': 17,
#  '53099': 17,
#  '54239': 17,
#  '54242': 17,
#  '54659': 17,
#  '55239': 17,
#  '8487_I333': 17,
#  '57967_I35': 17,
#  '58967': 17,
#  '59023': 17,
#  '8841_I285': 17,
#  '1890_I87': 17,
#  '64145': 17,
#  '64952': 17,
#  '65050': 17,
#  '10822_I107': 17,
#  '1572_I187': 17,
#  '67083': 17,
#  '18834_I292': 17,
#  '14081_I160': 17,
#  '70567': 17,
#  '28998_I175': 17,
#  '71612': 17,
#  '37495_I201': 17,
#  '8336_I250': 17,
#  '73399': 17,
#  '73426': 17,
#  '25624_I49': 17,
#  '75458': 17,
#  '760_I216': 16,
#  '1155': 16,
#  '1163': 16,
#  '1193': 16,
#  '1206_I172': 16,
#  '1694_I224': 16,
#  '1716': 16,
#  '1838_I172': 16,
#  '2173': 16,
#  '2189_I251': 16,
#  '2415_I224': 16,
#  '2563': 16,
#  '2857': 16,
#  '65101': 16,
#  '3776_I20': 16,
#  '4146': 16,
#  '4147': 16,
#  '4184_I35': 16,
#  '4238': 16,
#  '4272': 16,
#  '676_I292': 16,
#  '4977': 16,
#  '5378': 16,
#  '5925': 16,
#  '5958_I75': 16,
#  '6044_I75': 16,
#  '15758_I250': 16,
#  '53398_I250': 16,
#  '6892': 16,
#  '46310': 16,
#  '9668': 16,
#  '7428_I87': 16,
#  '7706_I49': 16,
#  '8132': 16,
#  '8178_I165': 16,
#  '8486_I165': 16,
#  '8498_I165': 16,
#  '9367_I75': 16,
#  '2422_I85': 16,
#  '11332_I85': 16,
#  '11565': 16,
#  '11876': 16,
#  '12474': 16,
#  '30419': 16,
#  '12898': 16,
#  '13143': 16,
#  '13207': 16,
#  '1556_I357': 16,
#  '13622_I20': 16,
#  '13876': 16,
#  '21477': 16,
#  '14176_I85': 16,
#  '14296': 16,
#  '3145_I27': 16,
#  '14514': 16,
#  '54906': 16,
#  '16355_I281': 16,
#  '17112': 16,
#  '17115': 16,
#  '17664': 16,
#  '17671': 16,
#  ...}

# %%
out_dgr_val = out_dgr.values()

# %%
out_dgr_dist = Counter(out_dgr_val)

# %%
deg, cnt = zip(*out_dgr_dist.items())

# %%
out_dgr_dist
# Out:
# Counter({6: 1820,
#          15: 233,
#          7: 1309,
#          0: 160472,
#          1: 42974,
#          2: 12390,
#          3: 6419,
#          18: 117,
#          4: 3853,
#          5: 2512,
#          8: 1073,
#          9: 753,
#          24: 47,
#          12: 385,
#          10: 578,
#          11: 456,
#          31: 19,
#          13: 296,
#          27: 30,
#          33: 11,
#          16: 164,
#          14: 248,
#          26: 40,
#          19: 96,
#          55: 1,
#          23: 45,
#          20: 96,
#          22: 66,
#          43: 6,
#          34: 7,
#          17: 130,
#          21: 61,
#          61: 1,
#          28: 23,
#          59: 1,
#          35: 10,
#          54: 1,
#          38: 10,
#          36: 8,
#          41: 2,
#          30: 19,
#          25: 30,
#          32: 12,
#          48: 1,
#          29: 21,
#          46: 4,
#          50: 3,
#          42: 1,
#          45: 5,
#          40: 3,
#          129: 1,
#          60: 1,
#          37: 3,
#          58: 1,
#          52: 1,
#          39: 2,
#          44: 1,
#          49: 1,
#          67: 1})

# %%
fig, ax = plt.subplots(figsize=(18,12))
plt.bar(deg, cnt, width=0.80, color="b")

plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
#ax.set_xticks([d for d in deg])
#ax.set_xticklabels(deg)
plt.show()

# %% [markdown]
# <h2>ANCESTORS, DESCENDANTS</h2>

# %%
len(nx.descendants(graph1,"20913"))
# Out:
# 75

# %%
len(nx.ancestors(graph1,"20913"))
# Out:
# 0

# %%
ment2.columns
# Out:
# Index(['advisorId', 'researcherId', 'advId_1', 'studId_1', 'advisor_name',
#        'researcher_name', 'dc.date.submitted[]', 'dc.language.iso[]',
#        'dc.publisher.department[]', 'DepartmentId',
#        'dc.publisher.institution[]', 'instituteId', 'dc.title[]', 'thesisId',
#        'dc.type.degree', 'dc.date.awarded', 'dc.subject.ddc', 'dc.source.uri',
#        'dc.description.abstract', 'dc.title.alternative'],
#       dtype='object')

# %%
ment2[(ment2["advId_1"]=="393_I333")]#['dc.publisher.department[]'].value_counts()
# Out:
#         advisorId  researcherId   advId_1 studId_1 advisor_name  \
# 86830         408        146855  393_I333   146855    Mohan, S.
# 107049        408        161233  393_I333   161233    Mohan, S.
# 107053        408        161234  393_I333   161234    Mohan, S.
# 107080        408        161247  393_I333   161247    Mohan, S.
# 107082        408        161248  393_I333   161248    Mohan, S.
# ...           ...           ...       ...      ...          ...
# 107424        408         61172  393_I333    61172    Mohan, S.
# 107426        408         44073  393_I333    44073    Mohan, S.
# 107429        408        161402  393_I333   161402    Mohan, S.
# 107432        408        161405  393_I333   161405    Mohan, S.
# 143016        408        190423  393_I333   190423    Mohan, S.
#
#           researcher_name dc.date.submitted[] dc.language.iso[]  \
# 86830         Moorthy, K.          01-01-2001               eng
# 107049  Vijayakumar, M P.          26-06-2009               eng
# 107053     Sasikala, K R.          23-05-2011               eng
# 107080    Dawood Shah, S.          01-01-2006               eng
# 107082        Manulal, G.          01-01-2007               eng
# ...                   ...                 ...               ...
# 107424           Mani, P.          11-06-2009               eng
# 107426   Govindarajan, K.          03-11-2009               eng
# 107429        Brindha, S.          30-12-2010               eng
# 107432          Deepa, S.          08-04-2011               eng
# 143016         Priya, MRC          13-01-2011               eng
#
#                             dc.publisher.department[] DepartmentId  \
# 86830           department of corporate secretaryship        D1120
# 107049                        department of education        D1418
# 107053                        department of education        D1418
# 107080                        department of education        D1418
# 107082                        department of education        D1418
# ...                                               ...          ...
# 107424                        department of education        D1418
# 107426                        department of education        D1418
# 107429                        department of education        D1418
# 107432                        department of education        D1418
# 143016  department of economics and rural development        D1597
#
#        dc.publisher.institution[] instituteId  \
# 86830         Alagappa University        I333
# 107049        Alagappa University        I333
# 107053        Alagappa University        I333
# 107080        Alagappa University        I333
# 107082        Alagappa University        I333
# ...                           ...         ...
# 107424        Alagappa University        I333
# 107426        Alagappa University        I333
# 107429        Alagappa University        I333
# 107432        Alagappa University        I333
# 143016        Alagappa University        I333
#
#                                                dc.title[] thesisId  \
# 86830   Effectiveness of competency based education pr...  T113335
# 107049  Financial management in primary education in C...  T128685
# 107053  Metacognitive orientation in learning English ...   T67664
# 107080                      Prophet Muhammad as a teacher   T47308
# 107082  Managerial roles performance by the heads of s...  T153565
# ...                                                   ...      ...
# 107424  A comparative study of the achievement in math...   T48950
# 107426  Emotional intelligence, aptitude and achieveme...  T161679
# 107429  Motivated self regulated learning and academic...  T162040
# 107432  Influence of remedial techniques on improving ...   T37192
# 143016  Teacher effectiveness of postgraduate teachers...   T19876
#
#        dc.type.degree dc.date.awarded  \
# 86830             phd             NaN
# 107049            phd      23-07-2010
# 107053            phd      16-04-2012
# 107080            phd             NaN
# 107082            phd             NaN
# ...               ...             ...
# 107424            phd      24-04-2010
# 107426            phd      29-05-2010
# 107429            phd      27-04-2012
# 107432            phd      03-02-2012
# 143016            phd      10-01-2012
#
#                                            dc.subject.ddc  \
# 86830   600::Technology|650::Management & auxiliary se...
# 107049                300::Social sciences|370::Education
# 107053                300::Social sciences|370::Education
# 107080                300::Social sciences|370::Education
# 107082                300::Social sciences|370::Education
# ...                                                   ...
# 107424                300::Social sciences|370::Education
# 107426                300::Social sciences|370::Education
# 107429                300::Social sciences|370::Education
# 107432                300::Social sciences|370::Education
# 143016                300::Social sciences|330::Economics
#
#                              dc.source.uri dc.description.abstract  \
# 86830   http://shodhganga.inflibnet.ac.in/                     NaN
# 107049  http://shodhganga.inflibnet.ac.in/                     NaN
# 107053  http://shodhganga.inflibnet.ac.in/                     NaN
# 107080  http://shodhganga.inflibnet.ac.in/                     NaN
# 107082  http://shodhganga.inflibnet.ac.in/                     NaN
# ...                                    ...                     ...
# 107424  http://shodhganga.inflibnet.ac.in/                     NaN
# 107426  http://shodhganga.inflibnet.ac.in/                     NaN
# 107429  http://shodhganga.inflibnet.ac.in/                     NaN
# 107432  http://shodhganga.inflibnet.ac.in/                     NaN
# 143016  http://shodhganga.inflibnet.ac.in/                     NaN
#
#        dc.title.alternative
# 86830                   NaN
# 107049                  NaN
# 107053                  NaN
# 107080                  NaN
# 107082                  NaN
# ...                     ...
# 107424                  NaN
# 107426                  NaN
# 107429                  NaN
# 107432                  NaN
# 143016                  NaN
#
# [129 rows x 20 columns]

# %%
#mod_ment[(mod_ment["studId_1"].str.contains("_"))].shape

# %%
ment2[ment2['advId_1'].str.contains("^393_")]["advId_1"].value_counts()
# Out:
# 393_I333    129
# 393_I92      13
# 393_I103     11
# 393_I250      7
# 393_I253      7
# 393_I357      3
# 393_I17       2
# 393_I364      1
# Name: advId_1, dtype: int64

# %%
ment2[ment2["studId_1"].str.contains("^"+"393"+"_")]
# Out:
#         advisorId  researcherId     advId_1  studId_1       advisor_name  \
# 47875       19429           408       19429  393_I333  Shivarudrappa, G.
# 101708      40845           408  40845_I253  393_I253          Gopal, G.
# 135892      51145           408       51145  393_I103     Kasinathan, P.
# 182901      68582           408   68582_I92   393_I92        Murugan, R.
# 182917      68585           408   68585_I92   393_I92    Karthikeyan, B.
#
#        researcher_name dc.date.submitted[] dc.language.iso[]  \
# 47875        Mohan, S.          31-07-1981               eng
# 101708       Mohan, S.          30-04-1995               eng
# 135892       Mohan, S.          01-01-2004               eng
# 182901       Mohan, S.          01-02-1998               eng
# 182917       Mohan, S.          01-11-2002               eng
#
#                     dc.publisher.department[] DepartmentId  \
# 47875                 department of education        D1418
# 101708                 department of commerce        D1072
# 135892             department of microbiology         D151
# 182901  department of raman school of physics        D2128
# 182917  department of raman school of physics        D2128
#
#        dc.publisher.institution[] instituteId  \
# 47875         Karnatak University         I26
# 101708      Bharathiar University        I253
# 135892   Bharathidasan University        I103
# 182901     Pondicherry University         I92
# 182917     Pondicherry University         I92
#
#                                                dc.title[] thesisId  \
# 47875   A critical study of factors related to withdra...    T8615
# 101708  A study on the sources and utilisation of fina...  T177557
# 135892  Studies on fungal phytase and its effect on bi...  T188836
# 182901  Investigations on the fourier transform infrar...   T53189
# 182917  Optical studies on technologically important n...   T48413
#
#        dc.type.degree dc.date.awarded  \
# 47875             phd             NaN
# 101708            phd             NaN
# 135892            phd             NaN
# 182901            phd             NaN
# 182917            phd             NaN
#
#                                            dc.subject.ddc  \
# 47875                 300::Social sciences|370::Education
# 101708  300::Social sciences|380::Commerce, communicat...
# 135892  500::Natural sciences & mathematics|570::Life ...
# 182901   500::Natural sciences & mathematics|530::Physics
# 182917   500::Natural sciences & mathematics|530::Physics
#
#                              dc.source.uri dc.description.abstract  \
# 47875   http://shodhganga.inflibnet.ac.in/                     NaN
# 101708  http://shodhganga.inflibnet.ac.in/                     NaN
# 135892  http://shodhganga.inflibnet.ac.in/                     NaN
# 182901  http://shodhganga.inflibnet.ac.in/                     NaN
# 182917  http://shodhganga.inflibnet.ac.in/                     NaN
#
#        dc.title.alternative
# 47875                   NaN
# 101708                  NaN
# 135892                  NaN
# 182901                  NaN
# 182917                  NaN
