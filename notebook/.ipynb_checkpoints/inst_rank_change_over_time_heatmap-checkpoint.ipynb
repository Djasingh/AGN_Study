# %%
from multiprocessing import Pool
from collections import Counter
import matplotlib.pyplot as plt
import networkx as nx
from tqdm import tqdm
import pandas as pd
import numpy as np
import import_ipynb
import itertools
import json
import sys

# %%
from metric_util_func import *
# Out:
# importing Jupyter notebook from metric_util_func.ipynb

# %%
# %matplotlib inline

# %%
folder="../dataset_v5/v5_2/"

# %%
mod_ment2 = pd.read_csv(folder+'v5_2_2/'+'final_shodhganga_dataset_v5_2_6.csv', sep =",")

# %%
mod_ment2.columns
# Out:
# Index(['advisorId', 'researcherId', 'advId', 'resId', 'advisor_name',
#        'researcher_name', 'publisher_dept', 'DepartmentId',
#        'publisher_institution', 'instituteId', 'title', 'thesisId',
#        'N_thesisId', 'date_submitted', 'new_date_awarded', 'dc.date.awarded',
#        'dc.subject.ddc', 'uniq_ddc_across_dept', 'dc.description.abstract',
#        'dc.title.alternative', 'N_DepartmentId_1', 'ddc_code', 'advisor_advId',
#        'researcher_resId'],
#       dtype='object')

# %%
mod_ment2.shape
# Out:
# (201477, 24)

# %%
mod_ment2['new_date_awarded']=pd.to_datetime(mod_ment2['new_date_awarded'],errors='coerce')

# %%
# mod_ment2 = mod_ment2.set_index('new_date_awarded')
# df_filter=mod_ment2.loc[:"1940-01-01"].copy()

# %%
# df_filter[df_filter['instituteId']=='I89']['title'].values
# Out:
# array(['A study of the social structure of Patidar migrants living in Anand and Nadiad cities of Gujarat state'],
#       dtype=object)

# %%
# df_filter

# %%
inx_to_inst=dict(zip(mod_ment2.instituteId,mod_ment2.publisher_institution))

# %%
inx_to_inst
# Out:
# {'I251': 'Mahatma Gandhi University',
#  'I368': 'Symbiosis International University',
#  'I26': 'Karnatak University',
#  'I58': 'Shivaji University',
#  'I346': 'Jawaharlal Nehru Technological University, Anantapuram',
#  'I216': 'Guru Nanak Dev University',
#  'I265': 'Sant Gadge Baba Amravati University',
#  'I253': 'Bharathiar University',
#  'I312': 'JK Lakshmipat University',
#  'I300': 'Sri Venkateswara University',
#  'I87': 'Panjab University',
#  'I35': 'Maharshi Dayanand University',
#  'I92': 'Pondicherry University',
#  'I38': 'University of Kashmir',
#  'I3': 'Karunya University',
#  'I295': 'Swami Ramanand Teerth Marathwada University',
#  'I218': 'Suresh Gyan Vihar University',
#  'I53': 'Chaudhary Sarwan Kumar Himachal Pradesh Krishi Vishvavidyalaya',
#  'I17': 'Shri Jagdishprasad Jhabarmal Tibarewala University',
#  'I106': 'Tamil University',
#  'I180': 'Hemchandracharya North Gujarat University',
#  'I88': 'Sri Satya Sai University of Technology and Medical Sciences',
#  'I121': 'University of Rajasthan',
#  'I34': 'B S Abdur Rahman University',
#  'I288': 'Tata Institute of Social Sciences',
#  'I162': 'The IIS University',
#  'I310': 'Dayalbag Educational Institute',
#  'I50': 'Dayalbagh Educational Institute',
#  'I217': 'Visva Bharti University',
#  'I302': 'University of Kalyani',
#  'I46': 'C.U. Shah University',
#  'I120': 'University of Hyderabad',
#  'I19': 'Patna University',
#  'I148': 'Punjabi University',
#  'I320': 'Nagaland University',
#  'I267': 'Uttarakhand Sanskrit University',
#  'I211': 'The Northcap University (Formerly ITM University, Gurgaon)',
#  'I172': 'Cochin University of Science and Technology',
#  'I285': 'Maharaja Sayajirao University of Baroda',
#  'I178': 'University of Allahabad',
#  'I47': 'SRM University',
#  'I89': 'Sardar Patel University',
#  'I271': 'Acharya Nagarjuna University',
#  'I342': 'Amity University',
#  'I55': 'Jaypee University of Information Technology, Solan',
#  'I260': 'Manipur University',
#  'I249': 'University of Calicut',
#  'I156': 'Mizoram University',
#  'I127': 'Maharishi Markandeshwar University',
#  'I84': 'Maharishi Markandeshwar University, Mullana',
#  'I185': 'Shoolini University of Biotechnology and Management Sciences',
#  'I194': 'University of Lucknow',
#  'I316': 'Manipal University',
#  'I339': 'Jaypee University of Engineering and Technology, Guna',
#  'I224': 'Bundelkhand University',
#  'I351': 'Savitribai Phule Pune University',
#  'I128': 'ICFAI Foundation for Higher Education',
#  'I144': 'North Maharashtra University',
#  'I31': 'Baba Ghulam Shah Badshah University',
#  'I350': 'Gujarat Vidyapith',
#  'I40': 'University of Mysore',
#  'I313': 'Gujarat University',
#  'I333': 'Alagappa University',
#  'I133': 'Rajiv Gandhi National University of Law Punjab',
#  'I110': 'CHRIST University',
#  'I256': 'Kavikulaguru Kalidas Sanskrit University',
#  'I145': 'Centurion University of Technology and Management',
#  'I327': 'Mohan Lal Sukhadia University',
#  'I10': 'Charotar University of Science and Technology',
#  'I292': 'Aligarh Muslim University',
#  'I183': 'VIT University',
#  'I306': 'V. B. S. Purvanchal University',
#  'I293': 'Sri Krishnadevaraya University',
#  'I57': 'Hemwati Nandan Bahuguna Garhwal University',
#  'I181': 'Bhagwant University',
#  'I136': 'Sri Chandrasekharendra Saraswathi Viswa Mahavidyalaya',
#  'I357': 'Manonmaniam Sundaranar University',
#  'I364': 'University of Madras',
#  'I189': 'The English and Foreign Languages University, Hyderabad',
#  'I100': 'Tezpur University',
#  'I209': 'Guru Gobind Singh Indraprastha University',
#  'I122': 'Integral University',
#  'I259': 'SNDT Womens University',
#  'I244': 'Kannur University',
#  'I118': 'The Gandhigram Rural Institute',
#  'I20': 'Banasthali Univesity',
#  'I309': 'Banasthali Vidyapith',
#  'I112': 'Graphic Era University',
#  'I210': 'Gujarat Technological University',
#  'I49': 'Himachal Pradesh University',
#  'I124': 'Jiwaji University',
#  'I140': 'Devi Ahilya Vishwavidyalaya',
#  'I142': 'Jamia Milia Islamia University',
#  'I85': 'Jawaharlal Nehru University',
#  'I175': 'Jamia Hamdard University',
#  'I337': 'Lovely Professional University',
#  'I5': 'Guru Jambheshwar University of Science and Technology',
#  'I196': 'Kurukshetra University',
#  'I52': 'Homi Bhabha National Institute',
#  'I250': 'Anna University',
#  'I349': 'Prist University',
#  'I103': 'Bharathidasan University',
#  'I8': 'Guru Ghasidas University',
#  'I71': 'University of North Bengal',
#  'I129': 'Narsee Monjee Institute of Management Studies',
#  'I347': 'Sharda University',
#  'I90': 'Sikkim Manipal University',
#  'I365': 'Pandit Deendayal Petroleum University',
#  'I356': 'Periyar Maniammai University',
#  'I336': 'Dr. D Y Patil Vidyapeeth',
#  'I332': 'Babu Banarasi Das University',
#  'I279': 'JSS University',
#  'I311': 'University of Kerala',
#  'I75': 'Utkal University',
#  'I73': 'Mangalore University',
#  'I108': 'Goa University',
#  'I131': 'Avinashilingam Deemed University For Women',
#  'I68': 'Graphic Era Hill University Dehradun',
#  'I301': 'Dr. M.G.R. Educational and Research Institute',
#  'I299': 'Central University of Kerala',
#  'I228': 'RK University',
#  'I207': 'International Institute of Information Technology, Hyderabad',
#  'I9': 'Indira Gandhi National Open University IGNOU',
#  'I335': 'Kalasalingam University',
#  'I343': 'The University of Burdwan',
#  'I4': 'Jadavpur University',
#  'I13': 'Tilak Maharashtra Vidyapeeth',
#  'I33': 'Central University of Punjab',
#  'I113': 'Bharati Vidyapeeth Deemed University',
#  'I236': 'Krishna Institute of Medical Sciences University',
#  'I152': 'Dr Ram Manohar Lohiya National Law University',
#  'I115': 'Chaudhary Charan Singh University',
#  'I340': 'University of Delhi',
#  'I233': 'Tumkur University',
#  'I254': 'Mewar University',
#  'I205': 'Manav Rachna International University',
#  'I65': 'Maulana Azad National Urdu University',
#  'I208': 'Central University of Himachal Pradesh',
#  'I153': 'The ICFAI University',
#  'I272': 'ICFAI University, Dehradun',
#  'I195': 'North Eastern Regional Institute of Science and Technology (NERIST)',
#  'I37': 'Shiksha o Anusandhan University',
#  'I325': 'Teerthanker Mahaveer University',
#  'I367': 'KIIT University',
#  'I308': 'Gujarat Forensic Sciences University',
#  'I165': 'Madurai Kamraj University',
#  'I245': 'Rajiv Gandhi University',
#  'I186': 'Birla Institute of Technology and Science',
#  'I111': 'Saurashtra University',
#  'I39': 'Mahatma Gandhi Antarrashtriya Hindi Vishwavidyalaya',
#  'I177': 'IFTM University',
#  'I326': 'Sri Sathya Sai Institute of Higher Learning',
#  'I328': 'Karnataka State Womens University',
#  'I255': 'GLA University',
#  'I98': 'Sam Higginbottom Institute of Agriculture, Technology and Sciences',
#  'I317': 'Andhra University',
#  'I116': 'Deccan College Post Graduate And Research Institute',
#  'I102': 'GITAM University',
#  'I138': 'Sambalpur University',
#  'I241': 'Assam University',
#  'I273': 'Kumaun University',
#  'I24': 'Gokhale Institute of Politics and Economics',
#  'I280': 'Solapur University',
#  'I198': 'Jai Narain Vyas University',
#  'I266': 'Pt. Ravishankar Shukla University',
#  'I168': 'Nirma University',
#  'I286': 'Sri Padmavathi Womens University',
#  'I227': 'Gujarat Ayurveda University',
#  'I323': 'Vikram University',
#  'I166': 'Vel Tech Dr. R R and Dr. S R Technical University',
#  'I141': 'SASTRA University',
#  'I204': 'JECRC University',
#  'I51': 'Institute of Chemical Technology',
#  'I268': 'Sree Sankaracharya University of Sanskrit',
#  'I247': 'Gujarat National Law University',
#  'I225': 'Osmania University',
#  'I202': 'Pravara Institute of Medical Sciences',
#  'I201': 'Dr. Babasaheb Ambedkar Marathwada University',
#  'I96': 'Ganpat University',
#  'I240': 'Annamalai University',
#  'I91': 'TERI University',
#  'I27': 'University of Petroleum and Energy Studies (UPES)',
#  'I117': 'Gulbarga University',
#  'I60': 'Uttarakhand Technical University',
#  'I77': 'Koneru Lakshmaiah Education Foundation',
#  'I352': 'Krishna Kanta Handiqui State Open University',
#  'I319': 'University of Pune',
#  'I28': 'Madhav University',
#  'I355': 'Maharshi Dayanand Saraswati University',
#  'I297': 'Bangalore University',
#  'I25': 'Singhania University',
#  'I61': 'Gauhati University',
#  'I97': 'Poornima University',
#  'I132': 'Calorx Teachers University',
#  'I86': 'North-Eastern Hill University',
#  'I361': 'Shiv Nadar University',
#  'I197': 'Central University of Gujarat',
#  'I126': 'Central University of Rajasthan',
#  'I83': 'Vivekananda Global University',
#  'I281': 'University of Calcutta',
#  'I296': 'Martin Luther Christian University',
#  'I305': 'Rai University',
#  'I119': 'Hindustan University',
#  'I290': 'University of Jammu',
#  'I187': 'Maharaja Krishnakumarsinhji Bhavnagar University',
#  'I171': 'Mother Teresa Womens University',
#  'I160': 'Dr. Harisingh Gour Vishwavidyalaya',
#  'I287': 'Guru Kashi University',
#  'I105': 'Vels University',
#  'I78': 'University of Science and Technology, Meghalaya',
#  'I191': 'Jayoti Vidyapeeth Women s University',
#  'I45': 'Uttaranchal University',
#  'I370': 'Shri Mata Vaishno Devi University',
#  'I16': 'Jawaharlal Nehru Technological University, Hyderabad',
#  'I298': 'Sri Ramachandra University',
#  'I219': 'Central University of Orissa',
#  'I44': 'Islamic University of Science and Technology',
#  'I318': 'Mangalayatan University',
#  'I62': 'Dibrugarh University',
#  'I32': 'Bharath University',
#  'I226': 'Navrachana University',
#  'I76': 'Tripura University',
#  'I104': 'Chitkara University',
#  'I303': 'Krantiguru Shyamji Krishna Verma Kachchh University',
#  'I329': 'Swarnim Gujarat Sports University',
#  'I348': 'Periyar University',
#  'I212': 'Chettinad Academy of Research and Education',
#  'I69': 'Vardhaman Mahaveer Open University, Kota',
#  'I222': 'Veer Surendra Sai University of Technology',
#  'I173': 'Forest Research Institute University',
#  'I214': 'RKDF University',
#  'I283': 'Ansal University',
#  'I366': 'Kadi Sarva Vishwavidyalaya',
#  'I15': 'Central University of Kashmir',
#  'I80': 'AISECT University',
#  'I137': 'Assam Don Bosco University',
#  'I294': 'Manipal University Jaipur',
#  'I246': 'Geetanjali University',
#  'I237': 'MATS University',
#  'I363': 'St. Peters University',
#  'I220': 'MGM Institute of Health Sciences',
#  'I95': 'Bhagat Phool Singh Mahila Vishwavidyalaya',
#  'I56': 'Vinayaka Missions University',
#  'I67': 'Suamandeep Vidyapeeth University',
#  'I314': 'Ahmedabad University',
#  'I161': 'Maharishi Markandeshwar University, Sodapur (Ambala)',
#  'I261': 'Nitte University',
#  'I54': 'Indraprastha Institute of Information Technology, Delhi (IIIT-Delhi)',
#  'I7': 'Amrita Vishwa Vidyapeetham (University)',
#  'I48': 'International Institute for Population Sciences IIPS',
#  'I307': 'Jain University',
#  'I330': 'Central University of Haryana',
#  'I29': 'Delhi Technological University',
#  'I182': 'Maharaja Ganga Singh University',
#  'I107': 'Kuvempu University',
#  'I334': 'Indian Institute of Space Science and Technology',
#  'I82': 'Chitkara University, Punjab',
#  'I125': 'AMET University',
#  'I258': 'BLDE University',
#  'I264': 'Sir Padampat Singhania University',
#  'I358': 'Sikkim University',
#  'I70': 'Datta Meghe Institute of Medical Sciences',
#  'I150': 'Sant Longowal Institute of Engineering and Technology',
#  'I163': 'Jagannath University',
#  'I143': 'Shri Lal Bahadur Shastri Rashtriya Sanskrit Vidyapeetha',
#  'I359': 'I K Gujral Punjab Techncial University',
#  'I179': 'Punjab Technical University',
#  'I158': 'Institute of Advanced Studies in Education (IASE)',
#  'I193': 'Desh Bhagat University',
#  'I278': 'Indian Institute of Information Technology Design and Manufacturing Kancheepuram',
#  'I345': 'Jharkhnad Rai University',
#  'I21': 'Pacific University',
#  'I269': 'Raiganj University',
#  'I154': 'Tamil Nadu Dr. Ambedkar Law University',
#  'I199': 'Sai Nath University',
#  'I262': 'Sri Venkateswara Institute of Medical Sciences',
#  'I134': 'Swami Vivekananad University',
#  'I79': 'Jodhpur National University',
#  'I170': 'National Law School of India University',
#  'I66': 'The Tamil Nadu Dr. M.G.R. Medical University',
#  'I248': 'Chandigarh University',
#  'I146': 'Raksha Shakti University',
#  'I230': 'Sri Devaraj Urs Academy of Higher Education and Research',
#  'I190': 'National Brain Research Centre',
#  'I238': 'Mahatma Gandhi Chitrakoot Gramodaya Vishwavidyalaya',
#  'I59': 'University of Kota',
#  'I94': 'SGT University',
#  'I263': 'Amity University Madhya Pradesh',
#  'I114': 'Bodoland University',
#  'I223': 'Uttarakhand Open University',
#  'I149': 'Babasaheb Bhimrao Ambedkar University',
#  'I274': 'Chhatrapati Sahuji Maharaj University',
#  'I63': 'Shri Vaishnav Vidyapeeth Vishwavidyalaya',
#  'I18': 'Rabindra Bharati University',
#  'I164': 'Chaudhary Devi Lal University',
#  'I23': 'Santosh Deemed to be University',
#  'I135': 'Galgotias University',
#  'I276': 'Banaras Hindu University',
#  'I353': 'Thapar Institute of Engineering and Technology',
#  'I242': 'Monad University',
#  'I64': 'Nims University Rajasthan',
#  'I151': 'Central University of Jharkhand',
#  'I213': 'National law University, Delhi',
#  'I235': 'Maharashtra Animal and Fishery Sciences University',
#  'I93': 'University of Gour Banga',
#  'I42': 'Central University of Jammu',
#  'I215': 'The National University of Advanced Legal Studies',
#  'I12': 'Tamilnadu Physical Education and Sports University',
#  'I139': 'Jawaharlal Nehru Technological University',
#  'I169': 'Lakshmibai National University of Physical Education',
#  'I362': 'Shobhit University',
#  'I284': 'J. R. N. Rajasthan Vidyapeeth University',
#  'I123': 'Jaypee Institute of Information Technology',
#  'I331': 'Swami Vivekanad Subharti University',
#  'I74': 'Veer Narmad South Gujarat University',
#  'I239': 'Dr. Babasaheb Ambedkar Technological University',
#  'I155': 'Gurukul Kangri Vishwavidyalaya',
#  'I167': 'Madhya Pradesh Bhoj (Open) University',
#  'I6': 'Bhupendra Narayan Mandal University',
#  'I321': 'Guru Angad Dev Veterinary and Animal Sciences University',
#  'I229': 'Indian School of Mines',
#  'I277': 'Lingayas University',
#  'I203': 'University of Mumbai',
#  'I282': 'Vidyasagar University',
#  'I2': 'Saveetha University',
#  'I184': 'Indian Institute of Foreign Trade',
#  'I360': 'Jai Prakash Vishwavidyalaya',
#  'I322': 'D Y Patil University',
#  'I147': 'St Peters University',
#  'I36': 'Jain Vishwa Bharati University',
#  'I338': 'Sri Ramachandra Medical College and Research Institute',
#  'I354': 'Eternal University',
#  'I1': 'Dhirubhai Ambani Institute of Information and Communication Technology (DA-IICT)',
#  'I324': 'Karnataka State Open University',
#  'I221': 'KLE University',
#  'I252': "St. Peter's University",
#  'I232': 'International Institute of Information Technology Bangalore',
#  'I200': 'University of Agricultural Sciences, Bangalore',
#  'I22': 'Teri University',
#  'I159': 'West Bengal University of Technology',
#  'I81': 'Dravidian University',
#  'I231': 'Magadh University',
#  'I206': 'Karnataka Veterinary, Animal and Fisheries Sciences University',
#  'I41': 'Noorul Islam Centre for Higher Education',
#  'I369': 'Dr. Ram Manohar Lohia Avadh University',
#  'I174': 'ICFAI University, Jharkhand',
#  'I43': 'Alliance University',
#  'I14': 'Yashwantrao Chavan Maharashtra Open University',
#  'I157': 'Indian Institute of Management Indore',
#  'I270': 'Swami Vivekananda Yoga Anusandhana Sansthana',
#  'I188': 'Kushabhau Thakre Patrakarita Avam Jansanchar Vishwavidyalaya',
#  'I192': 'Ramakrishna Mission Vivekananda University',
#  'I291': 'National Institute of Technology,Kurukshetra',
#  'I344': 'G.B.Pant University of Agriculture and Technology',
#  'I243': 'Junagadh Agricultural University',
#  'I101': 'V O Chidambaram College of Education',
#  'I315': 'Indira Gandhi University Meerpur,Rewari',
#  'I109': 'Rani Durgavati Vishwavidyalaya',
#  'I257': 'The Datta Meghe Institute of Medical Sciences',
#  'I30': 'YMCA University of Science and Technology',
#  'I275': 'Pandit Dwarka Prasad Mishra Indian Institute of Information Technology, Design and Manufacturing',
#  'I304': 'U P Rajarshi Tondon Open University',
#  'I130': 'Rashtrasant Tukadoji Maharaj Nagpur University',
#  'I99': 'IEC University',
#  'I341': 'Arni University',
#  'I11': 'Netaji Subhas Open University',
#  'I176': 'Ranchi University'}

# %%
important_labels = {
'Gauhati University':'GU',
'Aligarh Muslim University':"AMU",
'Karnatak University':"KU",
'Gujarat University': 'GUJU',
'Mahatma Gandhi University':'MGU',
'Utkal University':'UTU',
'Kuvempu University':'KUU',
'Sardar Patel University':'SPU',
'Jamia Milia Islamia University':'JMIU',
'University of Hyderabad':'UOH',
'Savitribai Phule Pune University':'SPPU',
'University of Calcutta':'UOC',
'Panjab University':'PU',
'Maharaja Sayajirao University of Baroda':'MSUOB',
'Dr. Harisingh Gour Vishwavidyalaya':'HGV',
'University of Kerala':'UOK',
'Jawaharlal Nehru University':'JNU',
'Dr. Babasaheb Ambedkar Marathwada University':'BAMU',
'Anna University':'AU',
'V. B. S. Purvanchal University':'VBSPU',
'University of Mysore':'UOM',
'Bharathiar University':'BU',
'Bharathidasan University':'BHAU',
'Maharshi Dayanand University':'MDU',
'Shivaji University':'SU',
'Manonmaniam Sundaranar University':'MSU',
'Sri Krishnadevaraya University':'SKU',
'University of Madras':'UOM',}

# %%
labels = list(important_labels.items())

# %%
df = pd.DataFrame(labels)

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lll}
# \toprule
# {} &                                             0 &      1 \\
# \midrule
# 0  &                            Gauhati University &     GU \\
# 1  &                     Aligarh Muslim University &    AMU \\
# 2  &                           Karnatak University &     KU \\
# 3  &                            Gujarat University &   GUJU \\
# 4  &                     Mahatma Gandhi University &    MGU \\
# 5  &                              Utkal University &    UTU \\
# 6  &                            Kuvempu University &    KUU \\
# 7  &                       Sardar Patel University &    SPU \\
# 8  &                Jamia Milia Islamia University &   JMIU \\
# 9  &                       University of Hyderabad &    UOH \\
# 10 &              Savitribai Phule Pune University &   SPPU \\
# 11 &                        University of Calcutta &    UOC \\
# 12 &                             Panjab University &     PU \\
# 13 &       Maharaja Sayajirao University of Baroda &  MSUOB \\
# 14 &            Dr. Harisingh Gour Vishwavidyalaya &    HGV \\
# 15 &                          University of Kerala &    UOK \\
# 16 &                   Jawaharlal Nehru University &    JNU \\
# 17 &  Dr. Babasaheb Ambedkar Marathwada University &   BAMU \\
# 18 &                               Anna University &     AU \\
# 19 &                V. B. S. Purvanchal University &  VBSPU \\
# 20 &                          University of Mysore &    UOM \\
# 21 &                         Bharathiar University &     BU \\
# 22 &                      Bharathidasan University &   BHAU \\
# 23 &                  Maharshi Dayanand University &    MDU \\
# 24 &                            Shivaji University &     SU \\
# 25 &             Manonmaniam Sundaranar University &    MSU \\
# 26 &                Sri Krishnadevaraya University &    SKU \\
# 27 &                          University of Madras &    UOM \\
# \bottomrule
# \end{tabular}

# %%
mod_inx_to_inst = {key:important_labels[key1] for key1 in important_labels for key in inx_to_inst if inx_to_inst[key]==key1}

# %%
#mod_inx_to_inst

# %%
# graph1 = nx.convert_matrix.from_pandas_edgelist(mod_ment2, 'advId','resId','instituteId', create_using=nx.DiGraph())
# graph1.remove_edges_from(nx.selfloop_edges(graph1))
# cycle=list(nx.simple_cycles(graph1))
# graph1.remove_edges_from(cycle)

# %%
#ax=draw_rank_heatmap()

# %%
ax=draw_rank_heatmap2(df=mod_ment2,inx_to_inst=mod_inx_to_inst,func1=Counter, func2=thesis_advised_cumlative, metric=0, title="")
fig=ax.get_figure()#Change in institute rank (based on thesis advised) over time
#fig.savefig('graphs/inst_rank_heatmap_with_thesis.png',bbox_inches='tight')
fig.savefig('../new_graphs/inst_rank_heatmap_with_thesis.svg',bbox_inches='tight')
# 14455 records missing date field, Based On thesis advised

# %%
#fig2=ax.get_figure()

# %%
#fig2.savefig('inst_rank1.png',bbox_inches='tight')

# %%
ax1 = draw_rank_heatmap2(df=mod_ment2,inx_to_inst=mod_inx_to_inst, from_y=1940, to_y=2020, step_size=20, func1=inst_wise_val, func2=other_metrics1, metric=2, title="")#Change in institute rank (based on fertility value) over time
fig1=ax1.get_figure()
#fig1.savefig('graphs/inst_rank_heatmap_with_fertility.png', bbox_inches='tight')
fig1.savefig('../new_graphs/inst_rank_heatmap_with_fertility.svg', bbox_inches='tight')

# %%
ax2 = draw_rank_heatmap2(df=mod_ment2,inx_to_inst=mod_inx_to_inst, from_y=1940, to_y=2020, step_size=20, func1=inst_wise_val, func2=other_metrics1, metric=3, title="")#Change in institute rank (based on h-index value) over time
fig2=ax2.get_figure()
#fig2.savefig('graphs/inst_rank_heatmap_with_hindex.png', bbox_inches='tight')
fig2.savefig('../new_graphs/inst_rank_heatmap_with_hindex.svg', bbox_inches='tight')

# %%
ax3 = draw_rank_heatmap1(df=mod_ment2,inx_to_inst=mod_inx_to_inst, from_y=1940, to_y=2020, step_size=20, func1=inst_wise_val, func2=other_metrics1, metric=4, title="")#Change in institute rank (based on g_index value) over time
fig3=ax3.get_figure()
#fig3.savefig('graphs/inst_rank_heatmap_with_g_index.png',bbox_inches='tight')
fig3.savefig('../new_graphs/inst_rank_heatmap_with_g_index.svg',bbox_inches='tight')

# %%
#len(set(inx_to_inst.values()))

# %%
stud = student_produced_over_time(df=mod_ment2)
# Out:
# [3, 20, 20, 20, 23, 34, 450, 3068, 10089, 24461, 47929, 94844, 174551]
# [1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
#stud1 = student_produced_over_time(df=mod_ment2,st_year=1951, end_year=2017, interval_size=5)

# %%
student = [3, 20, 20, 20, 23, 34, 450, 3068, 10089, 24461, 47929, 94844, 174551]
over_time =  [1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
inst1 = [3, 8, 8, 8, 10, 12, 23, 38, 50, 62, 76, 162, 359]
time1 = [1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
np.log2(student)
# Out:
# array([ 1.5849625 ,  4.32192809,  4.32192809,  4.32192809,  4.52356196,
#         5.08746284,  8.81378119, 11.58308277, 13.30049556, 14.57819576,
#        15.54861122, 16.53326889, 17.4132891 ])

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.plot(over_time, student, color="g",marker="*", label = 'Thesis/Researcher Growth (log10 scaled)')
plt.plot(over_time, inst1 , color="b",marker="*", label = 'University/Institute Growth (log10 scaled)')
plt.title("", fontsize=12)#No. of Researcher Graduated over time
plt.ylabel("Frequency", fontsize=20,fontweight='bold')
plt.xlabel("Year", fontsize=20,fontweight='bold')
ax.set_yscale('log')
plt.legend(fancybox=True, shadow=True,prop={"weight":'bold',"size":14})
plt.savefig('../new_graphs/comb_thesis_inst_distribution_over_time.svg',bbox_inches='tight')
plt.show()

# %%
inst = inst_increase_over_time(df=mod_ment2)
# Out:
# [3, 8, 8, 8, 10, 12, 23, 38, 50, 62, 76, 162, 359]
# [1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
#inst1 = inst_increase_over_time(df=mod_ment2,st_year=1951, end_year=2017, interval_size=5)

# %%
#mod_ment2['new_date_awarded'].isnull().sum()

# %%
#pd.unique(mod_ment2['N_thesisId']).shape

# %%
#exp = mod_ment2.drop_duplicates(subset='N_thesisId', keep="last").copy()

# %%
#exp.shape

# %%
#exp['new_date_awarded'].isnull().sum()

# %%
#mod_ment2.sample(10)['title'].values

# %%
#inx_to_inst#I87,I203,I292

# %%
#mod_ment2.columns

# %%
#mod_ment2[mod_ment2['instituteId']=='I87'].isnull().sum()#punjab

# %%
#mod_ment2[mod_ment2['instituteId']=='I292'].isnull().sum()#I250

# %%
#mod_ment2[mod_ment2['instituteId']=='I250'].isnull().sum()#I364

# %%
#mod_ment2[mod_ment2['instituteId']=='I364'].isnull().sum()#I364
